# %%
# Importing relevant packages and establishing the Exadata connection

import pandas as pd
import numpy as np
import getpass
import datetime as dt

# %%
df = pd.read_csv('textmining/products.csv')

prods = df.iloc[0:1000, :]
print(prods.head())
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
import re as re
import nltk
from nltk.stem.porter import *
from nltk.tokenize import TreebankWordTokenizer
from nltk.corpus import wordnet
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords

toker = TreebankWordTokenizer()

stemmer = SnowballStemmer("english")
prods['short_desc'] = prods.product_name.str.lower()

# Defining a function to clean the data and tokenize it 

def text_preprocessor(x):

    tmp = str(x)
    tmp = tmp.lower()
    x_cleaned = tmp.replace('/', ' ').replace('-', ' ').replace('"', '')
    
    stops = stopwords.words("english")   # removing stop words 
    
    tokens = toker.tokenize(x_cleaned)
    meaningful_words = [w for w in tokens if not w in [stops]]
    return( " ".join( meaningful_words ))  # Join the words back into one string separated by space, and return the result.



prods['desc']  = prods['short_desc'].apply(text_preprocessor)

# Removing numbers/special characters and other junk from the product descriptions using regular expressions
prods['new_desc'] = prods['desc'].map(lambda x: re.sub(r'\W+', ' ', x))
prods['wt_desc'] = prods['new_desc'].map(lambda x: re.sub("\d+(\s|g|mth|cm|hr|gram|s|kg|kilograms|cl|ml|ltr|pk| pk|gms|nb|up|\
                                                          |s|x|pack|l|lb|mg|d|in|yo|p|c|mm|qp|er|m|vol|h|oz|th|w|yr|tbsp|rd|nd)", '', x))
prods['final_desc'] = prods['wt_desc'].map(lambda x: re.sub('^\d+\s|\s\d+\s|\s\d+$', ' ', x))

prods_1 = prods[~prods.final_desc.isin([None])] # Removing null descriptions from the data set

prods_1.head()
# Out:
# /usr/lib/python3.4/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /usr/lib/python3.4/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/lib/python3.4/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/lib/python3.4/site-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/lib/python3.4/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id                                         short_desc  \
# 0             19                         chocolate sandwich cookies
# 1             13                                   all-seasons salt
# 2              7               robust golden unsweetened oolong tea
# 3              1  smart ones classic favorites mini rigatoni wit...
# 4             13                          green chile anytime sauce
#
#                                                 desc  \
# 0                         chocolate sandwich cookies
# 1                                   all seasons salt
# 2               robust golden unsweetened oolong tea
# 3  smart ones classic favorites mini rigatoni wit...
# 4                          green chile anytime sauce
#
#                                             new_desc  \
# 0                         chocolate sandwich cookies
# 1                                   all seasons salt
# 2               robust golden unsweetened oolong tea
# 3  smart ones classic favorites mini rigatoni wit...
# 4                          green chile anytime sauce
#
#                                              wt_desc  \
# 0                         chocolate sandwich cookies
# 1                                   all seasons salt
# 2               robust golden unsweetened oolong tea
# 3  smart ones classic favorites mini rigatoni wit...
# 4                          green chile anytime sauce
#
#                                           final_desc
# 0                         chocolate sandwich cookies
# 1                                   all seasons salt
# 2               robust golden unsweetened oolong tea
# 3  smart ones classic favorites mini rigatoni wit...
# 4                          green chile anytime sauce

# %%
# Using Tf-idf vectorizer from sklearn to create the bag of words and convert them into features

from sklearn.feature_extraction.text import TfidfVectorizer
vector_new = TfidfVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = "english",\
                             max_features = 40000)

product_bag = vector_new.fit_transform(prods_1.final_desc).toarray()
print(product_bag.shape)

vector_new.get_feature_names()
# Out:
# (1000, 1647)
# ['absorbency',
#  'acai',
#  'acaí',
#  'acne',
#  'acti',
#  'acting',
#  'action',
#  'active',
#  'added',
#  'ade',
#  'adobo',
#  'adult',
#  'advanced',
#  'adzuki',
#  'aged',
#  'ahoy',
#  'aid',
#  'air',
#  'albacore',
#  'alcohol',
#  'ale',
#  'alfredo',
#  'allergy',
#  'almond',
#  'almondmilk',
#  'almonds',
#  'aloe',
#  'alongs',
#  'alpha',
#  'aluminum',
#  'american',
#  'americana',
#  'aminos',
#  'annie',
#  'anti',
#  'antibacterial',
#  'antioxidant',
#  'antiplaque',
#  'antiseptic',
#  'anytime',
#  'apple',
#  'apples',
#  'applicator',
#  'apricot',
#  'apricots',
#  'aquaphor',
#  'argan',
#  'armor',
#  'aromatherapaes',
#  'arrabbiata',
#  'arrowroot',
#  'artichokes',
#  'artificial',
#  'artihearts',
#  'artisan',
#  'arugula',
#  'asiago',
#  'asian',
#  'asparagus',
#  'aspirin',
#  'assortment',
#  'atlantic',
#  'auroville',
#  'australian',
#  'authentic',
#  'automatic',
#  'autumn',
#  'awesome',
#  'babies',
#  'baby',
#  'bachelor',
#  'bacon',
#  'bag',
#  'bagels',
#  'bags',
#  'baits',
#  'bake',
#  'baked',
#  'bakeware',
#  'ball',
#  'balm',
#  'bamboo',
#  'banana',
#  'bananas',
#  'bar',
#  'barbara',
#  'barista',
#  'barley',
#  'barrel',
#  'bars',
#  'base',
#  'basil',
#  'bath',
#  'bathroom',
#  'bbq',
#  'beach',
#  'bean',
#  'beans',
#  'beef',
#  'beer',
#  'belgian',
#  'benefit',
#  'berries',
#  'berry',
#  'best',
#  'beta',
#  'beverage',
#  'binks',
#  'biotin',
#  'biscuit',
#  'bite',
#  'bites',
#  'bits',
#  'black',
#  'blackberry',
#  'blade',
#  'blades',
#  'blakes',
#  'blast',
#  'bleach',
#  'blend',
#  'bleu',
#  'blitz',
#  'block',
#  'blonde',
#  'blood',
#  'blossom',
#  'blossoms',
#  'blue',
#  'blueberries',
#  'blueberry',
#  'blush',
#  'bmg',
#  'board',
#  'bobby',
#  'body',
#  'bolani',
#  'bold',
#  'bologna',
#  'bone',
#  'boom',
#  'boost',
#  'booster',
#  'born',
#  'bottle',
#  'bottles',
#  'bowl',
#  'boysenberries',
#  'brain',
#  'brambleberry',
#  'bran',
#  'brand',
#  'brasilia',
#  'brazilian',
#  'bread',
#  'breadcrumbs',
#  'breaded',
#  'breadstick',
#  'break',
#  'breakfast',
#  'breast',
#  'breath',
#  'breeze',
#  'brew',
#  'brie',
#  'bright',
#  'brightener',
#  'brioche',
#  'brisk',
#  'broccoli',
#  'brooklyn',
#  'bros',
#  'broth',
#  'brown',
#  'brownie',
#  'brownies',
#  'brussels',
#  'brut',
#  'bubblegum',
#  'buckthorn',
#  'buckwheat',
#  'buffalo',
#  'bunny',
#  'buns',
#  'burger',
#  'burgers',
#  'burrito',
#  'butter',
#  'buttercream',
#  'butterfinger',
#  'buttermilk',
#  'cabernet',
#  'cacao',
#  'caesar',
#  'cafe',
#  'caffeine',
#  'caffiene',
#  'café',
#  'cake',
#  'cakes',
#  'calcium',
#  'california',
#  'calming',
#  'calories',
#  'camilia',
#  'candies',
#  'candle',
#  'candy',
#  'cane',
#  'canned',
#  'cantaloupe',
#  'cap',
#  'caplets',
#  'cappuccino',
#  'capsules',
#  'caramel',
#  'caraway',
#  'cardamom',
#  'cardboard',
#  'care',
#  'carrot',
#  'carrots',
#  'cartridge',
#  'cashew',
#  'cashewgurt',
#  'cashewmilk',
#  'cashews',
#  'castile',
#  'cat',
#  'cats',
#  'cauliflower',
#  'cavity',
#  'cayenne',
#  'celery',
#  'central',
#  'cereal',
#  'cereals',
#  'ceylon',
#  'cg',
#  'chai',
#  'chamomile',
#  'chamomilla',
#  'chanterelle',
#  'chapatti',
#  'chardonnay',
#  'cheddar',
#  'cheerios',
#  'cheese',
#  'cheesecake',
#  'cheesy',
#  'cheezy',
#  'chef',
#  'chelada',
#  'cherry',
#  'chew',
#  'chewables',
#  'chews',
#  'chewy',
#  'chex',
#  'chia',
#  'chicago',
#  'chicharrones',
#  'chick',
#  'chicka',
#  'chicken',
#  'children',
#  'chile',
#  'chili',
#  'chilies',
#  'chilis',
#  'chilpotles',
#  'chinese',
#  'chip',
#  'chipotle',
#  'chips',
#  'chkn',
#  'chocolate',
#  'choice',
#  'chop',
#  'chopped',
#  'chops',
#  'chorizo',
#  'chow',
#  'chowder',
#  'chrome',
#  'chub',
#  'chunk',
#  'chunky',
#  'churned',
#  'ciabatta',
#  'cider',
#  'cilantro',
#  'cinnamon',
#  'citrate',
#  'citrus',
#  'city',
#  'clam',
#  'clamato',
#  'clamshell',
#  'clarified',
#  'classic',
#  'classics',
#  'clean',
#  'cleaner',
#  'cleanse',
#  'cleanser',
#  'cleansing',
#  'clear',
#  'clementine',
#  'clementines',
#  'cling',
#  'cloths',
#  'clusters',
#  'coarse',
#  'coast',
#  'cocktail',
#  'coco',
#  'cocoa',
#  'coconut',
#  'cod',
#  'coffee',
#  'coke',
#  'colby',
#  'cold',
#  'collagen',
#  'color',
#  'columbian',
#  'combo',
#  'comment',
#  'compactor',
#  'compleats',
#  'complete',
#  'concentrate',
#  'concentrated',
#  'condensed',
#  'conditioner',
#  'conditioning',
#  'cones',
#  'confetti',
#  'constant',
#  'contact',
#  'container',
#  'containers',
#  'control',
#  'cooked',
#  'cookie',
#  'cookies',
#  'cooking',
#  'cool',
#  'corn',
#  'cornish',
#  'cottage',
#  'cotton',
#  'cough',
#  'count',
#  'countertop',
#  'country',
#  'couscous',
#  'crabmeat',
#  'cracked',
#  'cracker',
#  'crackers',
#  'craft',
#  'cranberries',
#  'cranberrry',
#  'cranberry',
#  'cream',
#  'creamer',
#  'creamline',
#  'creamy',
#  'creations',
#  'creme',
#  'crisp',
#  'crispbreads',
#  'crisps',
#  'crispy',
#  'crossovers',
#  'cruisers',
#  'crumbs',
#  'crunch',
#  'crunchers',
#  'crunchy',
#  'crushed',
#  'crust',
#  'cruz',
#  'ct',
#  'cucumber',
#  'culinary',
#  'cultured',
#  'cup',
#  'cupcakes',
#  'cups',
#  'curds',
#  'currant',
#  'curry',
#  'cut',
#  'cuts',
#  'cutting',
#  'daily',
#  'dailyfoods',
#  'dairy',
#  'daly',
#  'dance',
#  'dandelion',
#  'danish',
#  'dark',
#  'dawn',
#  'day',
#  'dcholecalciferol',
#  'deboned',
#  'decaffeinated',
#  'decorating',
#  'deep',
#  'deet',
#  'defying',
#  'deli',
#  'deluxe',
#  'dental',
#  'deodorant',
#  'designer',
#  'dessert',
#  'desserts',
#  'detergent',
#  'detox',
#  'dha',
#  'di',
#  'diablo',
#  'diapers',
#  'diarrheal',
#  'diavolo',
#  'diced',
#  'diet',
#  'dietary',
#  'dill',
#  'dinner',
#  'dinosaur',
#  'dip',
#  'dipping',
#  'direct',
#  'discovery',
#  'dish',
#  'dishwasher',
#  'dishwashing',
#  'disinfectant',
#  'disposable',
#  'dissolve',
#  'divino',
#  'dnatural',
#  'dog',
#  'dogs',
#  'doo',
#  'doodle',
#  'doses',
#  'dote',
#  'double',
#  'dough',
#  'downy',
#  'dr',
#  'dragonfruit',
#  'dreams',
#  'dressing',
#  'dried',
#  'drink',
#  'drinkable',
#  'drops',
#  'dry',
#  'dryer',
#  'dual',
#  'duck',
#  'duopack',
#  'duty',
#  'dye',
#  'earl',
#  'east',
#  'easter',
#  'easy',
#  'eating',
#  'echinacea',
#  'eco',
#  'econet',
#  'edamame',
#  'effects',
#  'effervescent',
#  'egg',
#  'einkorn',
#  'el',
#  'elbow',
#  'elbows',
#  'elderberry',
#  'eliminator',
#  'elixir',
#  'elmo',
#  'embrace',
#  'energy',
#  'england',
#  'english',
#  'enhance',
#  'enhancer',
#  'enhancers',
#  'enrich',
#  'enriched',
#  'entree',
#  'entrees',
#  'enzymes',
#  'epa',
#  'essentials',
#  'ettes',
#  'eucalyptus',
#  'euro',
#  'european',
#  'evercurl',
#  'everyday',
#  'extra',
#  'extract',
#  'fabric',
#  'face',
#  'facial',
#  'fade',
#  'fajita',
#  'fancy',
#  'fashioned',
#  'fat',
#  'fava',
#  'favorites',
#  'fe',
#  'feast',
#  'fed',
#  'female',
#  'feminine',
#  'fermented',
#  'feta',
#  'fettucine',
#  'fever',
#  'fiber',
#  'fields',
#  'fieno',
#  'fig',
#  'filets',
#  'filled',
#  'film',
#  'filter',
#  'filtered',
#  'fingerling',
#  'finish',
#  'firm',
#  'fish',
#  'fit',
#  'fl',
#  'flaked',
#  'flakes',
#  'flamin',
#  'flat',
#  'flatbread',
#  'flatbreads',
#  'flavor',
#  'flavored',
#  'flavors',
#  'flax',
#  'flaxseed',
#  'floor',
#  'floral',
#  'florettes',
#  'floss',
#  'flour',
#  'flourless',
#  'flu',
#  'fluffy',
#  'fluoride',
#  'foam',
#  'foamer',
#  'foaming',
#  'foil',
#  'foldit',
#  'food',
#  'foods',
#  'forest',
#  'formaggi',
#  'formula',
#  'fra',
#  'freak',
#  'free',
#  'freeze',
#  'freezer',
#  'french',
#  'fresh',
#  'freshener',
#  'frosting',
#  'frozen',
#  'fruit',
#  'fruits',
#  'fruitwater',
#  'fry',
#  'fudge',
#  'fuel',
#  'fun',
#  'funfetti',
#  'furniture',
#  'gain',
#  'gallo',
#  'gallon',
#  'garbanzo',
#  'garden',
#  'garlic',
#  'garnet',
#  'gefilte',
#  'gel',
#  'gelato',
#  'gels',
#  'gentle',
#  'geranium',
#  'german',
#  'gin',
#  'ginger',
#  'gingersnap',
#  'ginkgo',
#  'gins',
#  'ginseng',
#  'glass',
#  'glazed',
#  'glow',
#  'glue',
#  'gluten',
#  'glycerine',
#  'gmo',
#  'goat',
#  'goji',
#  'gold',
#  'golden',
#  'goldenseal',
#  'goober',
#  'good',
#  'gouda',
#  'gourmet',
#  'grab',
#  'grade',
#  'graduates',
#  'graham',
#  'grain',
#  'grains',
#  'granola',
#  'granulated',
#  'granulation',
#  'granules',
#  'grape',
#  'grapes',
#  'grass',
#  'grassmilk',
#  'gravy',
#  'great',
#  'greek',
#  'green',
#  'greener',
#  'greens',
#  'grey',
#  'grigio',
#  'grilled',
#  'grind',
#  'groats',
#  'ground',
#  'gum',
#  'gummi',
#  'gummies',
#  'gummy',
#  'habanero',
#  'hacho',
#  'hair',
#  'hairball',
#  'haircare',
#  'half',
#  'halves',
#  'ham',
#  'hand',
#  'hard',
#  'harvest',
#  'hash',
#  'hawaiian',
#  'hazel',
#  'healing',
#  'health',
#  'healthfull',
#  'healthy',
#  'heart',
#  'hearts',
#  'hearty',
#  'heavy',
#  'heirloom',
#  'hemp',
#  'hen',
#  'herb',
#  'herbal',
#  'herbs',
#  'hi',
#  'hibiscus',
#  'high',
#  'hold',
#  'holiday',
#  'home',
#  'homemade',
#  'homestyle',
#  'honey',
#  'honeycrisp',
#  'honeydew',
#  'horseradish',
#  'hot',
#  'house',
#  'hummus',
#  'hydracharge',
#  'hydro',
#  'ibuprofen',
#  'ice',
#  'iced',
#  'icing',
#  'imitation',
#  'immune',
#  'imported',
#  'incense',
#  'inch',
#  'infant',
#  'infants',
#  'infinity',
#  'infusions',
#  'injera',
#  'ink',
#  'insect',
#  'insecticide',
#  'instant',
#  'international',
#  'invigorating',
#  'invisible',
#  'ipa',
#  'island',
#  'israeli',
#  'italian',
#  'iu',
#  'jack',
#  'jalapeno',
#  'jam',
#  'jars',
#  'jasmine',
#  'java',
#  'jelly',
#  'jet',
#  'joe',
#  'juice',
#  'juicing',
#  'juicy',
#  'jumbo',
#  'juniper',
#  'just',
#  'kabocha',
#  'kalamata',
#  'kale',
#  'kamut',
#  'kansas',
#  'keebler',
#  'kefir',
#  'keratin',
#  'kernel',
#  'kettle',
#  'key',
#  'kickstart',
#  'kid',
#  'kidney',
#  'kids',
#  'kielbasa',
#  'kind',
#  'kisses',
#  'kit',
#  'kitchen',
#  'kiwi',
#  'kombucha',
#  'kosher',
#  'kraut',
#  'lamb',
#  'large',
#  'lasagna',
#  'lasagne',
#  'lash',
#  'lasting',
#  'laundry',
#  'lavender',
#  'laxative',
#  'layer',
#  'leaf',
#  'lean',
#  'leave',
#  'lecithin',
#  'lemon',
#  'lemonade',
#  'lemons',
#  'length',
#  'lens',
#  'lentil',
#  'lettuce',
#  'lids',
#  'light',
#  'lightest',
#  'lightly',
#  'lil',
#  'lime',
#  'limeade',
#  'linen',
#  'liners',
#  'linguine',
#  'linguini',
#  'links',
#  'lion',
#  'lip',
#  'liqueur',
#  'liqui',
#  'liquid',
#  'liquorice',
#  'listerine',
#  'lite',
#  'litter',
#  'little',
#  'liver',
#  'living',
#  'loads',
#  'loaf',
#  'loaves',
#  'loc',
#  'local',
#  'long',
#  'loss',
#  'lost',
#  'lotion',
#  'low',
#  'lower',
#  'lowfat',
#  'lozenges',
#  'lunchmakers',
#  'mac',
#  'macaroni',
#  'mache',
#  'mackerel',
#  'mag',
#  'magnesium',
#  'maid',
#  'majestic',
#  'makeup',
#  'malbec',
#  'mallow',
#  'malt',
#  'man',
#  'mandarin',
#  'mango',
#  'mania',
#  'maple',
#  'marble',
#  'marinade',
#  'marinara',
#  'marscapone',
#  'masala',
#  'mascara',
#  'mascarpone',
#  'mash',
#  'mashed',
#  'mashups',
#  'massage',
#  'mate',
#  'mature',
#  'max',
#  'maximum',
#  'maxtra',
#  'mcg',
#  'meadow',
#  'meadows',
#  'meal',
#  'meals',
#  'measuring',
#  'meat',
#  'meatballs',
#  'meatloaf',
#  'medium',
#  'medleys',
#  'mega',
#  'mein',
#  'melanie',
#  'melatonin',
#  'melon',
#  'melts',
#  'memorial',
#  'men',
#  'merlot',
#  'mexico',
#  'mg',
#  'micro',
#  'microwave',
#  'middle',
#  'mild',
#  'milk',
#  'milkfat',
#  'mineral',
#  'mini',
#  'minis',
#  'mint',
#  'mirabelle',
#  'miso',
#  'mist',
#  'mix',
#  'mixed',
#  'mm',
#  'moisture',
#  'moisturizer',
#  'moisturizing',
#  'molasses',
#  'months',
#  'mop',
#  'mopping',
#  'moringa',
#  'mornings',
#  'morocco',
#  'moscato',
#  'mosel',
#  'mountain',
#  'mousse',
#  'mouth',
#  'mouthwash',
#  'movie',
#  'mozzarella',
#  'muffin',
#  'muffins',
#  'multi',
#  'multigrain',
#  'multivitamin',
#  'munch',
#  'mushroom',
#  'mushrooms',
#  'mustard',
#  'naan',
#  'nacho',
#  'napkins',
#  'napoli',
#  'nasaflo',
#  'nasal',
#  'natural',
#  'naturally',
#  'naturals',
#  'nature',
#  'nectarines',
#  'neem',
#  'nestle',
#  'neti',
#  'new',
#  'newborn',
#  'night',
#  'nilla',
#  'nino',
#  'non',
#  'nonfat',
#  'noodle',
#  'noodles',
#  'normal',
#  'norwegian',
#  'nose',
#  'nourishing',
#  'nova',
#  'nugget',
#  'nuggets',
#  'nut',
#  'nutri',
#  'nutrition',
#  'nutrium',
#  'nuts',
#  'nutter',
#  'nyquil',
#  'oat',
#  'oatmeal',
#  'oatnut',
#  'oats',
#  'ocean',
#  'odor',
#  'oelek',
#  'oh',
#  'oikos',
#  'oil',
#  'ointment',
#  'oj',
#  'old',
#  'olive',
#  'olives',
#  'olli',
#  'omega',
#  'ones',
#  'onezip',
#  'onion',
#  'onions',
#  'oolong',
#  'opa',
#  'open',
#  'opener',
#  'oral',
#  'orange',
#  'oregano',
#  'oreo',
#  'organic',
#  'original',
#  'orzo',
#  'outlast',
#  ...]

# %%
# Concatenating bag of words representation with the original data 

products= pd.concat([prods_1.product_id, prods_1.product_name, prods_1.aisle_id, prods_1.department_id, prods_1.final_desc,
                               pd.DataFrame(product_bag, 
                                            columns= vector_new.get_feature_names(), index = prods_1.index)], axis=1)

prod_shape= pd.DataFrame(product_bag,columns= vector_new.get_feature_names(), index = prods_1.index)

# Looking at the most frequently occuring words and their cumulative score
prod_shape.sum().sort_values(ascending=False).head(100)
# Out:
# organic        27.847803
# cheese         14.402114
# chocolate      12.279438
# chicken        11.538936
# free           10.807617
# sauce           9.563004
# bar             9.432624
# tea             9.286392
# butter          9.095845
# vanilla         8.913695
# mix             8.723252
# cream           8.614585
# yogurt          8.394062
# blueberry       8.205332
# fruit           7.747023
# almond          7.745187
# juice           7.665321
# original        7.599579
# strawberry      7.536889
# blend           7.331994
# lemon           7.278775
# honey           7.208633
# turkey          7.198718
# vegetable       7.161820
# water           7.158457
# garlic          7.083952
# milk            7.038105
# wheat           6.805448
# red             6.718069
# pasta           6.667271
#                  ...
# oil             4.423390
# size            4.418972
# orange          4.402152
# mint            4.359728
# dry             4.315021
# cheddar         4.212334
# classic         4.188389
# ice             4.176245
# light           4.137568
# hot             4.072530
# coffee          4.031838
# greek           4.013967
# salad           3.991844
# baby            3.937122
# detergent       3.921531
# liquid          3.906970
# traditional     3.902977
# pure            3.897162
# dressing        3.895463
# fat             3.815182
# italian         3.805805
# soap            3.796643
# bags            3.785562
# herbal          3.779105
# extra           3.755622
# ultra           3.745885
# corn            3.720815
# cherry          3.698963
# super           3.683374
# snack           3.639233
# Length: 100, dtype: float64

# %%
# Importing relevant packages to calculate cosine distance 

import time as time 
import scipy.sparse
import random
import itertools
import numpy as np

from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse 

tfidf = vector_new.fit_transform(prods_1.final_desc).toarray() # Getting the tfidf representation again from vector

start_time = time.time()

# Iterating through the list of products to calculate the cosine similarity
b =[]
for i in range(tfidf.shape[0]): 
    a = linear_kernel(tfidf[i], tfidf).flatten() # linear kernel is used as the dot product gives the same result for normalized vetors in lesser time
    b.append(a)

print("--- RUNTIME : %s seconds ---" % (time.time() - start_time))

c = np.array(b)

start_time = time.time()

# Iterating throgh the matrix to pick products with similarity more than 0.5 and also ensuring to not look for the same product
a =[]
for (x,y), k in np.ndenumerate(c):
    if k > 0.5 and x!=y:
        q = products[products['product_id']==prods_1.iloc[x][0]]
        w = products[products['product_id']==prods_1.iloc[y][0]]
        u = np.array(q.iloc[0][10:], dtype=pd.Series)
        v = np.array(w.iloc[0][10:], dtype=pd.Series)
        s = (products.iloc[x][0],products.iloc[x][1], products.iloc[x][3],products.iloc[y][0], products.iloc[y][1], 
             products.iloc[y][3],products.iloc[x][4],products.iloc[y][4],k,scipy.spatial.distance.cosine(u, v))
        a.append(s)     

m = pd.DataFrame(a)

m.to_csv('prod_match.csv', sep=',')

print("--- RUNTIME : %s seconds ---" % (time.time() - start_time))
# Out:
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ...
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /usr/lib64/python3.4/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# --- RUNTIME : 1.566037654876709 seconds ---
# --- RUNTIME : 6.506204843521118 seconds ---

# %%
# Assigning columns and looking at the results

m.columns = ['primary_product_id','primary_product','primary_dept','secondary_product_id','secondary_product','secondary_dept'
            ,'primary_desc','secondary_desc','cosine_sim','cosine_dist']

m.sort_values('cosine_sim', ascending = False)
# Out:
#      primary_product_id                                    primary_product  \
# 139                 424                                     Linguine Pasta
# 318                 972                                Linguine No 7 Pasta
# 279                 890                             Organic Diced Tomatoes
# 127                 405                        100% Organic Diced Tomatoes
# 229                 690                       Vegetable Hearty Garden Soup
# 210                 626               Organic Hearty Garden Vegetable Soup
# 315                 969                                  Petite Green Peas
# 111                 327                        Green Peas, Organic, Petite
# 80                  254                                      Honey Mustard
# 262                 810                              Organic Honey Mustard
# 153                 454                                   Sloppy Joe Sauce
# 61                  201                                         Sloppy Joe
# 234                 721                   Sweet Chai of Mine Chai Tea Bags
# 93                  281                                      Chai Tea Bags
# 65                  217                          String Cheese, Mozzarella
# 164                 505       100% Natural String Cheese Mozzarella Cheese
# 126                 397                         Pure Granulated Cane Sugar
# 162                 495                 Pure Cane Granulated W/Spout Sugar
# 33                  112                                Hot Tomatillo Salsa
# 177                 546                                    Tomatillo Salsa
# 57                  193        fruitwater® Strawberry Kiwi Sparkling Water
# 69                  223                    Kiwi Strawberry Sparkling Water
# 62                  203                               Rescue Remedy, Spray
# 175                 535                                      Rescue Remedy
# 323                 983                             Strawberry Pomegranate
# 43                  132                      Yogurt Strawberry Pomegranate
# 9                    34                               Peanut Butter Cereal
# 213                 637                    Multigrain Peanut Butter Cereal
# 317                 972                                Linguine No 7 Pasta
# 137                 424                                     Linguine Pasta
# ..                  ...                                                ...
# 298                 934                   Mini Pre-Sliced Blueberry Bagels
# 264                 836                                Sliced Onion Bagels
# 220                 653       Flax, Oat Bran & Whole Wheat Flour Tortillas
# 17                   58                              Whole Wheat Tortillas
# 89                  269                    Stuffed Crust Five Cheese Pizza
# 117                 356          Ristorante Pizza Spinaci Thin Crust Pizza
# 44                  135                   Dark Chocolate Ice Cream Topping
# 141                 431                         Ice Cream, Cookies & Cream
# 35                  118                                 Ground Turkey Chub
# 256                 782           85% Lean, 15% Fat Ground Turkey (013021)
# 182                 559  Cookie Chips Crunchy Dark Chocolate Chocolate ...
# 52                  172     Gluten Free All Natural Chocolate Chip Cookies
# 289                 922                Chipotle & Roasted Garlic Seasoning
# 46                  140                        Chips Onion Chipotle Garlic
# 276                 883                   Peanut Butter Chocolate Chip Bar
# 10                   34                               Peanut Butter Cereal
# 200                 602                              Banana Chocolate Chip
# 278                 883                   Peanut Butter Chocolate Chip Bar
# 179                 552      Organic Mango Peach Carrot Kickstart Smoothie
# 2                    11                                  Peach Mango Juice
# 119                 362                                Pound Cake Cake Mix
# 68                  218                            6\" Organic Carrot Cake
# 109                 326  Deluxe Sauce Made with 2% Milk Cheese Macaroni...
# 190                 592          SpongeBob Shapes Macaroni & Cheese Dinner
# 84                  258                                  Vegetable Pot Pie
# 297                 932                 Vegetable Pie In A Pocket Sandwich
# 34                  118                                 Ground Turkey Chub
# 96                  287                                             Turkey
# 115                 342  Complete Health Deboned Chicken, Chicken Meal ...
# 196                 597              Chicken & Brown Rice Formula Cat Food
#
#      primary_dept  secondary_product_id  \
# 139             9                   972
# 318             9                   424
# 279            15                   405
# 127            15                   890
# 229            21                   626
# 210            15                   690
# 315             1                   327
# 111             1                   969
# 80             13                   810
# 262            13                   254
# 153            13                   201
# 61              1                   454
# 234             7                   281
# 93              7                   721
# 65             16                   505
# 164            16                   217
# 126            13                   495
# 162            13                   397
# 33             13                   546
# 177            13                   112
# 57              7                   223
# 69              7                   193
# 62             11                   535
# 175             2                   203
# 323            19                   132
# 43             16                   983
# 9              14                   637
# 213            14                    34
# 317             9                   418
# 137             9                   418
# ..            ...                   ...
# 298             3                   836
# 264             3                   934
# 220             3                    58
# 17              3                   653
# 89              1                   356
# 117             1                   269
# 44             19                   431
# 141             1                   135
# 35              1                   782
# 256            12                   118
# 182            19                   172
# 52             19                   559
# 289            13                   140
# 46             19                   922
# 276            19                    34
# 10             14                   883
# 200             1                   883
# 278            19                   602
# 179             1                    11
# 2               7                   552
# 119            13                   218
# 68              3                   362
# 109             9                   592
# 190             9                   326
# 84              1                   932
# 297             1                   258
# 34              1                   287
# 96             20                   118
# 115             8                   597
# 196             8                   342
#
#                                      secondary_product  secondary_dept  \
# 139                                Linguine No 7 Pasta               9
# 318                                     Linguine Pasta               9
# 279                        100% Organic Diced Tomatoes              15
# 127                             Organic Diced Tomatoes              15
# 229               Organic Hearty Garden Vegetable Soup              15
# 210                       Vegetable Hearty Garden Soup              21
# 315                        Green Peas, Organic, Petite               1
# 111                                  Petite Green Peas               1
# 80                               Organic Honey Mustard              13
# 262                                      Honey Mustard              13
# 153                                         Sloppy Joe               1
# 61                                    Sloppy Joe Sauce              13
# 234                                      Chai Tea Bags               7
# 93                    Sweet Chai of Mine Chai Tea Bags               7
# 65        100% Natural String Cheese Mozzarella Cheese              16
# 164                          String Cheese, Mozzarella              16
# 126                 Pure Cane Granulated W/Spout Sugar              13
# 162                         Pure Granulated Cane Sugar              13
# 33                                     Tomatillo Salsa              13
# 177                                Hot Tomatillo Salsa              13
# 57                     Kiwi Strawberry Sparkling Water               7
# 69         fruitwater® Strawberry Kiwi Sparkling Water               7
# 62                                       Rescue Remedy               2
# 175                               Rescue Remedy, Spray              11
# 323                      Yogurt Strawberry Pomegranate              16
# 43                              Strawberry Pomegranate              19
# 9                      Multigrain Peanut Butter Cereal              14
# 213                               Peanut Butter Cereal              14
# 317                         Whole Grain Linguine Pasta               9
# 137                         Whole Grain Linguine Pasta               9
# ..                                                 ...             ...
# 298                                Sliced Onion Bagels               3
# 264                   Mini Pre-Sliced Blueberry Bagels               3
# 220                              Whole Wheat Tortillas               3
# 17        Flax, Oat Bran & Whole Wheat Flour Tortillas               3
# 89           Ristorante Pizza Spinaci Thin Crust Pizza               1
# 117                    Stuffed Crust Five Cheese Pizza               1
# 44                          Ice Cream, Cookies & Cream               1
# 141                   Dark Chocolate Ice Cream Topping              19
# 35            85% Lean, 15% Fat Ground Turkey (013021)              12
# 256                                 Ground Turkey Chub               1
# 182     Gluten Free All Natural Chocolate Chip Cookies              19
# 52   Cookie Chips Crunchy Dark Chocolate Chocolate ...              19
# 289                        Chips Onion Chipotle Garlic              19
# 46                 Chipotle & Roasted Garlic Seasoning              13
# 276                               Peanut Butter Cereal              14
# 10                    Peanut Butter Chocolate Chip Bar              19
# 200                   Peanut Butter Chocolate Chip Bar              19
# 278                              Banana Chocolate Chip               1
# 179                                  Peach Mango Juice               7
# 2        Organic Mango Peach Carrot Kickstart Smoothie               1
# 119                            6\" Organic Carrot Cake               3
# 68                                 Pound Cake Cake Mix              13
# 109          SpongeBob Shapes Macaroni & Cheese Dinner               9
# 190  Deluxe Sauce Made with 2% Milk Cheese Macaroni...               9
# 84                  Vegetable Pie In A Pocket Sandwich               1
# 297                                  Vegetable Pot Pie               1
# 34                                              Turkey              20
# 96                                  Ground Turkey Chub               1
# 115              Chicken & Brown Rice Formula Cat Food               8
# 196  Complete Health Deboned Chicken, Chicken Meal ...               8
#
#                                           primary_desc  \
# 139                                     linguine pasta
# 318                                  linguine no pasta
# 279                             organic diced tomatoes
# 127                             organic diced tomatoes
# 229                       vegetable hearty garden soup
# 210               organic hearty garden vegetable soup
# 315                                  petite green peas
# 111                          green peas organic petite
# 80                                       honey mustard
# 262                              organic honey mustard
# 153                                   sloppy joe sauce
# 61                                          sloppy joe
# 234                   sweet chai of mine chai tea bags
# 93                                       chai tea bags
# 65                            string cheese mozzarella
# 164            natural string cheese mozzarella cheese
# 126                         pure granulated cane sugar
# 162                 pure cane granulated w spout sugar
# 33                                 hot tomatillo salsa
# 177                                    tomatillo salsa
# 57          fruitwater strawberry kiwi sparkling water
# 69                     kiwi strawberry sparkling water
# 62                                 rescue remedy spray
# 175                                      rescue remedy
# 323                             strawberry pomegranate
# 43                       yogurt strawberry pomegranate
# 9                                 peanut butter cereal
# 213                    multigrain peanut butter cereal
# 317                                  linguine no pasta
# 137                                     linguine pasta
# ..                                                 ...
# 298                   mini pre sliced blueberry bagels
# 264                                sliced onion bagels
# 220          flax oat bran whole wheat flour tortillas
# 17                               whole wheat tortillas
# 89                     stuffed crust five cheese pizza
# 117          ristorante pizza spinaci thin crust pizza
# 44                    dark chocolate ice cream topping
# 141                            ice cream cookies cream
# 35                                  ground turkey chub
# 256                            lean fat ground turkey
# 182  cookie chips crunchy dark chocolate chocolate ...
# 52      gluten free all natural chocolate chip cookies
# 289                  chipotle roasted garlic seasoning
# 46                         chips onion chipotle garlic
# 276                   peanut butter chocolate chip bar
# 10                                peanut butter cereal
# 200                              banana chocolate chip
# 278                   peanut butter chocolate chip bar
# 179      organic mango peach carrot kickstart smoothie
# 2                                    peach mango juice
# 119                                pound cake cake mix
# 68                                 organic carrot cake
# 109  deluxe sauce made with milk cheese macaroni ch...
# 190            spongebob shapes macaroni cheese dinner
# 84                                   vegetable pot pie
# 297                 vegetable pie in a pocket sandwich
# 34                                  ground turkey chub
# 96                                              turkey
# 115  complete health deboned chicken chicken meal a...
# 196                chicken brown rice formula cat food
#
#                                         secondary_desc  cosine_sim  \
# 139                                  linguine no pasta    1.000000
# 318                                     linguine pasta    1.000000
# 279                             organic diced tomatoes    1.000000
# 127                             organic diced tomatoes    1.000000
# 229               organic hearty garden vegetable soup    0.960653
# 210                       vegetable hearty garden soup    0.960653
# 315                          green peas organic petite    0.952177
# 111                                  petite green peas    0.952177
# 80                               organic honey mustard    0.925062
# 262                                      honey mustard    0.925062
# 153                                         sloppy joe    0.899644
# 61                                    sloppy joe sauce    0.899644
# 234                                      chai tea bags    0.897238
# 93                    sweet chai of mine chai tea bags    0.897238
# 65             natural string cheese mozzarella cheese    0.881822
# 164                           string cheese mozzarella    0.881822
# 126                 pure cane granulated w spout sugar    0.859635
# 162                         pure granulated cane sugar    0.859635
# 33                                     tomatillo salsa    0.855581
# 177                                hot tomatillo salsa    0.855581
# 57                     kiwi strawberry sparkling water    0.841754
# 69          fruitwater strawberry kiwi sparkling water    0.841754
# 62                                       rescue remedy    0.838945
# 175                                rescue remedy spray    0.838945
# 323                      yogurt strawberry pomegranate    0.835270
# 43                              strawberry pomegranate    0.835270
# 9                      multigrain peanut butter cereal    0.827402
# 213                               peanut butter cereal    0.827402
# 317                         whole grain linguine pasta    0.813993
# 137                         whole grain linguine pasta    0.813993
# ..                                                 ...         ...
# 298                                sliced onion bagels    0.514153
# 264                   mini pre sliced blueberry bagels    0.514153
# 220                              whole wheat tortillas    0.513930
# 17           flax oat bran whole wheat flour tortillas    0.513930
# 89           ristorante pizza spinaci thin crust pizza    0.513324
# 117                    stuffed crust five cheese pizza    0.513324
# 44                             ice cream cookies cream    0.511626
# 141                   dark chocolate ice cream topping    0.511626
# 35                             lean fat ground turkey     0.510409
# 256                                 ground turkey chub    0.510409
# 182     gluten free all natural chocolate chip cookies    0.509880
# 52   cookie chips crunchy dark chocolate chocolate ...    0.509880
# 289                        chips onion chipotle garlic    0.508933
# 46                   chipotle roasted garlic seasoning    0.508933
# 276                               peanut butter cereal    0.508156
# 10                    peanut butter chocolate chip bar    0.508156
# 200                   peanut butter chocolate chip bar    0.507798
# 278                              banana chocolate chip    0.507798
# 179                                  peach mango juice    0.506483
# 2        organic mango peach carrot kickstart smoothie    0.506483
# 119                                organic carrot cake    0.506470
# 68                                 pound cake cake mix    0.506470
# 109            spongebob shapes macaroni cheese dinner    0.505675
# 190  deluxe sauce made with milk cheese macaroni ch...    0.505675
# 84                  vegetable pie in a pocket sandwich    0.503698
# 297                                  vegetable pot pie    0.503698
# 34                                              turkey    0.502489
# 96                                  ground turkey chub    0.502489
# 115                chicken brown rice formula cat food    0.501586
# 196  complete health deboned chicken chicken meal a...    0.501586
#
#      cosine_dist
# 139     0.000000
# 318     0.000000
# 279     0.000000
# 127     0.000000
# 229     0.039347
# 210     0.039347
# 315     0.047823
# 111     0.047823
# 80      0.074938
# 262     0.074938
# 153     0.100356
# 61      0.100356
# 234     0.102762
# 93      0.102762
# 65      0.118178
# 164     0.118178
# 126     0.140365
# 162     0.140365
# 33      0.144419
# 177     0.144419
# 57      0.158246
# 69      0.158246
# 62      0.161055
# 175     0.161055
# 323     0.164730
# 43      0.164730
# 9       0.172598
# 213     0.172598
# 317     0.186007
# 137     0.186007
# ..           ...
# 298     0.485847
# 264     0.485847
# 220     0.486070
# 17      0.486070
# 89      0.486676
# 117     0.486676
# 44      0.488374
# 141     0.488374
# 35      0.489591
# 256     0.489591
# 182     0.490120
# 52      0.490120
# 289     0.491067
# 46      0.491067
# 276     0.491844
# 10      0.491844
# 200     0.492202
# 278     0.492202
# 179     0.493517
# 2       0.493517
# 119     0.493530
# 68      0.493530
# 109     0.494325
# 190     0.494325
# 84      0.496302
# 297     0.496302
# 34      0.497511
# 96      0.497511
# 115     0.498414
# 196     0.498414
#
# [332 rows x 10 columns]
