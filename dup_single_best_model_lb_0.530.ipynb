# %%
import pandas as pd
import numpy as np

from math import sin, cos, sqrt, atan2, radians, degrees, fabs
import string as str
import re
from random import randint

from sklearn.feature_extraction.text import CountVectorizer
from sklearn import model_selection 
from sklearn.preprocessing import LabelEncoder
from sklearn.mixture import GaussianMixture


import xgboost as xgb
from nltk.stem import PorterStemmer

# %%
#reading data
train_df = pd.read_json("train.json")
test_df = pd.read_json("test.json")

#creating test_train and y_train
y_train = train_df.interest_level
test_df.interest_level = -1
train_test = pd.concat([train_df,test_df])

y_train_dummies = pd.get_dummies(y_train, prefix = 'interest')
emp_bayes = pd.read_csv('emp_bayes.csv').set_index(train_test.index)

# %%
features_to_use= []

#clipping outliers
train_test['bathrooms'] = train_test.bathrooms.clip_upper(5)
train_test['bedrooms'] = train_test.bedrooms.clip_upper(5)
train_test['price'] = train_test.price.clip_upper(20000)

features_to_use.extend(['bathrooms','bedrooms','price'])

# Composite features based on: 
# https://www.kaggle.com/arnaldcat/two-sigma-connect-rental-listing-inquiries/a-proxy-for-sqft-and-the-interest-on-1-2-baths

train_test['num_priceXroom'] = (train_test.price / (1 + train_test.bedrooms.clip(1, 4) + 0.5*train_test.bathrooms.clip(0, 2))).values
features_to_use.append('num_priceXroom')

# %%
#empirical bayes
train_test = pd.merge(train_test,emp_bayes, left_index=True, right_index=True)
features_to_use.extend(emp_bayes.columns)

# %%
# count of photos 
train_test["num_photos"] = train_test["photos"].apply(len)
features_to_use.append('num_photos')

# is bulding id present or not
train_test['building_id_present'] = train_test['building_id'].apply(lambda x: 0 if x == '0' else 1)
features_to_use.append('building_id_present')

# #stores which have listing higher than 7235000 always have low interest
train_test['bad_listing'] = train_test['listing_id'].apply(lambda x: 1 if x>7235000 else 0)
features_to_use.append('bad_listing')

# %%
#importing clean features
features_dup = pd.read_csv("feature_duplicate.csv")

#creating a dictinary of deduplicated features
features = train_test[["features"]].apply(lambda _: [list(map(str.strip, map(str.lower, x))) for x in _])
features_dict = features_dup.set_index('original_feature')['unique_feature'].to_dict()

def features_map_func(x):
    temp_list = []
    for i in x:
        if i in features_dict.keys():
            temp_list.append(features_dict[i])
    return temp_list

#cleaning up features
train_test['new_features'] = features.features.apply(lambda x : features_map_func(x))
train_test['new_features'] = train_test["new_features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))

#count vectorizing features
count_vec = CountVectorizer(stop_words='english', max_features=100)

train_test_count_vec_feat = pd.DataFrame(count_vec.fit_transform(train_test["new_features"]).todense(), columns = [s + '_feat' for s in count_vec.vocabulary_.keys()] ).set_index(train_test.index)
train_test = train_test.merge(train_test_count_vec_feat,how='left', left_index = True, right_index = True)

features_to_use.extend([s + '_feat' for s in count_vec.vocabulary_.keys()] )
# Out:
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:11: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal

# %%
#clustering neighbourhood

lat_long = train_test[train_test.longitude> -74.05][train_test.longitude< -73.875][train_test.latitude> 40.63][train_test.latitude< 40.87]
cluster = lat_long[['latitude','longitude']]

model_gm = GaussianMixture(n_components=40, covariance_type='full',tol = 0.01, max_iter=5000, random_state=7, verbose=0)
pred_gm = pd.DataFrame(model_gm.fit(cluster).predict(cluster)).set_index(cluster.index)
pred_gm.columns = ['pred_gm']


train_test = pd.merge(train_test, pred_gm, how = 'left', left_index=True, right_index=True)
train_test.pred_gm[train_test.pred_gm.isnull()] = -1

dummy_neighbourhood = pd.get_dummies(train_test.pred_gm, prefix = 'dummy_nb_')

train_test = train_test.merge(dummy_neighbourhood, how='left', left_index = True, right_index = True)

features_to_use.extend(dummy_neighbourhood.columns)
# Out:
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
### Calculate the distance of all latitude & longitude from the city center 

# approximate radius of earth in km
R = 6373.0

location_dict = {
'manhatten_loc' : [40.7527, -73.9943],
'brooklyn_loc' : [45.0761,-73.9442],
'bronx_loc' : [40.8448,-73.8648],
'queens_loc' : [40.7282,-73.7949],
'staten_loc' : [40.5795,-74.1502]}

for location in location_dict.keys():

    lat1 = train_test['latitude'].apply(radians)
    lon1 = train_test['longitude'].apply(radians)
    lat2 = radians(location_dict[location][0])
    lon2 = radians(location_dict[location][1])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    def power(x):
        return x**2

    a = (dlat/2).apply(sin).apply(power) + lat1.apply(cos) * cos(lat2) * (dlon/2).apply(sin).apply(power)
    c = 2 * a.apply(sqrt).apply(sin)

    ### Add a new column called distance
    train_test['distance_' + location] = R * c
    features_to_use.append('distance_' + location)
    
    x = lat1.apply(cos)*sin(lat2) - lat1.apply(sin) * cos(lat2) * (lon2 - lon1).apply(cos)
    y = (lon2 - lon1).apply(sin)* cos(lat2)

    ### Create a new colum as degrees
    train_test['degrees_' + location] = (np.arctan2(x,y)).apply(degrees).apply(fabs)

# %%
#unique buildings managers and addresses

def find_objects_with_only_one_record(feature_name):
    temp = train_test[feature_name].reset_index()
    temp = temp.groupby(feature_name, as_index = False).count()
    return temp[temp['index'] == 1]

managers_with_one_lot = find_objects_with_only_one_record('manager_id')
buildings_with_one_lot = find_objects_with_only_one_record('building_id')
addresses_with_one_lot = find_objects_with_only_one_record('display_address')

train_test['manager_id_unique'] = 0
train_test['building_id_unique'] = 0
train_test['display_address_unique'] = 0

train_test.loc[train_test['manager_id'].isin(managers_with_one_lot['manager_id'].ravel()), 'manager_id_unique'] = 1

train_test.loc[train_test['building_id'].isin(buildings_with_one_lot['building_id'].ravel()), 'building_id_unique'] = 1
train_test['building_id_unique'] =  train_test[['building_id','building_id_unique']].apply(lambda x : 1 if x[0] == '0' else x[1], axis=1)
train_test.loc[train_test['display_address'].isin(addresses_with_one_lot['display_address'].ravel()),'display_address_unique'] = 1
categorical = ['building_id_unique', 'manager_id_unique','display_address_unique']

features_to_use.extend(['building_id_unique', 'manager_id_unique','display_address_unique'])

# %%
# replacing ids by counts

categorical = ['building_id', 'manager_id','display_address']
                   
for f in categorical:
    encoder = LabelEncoder()
    encoder.fit(list(train_test[f])) 
    train_test[f] = encoder.transform(train_test[f].ravel())
    
temp = train_test.manager_id.value_counts()
train_test['manager_id_count'] = train_test.manager_id.apply(lambda x: temp[x])

temp = train_test.building_id.value_counts()
train_test['building_id_count'] = train_test.building_id.apply(lambda x: temp[x])

temp = train_test.display_address.value_counts()
train_test['display_address_count'] = train_test.display_address.apply(lambda x: temp[x])


train_test.building_id_count = train_test[['building_id_count', 'building_id_unique']].apply(lambda x : 1 if x[1] == 1 else x[0], axis=1)
train_test.manager_id_count = train_test[['manager_id_count', 'manager_id_unique']].apply(lambda x : 1 if x[1] == 1 else x[0], axis=1)
train_test.display_address_count = train_test[['display_address_count', 'display_address_unique']].apply(lambda x : 1 if x[1] == 1 else x[0], axis=1)

features_to_use.extend(['manager_id_count','building_id_count','display_address_count'])

# %%
features_to_use.extend(['latitude','longitude','listing_id'])

# %%
#median price grouped by managers and neighbourhoods and bedrooms

train_test['median_price_groupby_manager'] = train_test.groupby(['manager_id','bedrooms'])['price'].transform('median') 
features_to_use.append('median_price_groupby_manager')

train_test['median_price_groupby_neighbourhood'] = train_test.groupby(['pred_gm','bedrooms'])['price'].transform('median') - train_test.price
features_to_use.append('median_price_groupby_neighbourhood')

# %%
# extract  features like month, day, hour from date columns and categorizing them, year not taken as every obs is from 2016
train_test["created"] = pd.to_datetime(train_test["created"])

train_test['month'] =train_test["created"].dt.month
train_test['day_of_week'] =train_test["created"].dt.weekday
train_test['day_of_month'] =train_test["created"].dt.day
train_test['hour_of_day'] =train_test["created"].dt.hour

features_to_use.extend(['month','day_of_week','day_of_month','hour_of_day'])

# %%
import random

train_df = train_test.ix[train_df.index]
test_df = train_test.ix[test_df.index]

index=list(range(train_df.shape[0]))
random.shuffle(index)
a=[np.nan]*len(train_df)
b=[np.nan]*len(train_df)
c=[np.nan]*len(train_df)

for i in range(5):
    building_level={}
    for j in train_df['manager_id'].values:
        building_level[j]=[0,0,0]
    test_index=index[int((i*train_df.shape[0])/5):int(((i+1)*train_df.shape[0])/5)]
    train_index=list(set(index).difference(test_index))
    for j in train_index:
        temp=train_df.iloc[j]
        if temp['interest_level']=='low':
            building_level[temp['manager_id']][0]+=1
        if temp['interest_level']=='medium':
            building_level[temp['manager_id']][1]+=1
        if temp['interest_level']=='high':
            building_level[temp['manager_id']][2]+=1
    for j in test_index:
        temp=train_df.iloc[j]
        if sum(building_level[temp['manager_id']])!=0:
            a[j]=building_level[temp['manager_id']][0]*1.0/sum(building_level[temp['manager_id']])
            b[j]=building_level[temp['manager_id']][1]*1.0/sum(building_level[temp['manager_id']])
            c[j]=building_level[temp['manager_id']][2]*1.0/sum(building_level[temp['manager_id']])
train_df['manager_level_low']=a
train_df['manager_level_medium']=b
train_df['manager_level_high']=c



a=[]
b=[]
c=[]
building_level={}
for j in train_df['manager_id'].values:
    building_level[j]=[0,0,0]
for j in range(train_df.shape[0]):
    temp=train_df.iloc[j]
    if temp['interest_level']=='low':
        building_level[temp['manager_id']][0]+=1
    if temp['interest_level']=='medium':
        building_level[temp['manager_id']][1]+=1
    if temp['interest_level']=='high':
        building_level[temp['manager_id']][2]+=1

for i in test_df['manager_id'].values:
    if i not in building_level.keys():
        a.append(np.nan)
        b.append(np.nan)
        c.append(np.nan)
    else:
        a.append(building_level[i][0]*1.0/sum(building_level[i]))
        b.append(building_level[i][1]*1.0/sum(building_level[i]))
        c.append(building_level[i][2]*1.0/sum(building_level[i]))
test_df['manager_level_low']=a
test_df['manager_level_medium']=b
test_df['manager_level_high']=c

features_to_use.append('manager_level_low') 
features_to_use.append('manager_level_medium') 
features_to_use.append('manager_level_high')

# %%
train_test = pd.concat([train_df,test_df])

# %%
# features_to_model = forest_features
features_to_model = features_to_use

# %%
target_num_map = {'high':0, 'medium':1, 'low':2}
y_train = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))

new_feature = pd.read_csv('listing_image_time.csv')

new_feature['listing_id'] = new_feature['Listing_Id']

new_feature.ix[train_df.index]

all_data =  pd.merge(train_test, new_feature, on='listing_id', how='left')

features_to_use.append('time_stamp')

features_to_model = features_to_use

all_data.set_index(train_test.index, inplace = True)

X_train = all_data.ix[train_df.index][features_to_model]
X_test = all_data.ix[test_df.index][features_to_model]

# %%
X_train.head()
# Out:
#         bathrooms  bedrooms  price  num_priceXroom  building_id_mean_medium  \
# 10            1.5         3   3000      631.578947                 0.217575
# 10000         1.0         2   5465     1561.428571                 0.110642
# 100004        1.0         1   2850     1140.000000                 0.467347
# 100007        1.0         1   3275     1310.000000                 0.094998
# 100013        1.0         4   3350      609.090909                 0.058909
#
#         building_id_mean_high  manager_id_mean_medium  manager_id_mean_high  \
# 10               7.436940e-02                0.283585          9.190504e-29
# 10000            1.761506e-07                0.012447          2.088626e-34
# 100004           9.291841e-02                0.357575          3.169581e-02
# 100007           1.187783e-02                0.152256          8.444808e-02
# 100013           2.270975e-02                0.000564          1.922140e-04
#
#         num_photos  building_id_present     ...      \
# 10               5                    1     ...
# 10000           11                    1     ...
# 100004           8                    1     ...
# 100007           3                    1     ...
# 100013           3                    0     ...
#
#         median_price_groupby_manager  median_price_groupby_neighbourhood  \
# 10                            2800.0                               300.0
# 10000                         5445.0                             -1290.0
# 100004                        2862.5                               775.0
# 100007                        3195.0                              -200.0
# 100013                        5000.0                               440.0
#
#         month  day_of_week  day_of_month  hour_of_day  manager_level_low  \
# 10          6            4            24            7           0.753425
# 10000       6            6            12           12           0.985915
# 100004      4            6            17            3           0.596154
# 100007      4            0            18            2           0.804054
# 100013      4            3            28            1           1.000000
#
#         manager_level_medium  manager_level_high  time_stamp
# 10                  0.246575            0.000000  1478091590
# 10000               0.014085            0.000000  1478129766
# 100004              0.375000            0.028846  1478714436
# 100007              0.135135            0.060811  1478714444
# 100013              0.000000            0.000000  1478714464
#
# [5 rows x 176 columns]

# %%
features_to_use
# Out:
# ['bathrooms',
#  'bedrooms',
#  'price',
#  'num_priceXroom',
#  'building_id_mean_medium',
#  'building_id_mean_high',
#  'manager_id_mean_medium',
#  'manager_id_mean_high',
#  'num_photos',
#  'building_id_present',
#  'bad_listing',
#  u'exclusive_feat',
#  u'outdoor_feat',
#  u'furnished_feat',
#  u'walk_in_closet_feat',
#  u'ft_doorman_feat',
#  u'terrace_feat',
#  u'newly_renovated_feat',
#  u'duplex_feat',
#  u'dryer_in_unit_feat',
#  u'green_building_feat',
#  u'private_backyard_feat',
#  u'multi_level_feat',
#  u'garden_feat',
#  u'rise_feat',
#  u'park_view_feat',
#  u'fireplace_feat',
#  u'eat_in_kitchen_feat',
#  u'dish_washer_feat',
#  u'granite_counter_tops_feat',
#  u'stainless_steel_feat',
#  u'site_laundry_feat',
#  u'garage_feat',
#  u'common_feat',
#  u'fitness_feat',
#  u'dining_room_feat',
#  u'view_feat',
#  u'hardwood_feat',
#  u'fitness_center_feat',
#  u'space_feat',
#  u'microwave_feat',
#  u'valet_feat',
#  u'pets_feat',
#  u'short_term_allowed_feat',
#  u'new_construction_feat',
#  u'_photos_feat',
#  u'reduced_fee_feat',
#  u'common_parking_feat',
#  u'wi_feat',
#  u'courtyard_feat',
#  u'simplex_feat',
#  u'air_conditioning_feat',
#  u'sauna_feat',
#  u'renovated_feat',
#  u'cats_allowed_feat',
#  u'exposed_brick_feat',
#  u'24_hour_concierge_feat',
#  u'site_parking_feat',
#  u'outdoor_areas_feat',
#  u'common_roof_deck_feat',
#  u'no_pets_feat',
#  u'share_ok_feat',
#  u'live_in_super_feat',
#  u'bicycle_room_feat',
#  u'publicoutdoor_feat',
#  u'wheelchair_access_feat',
#  u'post_war_feat',
#  u'light_feat',
#  u'elevator_feat',
#  u'low_feat',
#  u'outdoor_entertainment_space_feat',
#  u'fi_access_feat',
#  u'health_club_feat',
#  u'loft_feat',
#  u'site_garage_feat',
#  u'gym_feat',
#  u'residents_garden_feat',
#  u'outdoor_space_feat',
#  u'pre_war_feat',
#  u'decorative_fireplace_feat',
#  u'site_super_feat',
#  u'marble_bath_feat',
#  u'washer__feat',
#  u'roof_feat',
#  u'virtual_doorman_feat',
#  u'private_outdoor_space_feat',
#  u'high_ceiling_feat',
#  u'concierge_feat',
#  u's_playroom_feat',
#  u'doorman_feat',
#  u'full_service_garage_feat',
#  u'balcony_feat',
#  u'dogs_allowed_feat',
#  u'indoor_pool_feat',
#  u'storage_feat',
#  u'_dryer_feat',
#  u'lounge_feat',
#  u'brownstone_feat',
#  u'central_a_feat',
#  u'laundry_feat',
#  u'luxury_building_feat',
#  u'pool_feat',
#  u'building_feat',
#  u'children_feat',
#  u'common_outdoor_space_feat',
#  u'swimming_pool_feat',
#  u'sublet_feat',
#  u'actual_apt_feat',
#  u'no_fee_feat',
#  u'patio_feat',
#  u'subway_feat',
#  'dummy_nb__-1.0',
#  'dummy_nb__0.0',
#  'dummy_nb__1.0',
#  'dummy_nb__2.0',
#  'dummy_nb__3.0',
#  'dummy_nb__4.0',
#  'dummy_nb__5.0',
#  'dummy_nb__6.0',
#  'dummy_nb__7.0',
#  'dummy_nb__8.0',
#  'dummy_nb__9.0',
#  'dummy_nb__10.0',
#  'dummy_nb__11.0',
#  'dummy_nb__12.0',
#  'dummy_nb__13.0',
#  'dummy_nb__14.0',
#  'dummy_nb__15.0',
#  'dummy_nb__16.0',
#  'dummy_nb__17.0',
#  'dummy_nb__18.0',
#  'dummy_nb__19.0',
#  'dummy_nb__20.0',
#  'dummy_nb__21.0',
#  'dummy_nb__22.0',
#  'dummy_nb__23.0',
#  'dummy_nb__24.0',
#  'dummy_nb__25.0',
#  'dummy_nb__26.0',
#  'dummy_nb__27.0',
#  'dummy_nb__28.0',
#  'dummy_nb__29.0',
#  'dummy_nb__30.0',
#  'dummy_nb__31.0',
#  'dummy_nb__32.0',
#  'dummy_nb__33.0',
#  'dummy_nb__34.0',
#  'dummy_nb__35.0',
#  'dummy_nb__36.0',
#  'dummy_nb__37.0',
#  'dummy_nb__38.0',
#  'dummy_nb__39.0',
#  'distance_brooklyn_loc',
#  'distance_manhatten_loc',
#  'distance_bronx_loc',
#  'distance_queens_loc',
#  'distance_staten_loc',
#  'building_id_unique',
#  'manager_id_unique',
#  'display_address_unique',
#  'manager_id_count',
#  'building_id_count',
#  'display_address_count',
#  'latitude',
#  'longitude',
#  'listing_id',
#  'median_price_groupby_manager',
#  'median_price_groupby_neighbourhood',
#  'month',
#  'day_of_week',
#  'day_of_month',
#  'hour_of_day',
#  'manager_level_low',
#  'manager_level_medium',
#  'manager_level_high',
#  'time_stamp']

# %%
# XGBoost
X_dev, X_val, y_dev, y_val = model_selection.train_test_split(X_train, y_train, test_size=0.2, random_state=3 )

# %%
param = {}
param['objective'] = 'multi:softprob'
param['eta'] = .02
param['gamma'] = 0.8
param['max_depth'] = 8
param['silent'] = 1
param['num_class'] = 3
param['eval_metric'] = "mlogloss"
param['reg_alpha'] = 2.0
param['min_child_weight'] = 15
param['subsample'] = 0.99
param['colsample_bytree'] = 0.45
param['seed'] = 3
param['nthread'] = 4
param['n_jobs'] = -1
num_rounds = 5000

# %%
plst = list(param.items())

xgtrain = xgb.DMatrix(X_dev, label=y_dev)
xgtest = xgb.DMatrix(X_val, label=y_val)
watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval = 100)
#0.514 with eta 0.02 max_depth 4 min_child 1 lb 0.53 rounds 3700
#current benchmark with eta 0.5 = 0.5152
# test-mlogloss:0.513764
# train-mlogloss:0.422563	test-mlogloss:0.5131
# train-mlogloss:0.402687	test-mlogloss:0.512209
# train-mlogloss:0.365848	test-mlogloss:0.511613
# train-mlogloss:0.360063	test-mlogloss:0.511188
# train-mlogloss:0.315602	test-mlogloss:0.51029
# Out:
# [0]	train-mlogloss:1.08457	test-mlogloss:1.08487
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 50 rounds.
# [100]	train-mlogloss:0.586085	test-mlogloss:0.614344
# [200]	train-mlogloss:0.502683	test-mlogloss:0.551517
# [300]	train-mlogloss:0.466779	test-mlogloss:0.533091
# [400]	train-mlogloss:0.441403	test-mlogloss:0.525008
# [500]	train-mlogloss:0.421592	test-mlogloss:0.520142
# [600]	train-mlogloss:0.403526	test-mlogloss:0.517117
# [700]	train-mlogloss:0.388421	test-mlogloss:0.515364
# [800]	train-mlogloss:0.374782	test-mlogloss:0.513834
# [900]	train-mlogloss:0.36222	test-mlogloss:0.512846
# [1000]	train-mlogloss:0.351079	test-mlogloss:0.512033
# [1100]	train-mlogloss:0.340178	test-mlogloss:0.51133
# [1200]	train-mlogloss:0.330718	test-mlogloss:0.510794
# [1300]	train-mlogloss:0.321947	test-mlogloss:0.510422
# [1400]	train-mlogloss:0.31362	test-mlogloss:0.510337
# Stopping. Best iteration:
# [1377]	train-mlogloss:0.315602	test-mlogloss:0.51029

# %%
num_rounds = 1380
xgtrain = xgb.DMatrix(X_train, label=y_train)
watchlist = [ (xgtrain,'train') ]
model = xgb.train(plst, xgtrain, num_rounds, watchlist,verbose_eval = 100)
# Out:
# [0]	train-mlogloss:1.08468
# [100]	train-mlogloss:0.587473
# [200]	train-mlogloss:0.505938
# [300]	train-mlogloss:0.47181
# [400]	train-mlogloss:0.448499
# [500]	train-mlogloss:0.429687
# [600]	train-mlogloss:0.413446
# [700]	train-mlogloss:0.399326
# [800]	train-mlogloss:0.386669
# [900]	train-mlogloss:0.375433
# [1000]	train-mlogloss:0.364755
# [1100]	train-mlogloss:0.354768
# [1200]	train-mlogloss:0.345388
# [1300]	train-mlogloss:0.336314
# [1379]	train-mlogloss:0.329919

# %%
# xgboost submission
forest_xgb = model.predict(xgb.DMatrix(X_test))
submission = pd.DataFrame(forest_xgb, columns = ['high','medium','low']).set_index(test_df.index)
submission['listing_id'] = test_df.listing_id.values
submission.to_csv('model_9_xgb_reg2_mc15_eta0.02_1380_ss0.99.csv', index= False)

# %%
param = {}
param['objective'] = 'multi:softprob'
param['eta'] = .02
param['gamma'] = 0.8
param['max_depth'] = 6
param['silent'] = 1
param['num_class'] = 3
param['eval_metric'] = "mlogloss"
param['reg_alpha'] = 2
param['min_child_weight'] = 10
param['subsample'] = 0.99
param['colsample_bytree'] = 0.5
param['seed'] = 3
param['nthread'] = 4
param['n_jobs'] = -1
num_rounds = 5000

# param = {}
# param['objective'] = 'multi:softprob'
# param['eta'] = .02
# param['gamma'] = 0.8
# param['max_depth'] = 8
# param['silent'] = 1
# param['num_class'] = 3
# param['eval_metric'] = "mlogloss"
# param['reg_alpha'] = 2.0
# param['min_child_weight'] = 15
# param['subsample'] = 0.99
# param['colsample_bytree'] = 0.45
# param['seed'] = 3
# param['nthread'] = 4
# param['n_jobs'] = -1
# num_rounds = 5000

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# x_train = np.array(X_train)
# x_test = np.array(X_test)

X_train = X_train.replace([np.inf, -np.inf], np.nan)
X_train = X_train.fillna(0)

X_test = X_test.replace([np.inf, -np.inf], np.nan)
X_test = X_test.fillna(0)

x_train = scaler.fit_transform(X_train)
x_test = scaler.transform(X_test)

print x_train.shape
print x_test.shape
# Out:
# (49352, 176)
# (74659, 176)

# %%
tsne_train = np.loadtxt("stnet/tr_tsne.csv", delimiter=",")
tsne_test = np.loadtxt("stnet/test_tsne.csv", delimiter=",")

# print x_train.shape
# print x_test.shape

x_train = np.column_stack((x_train,tsne_train))
x_test = np.column_stack((x_test,tsne_test))

print x_train.shape
print x_test.shape
# Out:
# (49352, 186)
# (74659, 186)

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=4000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = .05
    param['gamma'] = 0.0
    param['max_depth'] = 7
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['reg_alpha'] = 2.0
    param['reg_lambda'] = 1.0
    param['min_child_weight'] = 10
    param['subsample'] = 0.99
    param['colsample_bytree'] = 0.55
    param['seed'] = 3
#     param['nthread'] = 4
    param['n_jobs'] = -1
#     num_rounds = 5000

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=50, verbose_eval = 1000)
    else:
        xgtest = xgb.DMatrix(test_X)
        watchlist = [ (xgtrain,'train') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, verbose_eval = 100)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
from sklearn import model_selection
from sklearn.metrics import log_loss
from sklearn.model_selection import KFold

# x_train = np.array(X_train)
# x_test = np.array(X_test)

train_stacker=[ [0.0 for s in range(3)]  for k in range (0,(x_train.shape[0])) ]
test_stacker=[[0.0 for s in range(3)]   for k in range (0,(x_test.shape[0]))]
X = np.array(X_train)
cv_scores = []
oof_preds = []
# StratifiedKFold
# kf = model_selection.StratifiedKFold(n_splits=10, shuffle=True, random_state=2016)
# for dev_index, val_index in kf.split(range(x_train.shape[0]),y_train):
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(x_train.shape[0])):
        dev_X, val_X = x_train[dev_index,:], x_train[val_index,:]
        dev_y, val_y = y_train[dev_index], y_train[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y)
        cv_scores.append(log_loss(val_y, preds))
#         oof_preds.append(preds)
#         predictions = bst.predict(X1cv)     
#         predictions = preds.reshape( val_X.shape[0], 3)
        print(cv_scores)
        break
#         no=0
#         for real_index in val_index:
#             for d in range (0,3):
#                 train_stacker[real_index][d]=(predictions[no][d])
#             no+=1
#         X = np.column_stack((X,train_stacker))

# [2049]	train-mlogloss:0.354939	test-mlogloss:0.515924  
# Stopping. Best iteration:
# [3543]	train-mlogloss:0.396121	test-mlogloss:0.512792


# [0.5162835560663217]
# [0.51378179879688479]
#[0.51489777736957554]
# [0.51494246542330147]

# [0.51531373368992195]
# Out:
# [0]	train-mlogloss:1.06307	test-mlogloss:1.06431
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [432]	train-mlogloss:0.325519	test-mlogloss:0.520164
#
# [0.5203930115408385]

# %%
from sklearn import model_selection
from sklearn.metrics import log_loss
from sklearn.model_selection import KFold

# x_train = np.array(X_train)
# x_test = np.array(X_test)
train_stacker=[ [0.0 for s in range(3)]  for k in range (0,(x_train.shape[0])) ]
test_stacker=[[0.0 for s in range(3)]   for k in range (0,(x_test.shape[0]))]
X = np.array(X_train)
cv_scores = []
oof_preds = []
# StratifiedKFold
# kf = model_selection.StratifiedKFold(n_splits=10, shuffle=True, random_state=2016)
# for dev_index, val_index in kf.split(range(x_train.shape[0]),y_train):
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(x_train.shape[0])):
        dev_X, val_X = x_train[dev_index,:], x_train[val_index,:]
        dev_y, val_y = y_train[dev_index], y_train[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y)
        cv_scores.append(log_loss(val_y, preds))
#         oof_preds.append(preds)
#         predictions = bst.predict(X1cv)     
        predictions = preds.reshape( val_X.shape[0], 3)
        print(cv_scores)
        no=0
        for real_index in val_index:
            for d in range (0,3):
                train_stacker[real_index][d]=(predictions[no][d])
            no+=1
#         X = np.column_stack((X,train_stacker))

# [2049]	train-mlogloss:0.354939	test-mlogloss:0.515924  
# Stopping. Best iteration:
# [3543]	train-mlogloss:0.396121	test-mlogloss:0.512792

# [0.51282974902487233]
# Out:
# [0]	train-mlogloss:1.06307	test-mlogloss:1.06431
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [432]	train-mlogloss:0.325519	test-mlogloss:0.520164
#
# [0.5203930115408385]
# [0]	train-mlogloss:1.06313	test-mlogloss:1.06427
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [539]	train-mlogloss:0.297417	test-mlogloss:0.515194
#
# [0.5203930115408385, 0.51537463923821591]
# [0]	train-mlogloss:1.06331	test-mlogloss:1.06444
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [411]	train-mlogloss:0.333228	test-mlogloss:0.521438
#
# [0.5203930115408385, 0.51537463923821591, 0.52156811150757121]
# [0]	train-mlogloss:1.06336	test-mlogloss:1.06445
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [477]	train-mlogloss:0.313777	test-mlogloss:0.512757
#
# [0.5203930115408385, 0.51537463923821591, 0.52156811150757121, 0.51305169469248524]
# [0]	train-mlogloss:1.06337	test-mlogloss:1.06407
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [521]	train-mlogloss:0.305219	test-mlogloss:0.50826
#
# [0.5203930115408385, 0.51537463923821591, 0.52156811150757121, 0.51305169469248524, 0.5083535321832473]

# %%
train_stacker

np.savetxt("stnet/train_stacker_xgb_tsne.csv", train_stacker, delimiter=",", fmt='%.6f')

# %%
np.savetxt("stnet/train_data.csv", x_train, delimiter=",", fmt='%.6f')
np.savetxt("stnet/test_data.csv", x_test, delimiter=",", fmt='%.6f')

# %%
# t_file = pd.read_csv('model_xgb_6_md6_reg2_mc10_eta0.02_1850.csv')

# t_file.head()

# test_stacker = np.array(t_file)

np.savetxt("stnet/test_stacker_xgb_1.csv", test_stacker[:,0:3], delimiter=",", fmt='%.6f')

# %%
# X_train.head()

# train_ts = np.array(X_train)

# train_ts[:,175:176]

# test_ts = np.array(X_test)

# np.savetxt("stnet/train_nf.csv", train_ts[:,175:176], delimiter=",", fmt='%.6f')
# np.savetxt("stnet/test_nf.csv", test_ts[:,175:176], delimiter=",", fmt='%.6f')

F = np.loadtxt("stnet/train_nf.csv", delimiter=",")
F_ts = np.loadtxt("stnet/test_nf.csv", delimiter=",")

print F.shape
print F_ts.shape
# Out:
# (49352,)
# (74659,)

# %%
preds, model = runXGB(X_train, y_train, X_test, num_rounds=432)
np.savetxt("stnet/test_stacker_xgb_tsne.csv",preds, delimiter=",", fmt='%.6f')

out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("model_xgb_tsne.csv", index=False)

# forest_xgb = model.predict(xgb.DMatrix(X_test))
# submission = pd.DataFrame(preds, columns = ['high','medium','low']).set_index(test_df.index)
# submission['listing_id'] = test_df.listing_id.values
# submission.to_csv('model_10_xgb_reg2_mc10_eta0.02_2050.csv', index= False)
# Out:
# [0]	train-mlogloss:1.06301
# [100]	train-mlogloss:0.488474
# [200]	train-mlogloss:0.435992
# [300]	train-mlogloss:0.400098
# [400]	train-mlogloss:0.371235
# [431]	train-mlogloss:0.363607

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# x_train = np.array(X_train)
# x_test = np.array(X_test)

X_train = X_train.replace([np.inf, -np.inf], np.nan)
X_train = X_train.fillna(0)

X_test = X_test.replace([np.inf, -np.inf], np.nan)
X_test = X_test.fillna(0)

x_train = scaler.fit_transform(X_train)
x_test = scaler.transform(X_test)

print x_train.shape
print x_test.shape
# Out:
# (49352, 175)
# (74659, 175)

# %%
# X_ts = np.array(X_test)

X_ts = np.column_stack((X_ts,F_ts[:,176:179]))

# X_ts.shape

X = np.column_stack((np.array(y_train),X,train_stacker))

X_ts = np.column_stack((np.array(X_test['listing_id']),X_ts))
                       
print X.shape
print X_ts.shape
# Out:
# (49352, 179)
# (74659, 179)

# %%
train_file="stnet/train6.csv"
test_file="stnet/test6.csv"


print ("exporting files")
np.savetxt(train_file, X, delimiter=",", fmt='%.5f')
np.savetxt(test_file, X_ts, delimiter=",", fmt='%.5f')
# Out:
# exporting files

# %%
# java -Xmx4048m -jar StackNet.jar train train_file=train5.csv test_file=test5.csv params=paramssimplev1.txt pred_fil
# e=sigma_stack_pred_8.csv test_target=true verbose=true Threads=6 stackdata=false folds=5 seed=1 metric=logloss
x_train
# Out:
# array([[  1.50000000e+00,   3.00000000e+00,   3.00000000e+03, ...,
#           7.71428571e-01,   2.28571429e-01,   0.00000000e+00],
#        [  1.00000000e+00,   2.00000000e+00,   5.46500000e+03, ...,
#           9.82758621e-01,   1.72413793e-02,   0.00000000e+00],
#        [  1.00000000e+00,   1.00000000e+00,   2.85000000e+03, ...,
#           5.92592593e-01,   3.42592593e-01,   6.48148148e-02],
#        ...,
#        [  1.00000000e+00,   1.00000000e+00,   2.59500000e+03, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   0.00000000e+00,   3.35000000e+03, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   2.00000000e+00,   2.20000000e+03, ...,
#           9.33333333e-01,   6.66666667e-02,   0.00000000e+00]])

# %%
# F_ts = np.loadtxt("stnet/test5.csv", delimiter=",")
# F = np.loadtxt("stacknet/train_stacknet.csv", delimiter=",")
# F_test = np.loadtxt("stacknet/test_stacknet.csv", delimiter=",")

# load results of one (or more) of your models - here also 
# out-of-fold predictions for the train set are needed
# pred_test = np.loadtxt("meta_predictions/preds_test.txt")
# pred_train = np.loadtxt("meta_predictions/preds_train.txt")
# F_ts[:,176:179]
# # # combine them with the StackNet input
# F_test = np.column_stack((F_test, F_ts[:,176:179]))
# F = np.column_stack((F, train_stacker))
# print F.shape
# print F_test.shape
# save into new files to be fed into StackNet

# np.savetxt("stacknet/train_stacknet_with_meta.csv", F, delimiter=",", fmt='%.6f')
# np.savetxt("stacknet/test_stacknet_with_meta.csv", F_test, delimiter=",", fmt='%.6f')

# F = np.loadtxt("stacknet/train_stacknet_with_meta.csv", delimiter=",")
# F_ts = np.loadtxt("stacknet/test_stacknet_with_meta.csv", delimiter=",")

# G = scaler.fit_transform(X_train)
# G_ts = scaler.transform(X_test)

# F = np.column_stack((F, G))
# F_ts = np.column_stack((F_ts,G_ts))

# print F.shape
# print F_ts.shape

F = np.loadtxt("stnet/train_with_add_data.csv", delimiter=",")
F_ts = np.loadtxt("stnet/test_with_add_data.csv", delimiter=",")

F = np.column_stack((F, train_stacker))
F_ts = np.column_stack((F_ts, preds_better[:,0:3]))

np.savetxt("stnet/train_with_add_data_0.529.csv", F, delimiter=",", fmt='%.6f')
np.savetxt("stnet/test_with_add_data_0.529.csv", F_ts, delimiter=",", fmt='%.6f')

# %%
# np.savetxt("stnet/train_stacker_0.5291.csv", train_stacker, delimiter=",", fmt='%.6f')
# preds_new = pd.read_csv('model_15_xgb_md8_reg2_mc10_eta0.02_1460.csv')

# preds_better = np.array(preds_new)

np.savetxt("stnet/test_stacker_0.5291.csv", preds_better[:,0:3], delimiter=",", fmt='%.6f')

# %%
X = np.loadtxt("stnet/train_with_add_data_0.529.csv", delimiter=",")
X_ts = np.loadtxt("stnet/test_with_add_data_0.529.csv", delimiter=",")

X_nn = np.loadtxt("stnet/train_stacker_reg_nn.csv", delimiter=",")
X_ts_nn = np.loadtxt("stnet/test_stacker_reg_nn.csv", delimiter=",")

X_rf = np.loadtxt("stnet/train_stacker_rf.csv",  delimiter=",")
X_ts_rf = np.loadtxt("stnet/test_stacker_rf.csv", delimiter=",")

X_lgr = np.loadtxt("stnet/train_stacker_lgr.csv", delimiter=",")
X_ts_lgr = np.loadtxt("stnet/test_stacker_lgr.csv", delimiter=",")

F = np.column_stack((X, X_nn, X_rf, X_lgr))
F_ts = np.column_stack((X_ts, X_ts_nn, X_ts_rf, X_ts_lgr))

np.savetxt("stnet/train_meta_xgb3_rf_nn_lgr.csv", F, delimiter=",", fmt='%.6f')
np.savetxt("stnet/test_meta_xgb3_rf_nn_lgr.csv", F_ts, delimiter=",", fmt='%.6f')

# %%
G = np.loadtxt("stnet/train_meta_xgb3_rf_nn_lgr.csv", delimiter=",")
G_ts = np.loadtxt("stnet/test_meta_xgb3_rf_nn_lgr.csv", delimiter=",")

lgrtf = np.loadtxt("stnet/train_stacker_lgr_tf.csv", delimiter=",")
lgrtf_ts = np.loadtxt("stnet/test_stacker_lgr_tf.csv", delimiter=",")

m = np.column_stack((G,lgrtf))
m_ts = np.column_stack((G_ts,lgrtf_ts))

np.savetxt("stnet/train_add_3xgb_nn_rf_2lr.csv", m, delimiter=",", fmt='%.6f')
np.savetxt("stnet/test_add_3xgb_nn_rf_2lr.csv", m_ts, delimiter=",", fmt='%.6f')

# %%
G = np.loadtxt("new_st/train_add_3xgb_nn_rf_2lr_7.csv", delimiter=",")
G_ts = np.loadtxt("new_st/test_add_3xgb_nn_rf_2lr_7.csv", delimiter=",")

# gbm = np.loadtxt("stnet/train_stacker_gbm.csv", delimiter=",")
# gbm_ts = np.loadtxt("stnet/test_stacker_gbm.csv", delimiter=",")

# knn = np.loadtxt("stnet/train_stacker_knn.csv", delimiter=",")
# knn_ts = np.loadtxt("stnet/test_stacker_knn.csv", delimiter=",")

# sgd = np.loadtxt("stnet/train_stacker_sgd.csv", delimiter=",")
# sgd_ts = np.loadtxt("stnet/test_stacker_sgd.csv", delimiter=",")

# sgdtf = np.loadtxt("stnet/train_stacker_sgd_tf.csv", delimiter=",")
# sgdtf_ts = np.loadtxt("stnet/test_stacker_sgd_tf.csv", delimiter=",")

# lda = np.loadtxt("stnet/train_stacker_lda.csv", delimiter=",")
# lda_ts = np.loadtxt("stnet/test_stacker_lda.csv", delimiter=",")

# knn_meta = np.loadtxt("stnet/train_stacker_knn_meta_1k.csv", delimiter=",")
# knn_meta_ts = np.loadtxt("stnet/test_stacker_knn_meta_1k.csv", delimiter=",")

# et = np.loadtxt("stnet/train_stacker_et_meta_md10.csv", delimiter=",")
# et_ts = np.loadtxt("stnet/test_stacker_et_meta_md10.csv", delimiter=",")

knn_meta1 = np.loadtxt("stnet/train_stacker_knn_meta_0.5k.csv", delimiter=",")
knn_meta1_ts = np.loadtxt("stnet/test_stacker_knn_meta_0.5k.csv", delimiter=",")

knn_meta2 = np.loadtxt("stnet/train_stacker_knn_meta_0.25k.csv", delimiter=",")
knn_meta2_ts = np.loadtxt("stnet/test_stacker_knn_meta_0.25k.csv", delimiter=",")

et1 = np.loadtxt("stnet/train_stacker_et_meta_md5.csv", delimiter=",")
et1_ts = np.loadtxt("stnet/test_stacker_et_meta_md5.csv", delimiter=",")

et2 = np.loadtxt("stnet/train_stacker_et_meta_md3.csv", delimiter=",")
et2_ts = np.loadtxt("stnet/test_stacker_et_meta_md3.csv", delimiter=",")


m = np.column_stack((G,knn_meta1,et1,knn_meta2,et2))
m_ts = np.column_stack((G_ts,knn_meta1_ts,et1_ts,knn_meta2_ts,et2_ts))

print m.shape
print m_ts.shape

# np.savetxt("stnet/train_add_3xgb_nn_rf_2lr_5.csv", m, delimiter=",", fmt='%.6f')
# np.savetxt("stnet/test_add_3xgb_nn_rf_2lr_5.csv", m_ts, delimiter=",", fmt='%.6f')

np.savetxt("new_st/train_add_3xgb_nn_rf_2lr_11.csv", m, delimiter=",", fmt='%.6f')
np.savetxt("new_st/test_add_3xgb_nn_rf_2lr_11.csv", m_ts, delimiter=",", fmt='%.6f')
# Out:
# (49352, 462)
# (74659, 462)

# %%
np.savetxt("stacknet/train_add_3xgb_nn_rf_2lr_5.csv", m, delimiter=",", fmt='%.6f')
np.savetxt("stacknet/test_add_3xgb_nn_rf_2lr_5.csv", m_ts, delimiter=",", fmt='%.6f')

# %%
print m.shape
print m_ts.shape
# java -Xmx6048m -jar StackNet.jar train train_file=train_nf1.csv test_file=test_nf1.csv params=paramssimplev1.txt pred_file=sigma_stack_pred_nf1.csv test_target=true verbose=true Threads=9 stackdata=true folds=5 seed=1 metric=logloss
# Out:
# (49352, 444)
# (74659, 444)

# %%
# pd.DataFrame(m[:,414:445]).head()
# pd.DataFrame(m[:,233:239]).head()

# df_ts = np.column_stack((m_ts[:,233:239],m_ts[:,414:445]))

# print df.shape
# print df_ts.shape

np.savetxt("stnet/meta_dftrain.csv", df, delimiter=",", fmt='%.6f')
np.savetxt("stnet/meta_dftest.csv", df_ts, delimiter=",", fmt='%.6f')


# d_train = np.loadtxt("stnet/meta_dftrain.csv", delimiter=",")
# d_test = np.loadtxt("stnet/meta_dftest.csv", delimiter=",")

# print d_train.shape
# print d_test.shape

# %%
# G = np.loadtxt("stacknet/train_stacknet_with_meta.csv", delimiter=",")
# G_ts = np.loadtxt("stacknet/test_stacknet_with_meta.csv", delimiter=",")

# lgrtf = np.loadtxt("stnet/train_stacker_lgr_tf.csv", delimiter=",")
# lgrtf_ts = np.loadtxt("stnet/test_stacker_lgr_tf.csv", delimiter=",")


# l = F[:,414:427]
# p = G[:,233:239]
# m = np.column_stack((p,l,lgrtf))

# l_ts = F_ts[:,414:427]
# p_ts = G_ts[:,233:239]
# m_ts = np.column_stack((p_ts,l_ts,lgrtf_ts))

# print m.shape
# print m_ts.shape

# np.savetxt("stnet/pred_train_3xgb_nn_rf_2lr.csv", m, delimiter=",", fmt='%.6f')
# np.savetxt("stnet/pred_test_3xgb_nn_rf_2lr.csv", m_ts, delimiter=",", fmt='%.6f')
# X = np.column_stack((np.array(y_train),X,train_stacker))
# X_ts = np.column_stack((np.array(X_test['listing_id']),X_ts))

x = np.column_stack((np.array(y_train),x,m))
x_ts = np.column_stack((np.array(X_test['listing_id']),x_ts,m_ts))

print x.shape
print x_ts.shape

np.savetxt("stacknet/train_norm_3xgb_nn_rf_2lr.csv", x, delimiter=",", fmt='%.6f')
np.savetxt("stacknet/test_norm_3xgb_nn_rf_2lr.csv", x_ts, delimiter=",", fmt='%.6f')

# p = pd.DataFrame(G[:,233:239])
# p.head()
# l = pd.DataFrame(F[:,414:427])
# l.head()
# Out:
# (49352, 200)
# (74659, 200)

# %%
from scipy import sparse

sx = sparse.csr_matrix(x)   # Here's the initialization of the sparse matrix.
sx_test = sparse.csr_matrix(x_ts)

x = sx.toarray()
x_ts = sx_test.toarray()

np.savetxt("stacknet/train_norm_3xgb_nn_rf_2lr.csv", x, delimiter=",", fmt='%.6f')
np.savetxt("stacknet/test_norm_3xgb_nn_rf_2lr.csv", x_ts, delimiter=",", fmt='%.6f')

# %%
print F.shape
print F_ts.shape

java -Xmx6048m -jar StackNet.jar train train_file=train_add_3xgb_nn_rf_2lr.csv test_file=test_add_3xgb_nn_rf_2lr.csv params=paramssimplev1.txt pred_file=sigma_stack_pred_meta7_add.csv test_target=true verbose=true Threads=9 stackdata=true folds=5 seed=1 metric=logloss
# Out:
# (49352, 426)
# (74659, 426)

# %%
from sklearn.preprocessing import PolynomialFeatures    
from sklearn.preprocessing import FunctionTransformer

transformer = FunctionTransformer(np.log1p)    
square = FunctionTransformer(np.square)    

#poly = PolynomialFeatures(degree=2)
x_train[np.isnan(x_train)] = 0
x_test[np.isnan(x_test)] = 0

x_train[np.isinf(x_train)] = 0
x_test[np.isinf(x_test)] = 0

# x_train = np.column_stack((x_train,square.transform(x_train),transformer.transform(x_train)))
# x_test = np.column_stack((x_test,square.transform(x_test),transformer.transform(x_test)))

x_train = np.column_stack((square.transform(x_train),transformer.transform(x_train)))
x_test = np.column_stack((square.transform(x_test),transformer.transform(x_test)))

x_train[np.isnan(x_train)] = 0
x_test[np.isnan(x_test)] = 0

x_train[np.isinf(x_train)] = 0
x_test[np.isinf(x_test)] = 0

for i in range(x_train.shape[1]):
    x_test[:, i] = (x_test[:, i] - np.mean(x_train[:, i]))/np.std(x_train[:, i])
    x_train[:, i] = (x_train[:, i] - np.mean(x_train[:, i]))/np.std(x_train[:, i])

x_train[np.isnan(x_train)] = 0
x_test[np.isnan(x_test)] = 0

x_train[np.isinf(x_train)] = 0
x_test[np.isinf(x_test)] = 0

print x_train.shape
print x_test.shape
# Out:
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:27: RuntimeWarning: divide by zero encountered in divide
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:27: RuntimeWarning: invalid value encountered in divide
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:28: RuntimeWarning: invalid value encountered in divide
# (49352, 350)
# (74659, 350)

# %%
x_train = np.array(X_train)
x_test = np.array(X_test)

# %%
from sklearn.ensemble import GradientBoostingClassifier,ExtraTreesClassifier 
from sklearn.linear_model import Perceptron,SGDClassifier,RidgeClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis,LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC,SVC
from sklearn.gaussian_process import GaussianProcessClassifier

import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.cross_validation import train_test_split
from pyfm import pylibfm

from sklearn.datasets import make_classification

# X, y = make_classification(n_samples=1000,n_features=100, n_clusters_per_class=1)
# data = [ {v: k for k, v in dict(zip(i, range(len(i)))).items()}  for i in X]

# X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.1, random_state=42)

v = DictVectorizer()
x_train = v.fit_transform(x_train)
x_test = v.transform(x_test)

forest = pylibfm.FM(num_factors=50, num_iter=10, verbose=True, task="classification", initial_learning_rate=0.0001, 
                learning_rate_schedule="optimal")

forest.fit(x_train,y_train)

# forest = GaussianProcessClassifier(kernel=None, optimizer='fmin_l_bfgs_b', n_restarts_optimizer=0, 
#                                     max_iter_predict=10, warm_start=False, copy_X_train=True, random_state=None, 
#                                    multi_class='one_vs_rest', n_jobs=1)


# cv_scores = []
# oof_preds = []

# # StratifiedKFold
# # kf = model_selection.StratifiedKFold(n_splits=10, shuffle=True, random_state=2016)
# # for dev_index, val_index in kf.split(range(x_train.shape[0]),y_train):

# kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
# for dev_index, val_index in kf.split(range(x_train.shape[0])):
#         dev_X, val_X = x_train[dev_index,:], x_train[val_index,:]
#         dev_y, val_y = y_train[dev_index], y_train[val_index]
#         forest.fit(dev_X, dev_y)
#         forest_predict = forest.predict_proba(val_X)
#         cv_scores.append(log_loss(val_y, forest_predict))
# #         oof_preds.append(preds)
# #         predictions = bst.predict(X1cv)     
# #         predictions = preds.reshape( val_X.shape[0], 3)
#         print(cv_scores)
#         break
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-255-6ee157fb18ae> in <module>()
#      20
#      21 v = DictVectorizer()
# ---> 22 x_train = v.fit_transform(x_train)
#      23 x_test = v.transform(x_test)
#      24
#
# /usr/lib64/python2.7/site-packages/sklearn/feature_extraction/dict_vectorizer.pyc in fit_transform(self, X, y)
#     229             Feature vectors; always 2-d.
#     230         """
# --> 231         return self._transform(X, fitting=True)
#     232
#     233     def inverse_transform(self, X, dict_type=dict):
#
# /usr/lib64/python2.7/site-packages/sklearn/feature_extraction/dict_vectorizer.pyc in _transform(self, X, fitting)
#     165         # same time
#     166         for x in X:
# --> 167             for f, v in six.iteritems(x):
#     168                 if isinstance(v, six.string_types):
#     169                     f = "%s%s%s" % (f, self.separator, v)
#
# /usr/lib64/python2.7/site-packages/sklearn/externals/six.pyc in iteritems(d, **kw)
#     437 def iteritems(d, **kw):
#     438     """Return an iterator over the (key, value) pairs of a dictionary."""
# --> 439     return iter(getattr(d, _iteritems)(**kw))
#     440
#     441 def iterlists(d, **kw):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iteritems'

# %%
# forest = RandomForestClassifier(n_estimators=500, criterion='entropy', max_depth=10,
#                                 max_features= 0.2, min_samples_split = 20 ,bootstrap=False,n_jobs=-1, 
#                                 oob_score = False, random_state=3, verbose=1)
x_train = np.array(X_train)
x_test = np.array(X_test)

for i in range(x_train.shape[1]):
    x_test[:, i] = (x_test[:, i] - np.mean(x_train[:, i]))/np.std(x_train[:, i])
    x_train[:, i] = (x_train[:, i] - np.mean(x_train[:, i]))/np.std(x_train[:, i])

from sklearn.preprocessing import PolynomialFeatures    
from sklearn.preprocessing import FunctionTransformer

transformer = FunctionTransformer(np.log1p)    

poly = PolynomialFeatures(degree=2)

x_train = np.column_stack((x_train,poly.fit_transform(x_train),transformer.transform(x_train)))
x_test = np.column_stack((x_test,poly.fit_transform(x_test),transformer.transform(x_test)))

x_train[np.isnan(x_train)] = 0
x_test[np.isnan(x_test)] = 0

x_train[np.isinf(x_train)] = 0
x_test[np.isinf(x_test)] = 0

print x_train.shape
print x_test.shape
# from sklearn.ensemble import ExtraTreesClassifier,AdaBoostClassifier,IsolationForest
# from sklearn.linear_model import ARDRegression,LogisticRegression,BayesianRidge
# from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
# from sklearn.metrics import log_loss

# # BayesianRidge(n_iter=300, tol=0.001, alpha_1=1e-06, alpha_2=1e-06, 
# #               lambda_1=1e-06, lambda_2=1e-06, compute_score=False, fit_intercept=True, 
# #               normalize=False, copy_X=True, verbose=False)

# forest = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=0.02, fit_intercept=True, 
#                             intercept_scaling=1, class_weight=None, random_state=None, solver='newton-cg', 
#                             max_iter=100, multi_class='multinomial', verbose=1, warm_start=False, n_jobs=1)

# cv_scores = []
# oof_preds = []
# # StratifiedKFold
# # kf = model_selection.StratifiedKFold(n_splits=10, shuffle=True, random_state=2016)
# # for dev_index, val_index in kf.split(range(x_train.shape[0]),y_train):
# kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
# for dev_index, val_index in kf.split(range(x_train.shape[0])):
#         dev_X, val_X = x_train[dev_index,:], x_train[val_index,:]
#         dev_y, val_y = y_train[dev_index], y_train[val_index]
#         forest.fit(dev_X, dev_y)
#         forest_predict = forest.predict_proba(val_X)
#         cv_scores.append(log_loss(val_y, forest_predict))
# #         oof_preds.append(preds)
# #         predictions = bst.predict(X1cv)     
# #         predictions = preds.reshape( val_X.shape[0], 3)
#         print(cv_scores)
#         break
# Out:
# (49352, 15926)
# (74659, 15926)

# %%
# Out:
# (49352, 16466)

# %%
#random forest

forest_predict = forest.predict_proba(X_val)
log_loss(y_val,forest_predict)
#benchmark 0.541
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-163-24be9e1e9e15> in <module>()
#       2
#       3 forest = RandomForestClassifier(n_estimators=300, criterion='entropy', max_depth=30,max_features= 0.3, min_samples_split =10 ,bootstrap=True,n_jobs=4, oob_score = True, random_state=3, verbose=1)
# ----> 4 forest.fit(X_dev, y_dev)
#       5 forest_predict = forest.predict_proba(X_val)
#       6 log_loss(y_val,forest_predict)
#
# NameError: name 'X_dev' is not defined

# %%
#forest submission
forest_predict = forest.fit(X_train, y_train).predict_proba(X_test)
submission = pd.DataFrame(forest_predict, columns = ['high','medium','low']).set_index(test_df.index)
submission['listing_id'] = test_df.listing_id.values
submission.to_csv('model_1_forest.csv', index= False)
# Out:
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=4)]: Done 300 out of 300 | elapsed:  1.5min finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 300 out of 300 | elapsed:    3.4s finished

# %%
st = pd.read_csv('stnet/test5.csv')

st.head()
# Out:
#    7142618.00000  1.00000  1.00000.1  2950.00000  1180.00000  0.32093  \
# 0      7210040.0      1.0        2.0      2850.0   814.28571  0.06051
# 1      7103890.0      1.0        1.0      3758.0  1503.20000  0.27927
# 2      7143442.0      1.0        2.0      3300.0   942.85714  0.22797
# 3      6860601.0      2.0        2.0      4900.0  1225.00000  0.34767
# 4      6840081.0      3.0        3.0      9000.0  1800.00000  0.11321
#
#    0.06863  0.33255  0.20816  8.00000   ...     6.00000  5.00000  11.00000  \
# 0  0.02353  0.00411  0.00140      3.0   ...         6.0      4.0      24.0
# 1  0.06854  0.24077  0.07628      6.0   ...         6.0      4.0       3.0
# 2  0.07753  0.39354  0.35979      6.0   ...         6.0      5.0      11.0
# 3  0.05634  0.32074  0.08310      7.0   ...         4.0      1.0      12.0
# 4  0.03883  0.01119  0.00000      8.0   ...         4.0      3.0       7.0
#
#    5.00000.1  0.45833  0.33333  0.20833  0.13348  0.45643  0.41010
# 0        6.0  1.00000  0.00000  0.00000  0.00887  0.02833  0.96280
# 1        4.0  0.00000  1.00000  0.00000  0.05618  0.46727  0.47655
# 2        6.0  0.24590  0.39344  0.36066  0.15609  0.52356  0.32035
# 3        5.0  0.59722  0.31944  0.08333  0.07302  0.25761  0.66937
# 4        6.0  0.98876  0.01124  0.00000  0.00024  0.00796  0.99180
#
# [5 rows x 179 columns]

# %%
# test = pd.read_csv('stacknet/train_stacknet.csv')
X_train.head()
# Out:
#         bathrooms  bedrooms  price  num_priceXroom  building_id_mean_medium  \
# 10            1.5         3   3000      631.578947                 0.217575
# 10000         1.0         2   5465     1561.428571                 0.110642
# 100004        1.0         1   2850     1140.000000                 0.467347
# 100007        1.0         1   3275     1310.000000                 0.094998
# 100013        1.0         4   3350      609.090909                 0.058909
#
#         building_id_mean_high  manager_id_mean_medium  manager_id_mean_high  \
# 10               7.436940e-02                0.283585          9.190504e-29
# 10000            1.761506e-07                0.012447          2.088626e-34
# 100004           9.291841e-02                0.357575          3.169581e-02
# 100007           1.187783e-02                0.152256          8.444808e-02
# 100013           2.270975e-02                0.000564          1.922140e-04
#
#         num_photos  building_id_present         ...          listing_id  \
# 10               5                    1         ...             7211212
# 10000           11                    1         ...             7150865
# 100004           8                    1         ...             6887163
# 100007           3                    1         ...             6888711
# 100013           3                    0         ...             6934781
#
#         median_price_groupby_manager  median_price_groupby_neighbourhood  \
# 10                            2800.0                               300.0
# 10000                         5445.0                             -1290.0
# 100004                        2862.5                               775.0
# 100007                        3195.0                              -200.0
# 100013                        5000.0                               440.0
#
#         month  day_of_week  day_of_month  hour_of_day  manager_level_low  \
# 10          6            4            24            7           0.800000
# 10000       6            6            12           12           0.985507
# 100004      4            6            17            3           0.560748
# 100007      4            0            18            2           0.777778
# 100013      4            3            28            1           1.000000
#
#         manager_level_medium  manager_level_high
# 10                  0.200000            0.000000
# 10000               0.014493            0.000000
# 100004              0.383178            0.056075
# 100007              0.143791            0.078431
# 100013              0.000000            0.000000
#
# [5 rows x 175 columns]

# %%
pred_tr = model.predict(xgb.DMatrix(X_train))
pred_ts = model.predict(xgb.DMatrix(X_test))

# %%
# new_df = X_train.copy()

# new_df['target'] = y_train

# new_df.head()

cols = list(new_df.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('target')) #Remove b from list
# cols.pop(cols.index('x')) #Remove x from list
new_df = new_df[['target']+cols]
new_df.head()
# Out:
#         target  bathrooms  bedrooms  price  num_priceXroom  \
# 10           1        1.5         3   3000      631.578947
# 10000        2        1.0         2   5465     1561.428571
# 100004       0        1.0         1   2850     1140.000000
# 100007       2        1.0         1   3275     1310.000000
# 100013       2        1.0         4   3350      609.090909
#
#         building_id_mean_medium  building_id_mean_high  \
# 10                     0.217575           7.436940e-02
# 10000                  0.110642           1.761506e-07
# 100004                 0.467347           9.291841e-02
# 100007                 0.094998           1.187783e-02
# 100013                 0.058909           2.270975e-02
#
#         manager_id_mean_medium  manager_id_mean_high  num_photos  \
# 10                    0.283585          9.190504e-29           5
# 10000                 0.012447          2.088626e-34          11
# 100004                0.357575          3.169581e-02           8
# 100007                0.152256          8.444808e-02           3
# 100013                0.000564          1.922140e-04           3
#
#                ...          listing_id  median_price_groupby_manager  \
# 10             ...             7211212                        2800.0
# 10000          ...             7150865                        5445.0
# 100004         ...             6887163                        2862.5
# 100007         ...             6888711                        3195.0
# 100013         ...             6934781                        5000.0
#
#         median_price_groupby_neighbourhood  month  day_of_week  day_of_month  \
# 10                                   300.0      6            4            24
# 10000                              -1290.0      6            6            12
# 100004                               775.0      4            6            17
# 100007                              -200.0      4            0            18
# 100013                               440.0      4            3            28
#
#         hour_of_day  manager_level_low  manager_level_medium  \
# 10                7           0.800000              0.200000
# 10000            12           0.985507              0.014493
# 100004            3           0.560748              0.383178
# 100007            2           0.777778              0.143791
# 100013            1           1.000000              0.000000
#
#         manager_level_high
# 10                0.000000
# 10000             0.000000
# 100004            0.056075
# 100007            0.078431
# 100013            0.000000
#
# [5 rows x 176 columns]

# %%
ntest_df = X_test.copy()

ntest_df['id'] = test_df['listing_id']

ntest_df.head()

cols = list(ntest_df.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('id')) #Remove b from list
# cols.pop(cols.index('x')) #Remove x from list
ntest_df = ntest_df[['id']+cols]
ntest_df.head()
# Out:
#              id  bathrooms  bedrooms  price  num_priceXroom  \
# 0       7142618        1.0         1   2950     1180.000000
# 1       7210040        1.0         2   2850      814.285714
# 100     7103890        1.0         1   3758     1503.200000
# 1000    7143442        1.0         2   3300      942.857143
# 100000  6860601        2.0         2   4900     1225.000000
#
#         building_id_mean_medium  building_id_mean_high  \
# 0                      0.320934               0.068633
# 1                      0.060514               0.023531
# 100                    0.279269               0.068537
# 1000                   0.227968               0.077526
# 100000                 0.347673               0.056340
#
#         manager_id_mean_medium  manager_id_mean_high  num_photos  \
# 0                     0.332546              0.208158           8
# 1                     0.004108              0.001402           3
# 100                   0.240770              0.076282           6
# 1000                  0.393544              0.359790           6
# 100000                0.320742              0.083104           7
#
#                ...          listing_id  median_price_groupby_manager  \
# 0              ...             7142618                        2650.0
# 1              ...             7210040                        2850.0
# 100            ...             7103890                        4129.0
# 1000           ...             7143442                        3200.0
# 100000         ...             6860601                        4200.0
#
#         median_price_groupby_neighbourhood  month  day_of_week  day_of_month  \
# 0                                    400.0      6            5            11
# 1                                   1100.0      6            4            24
# 100                                  292.0      6            4             3
# 1000                                 131.5      6            5            11
# 100000                             -1305.0      4            1            12
#
#         hour_of_day  manager_level_low  manager_level_medium  \
# 0                 5           0.458333              0.333333
# 1                 6           1.000000              0.000000
# 100               4           0.000000              1.000000
# 1000              6           0.245902              0.393443
# 100000            5           0.597222              0.319444
#
#         manager_level_high
# 0                 0.208333
# 1                 0.000000
# 100               0.000000
# 1000              0.360656
# 100000            0.083333
#
# [5 rows x 176 columns]

# %%
# new_df.to_csv('stnet/train.csv')
# ntest_df.to_csv('stnet/test.csv')
from scipy import sparse

train_file="stnet/train2.csv"
test_file="stnet/test2.csv"

# train_X = X_train.tocsr() 
# test_X = X_test.tocsr() 

train = np.array(new_df)
test = np.array(ntest_df) 

# X = np.column_stack((train,pred_tr))
#         # stack id to test
# X_ts = np.column_stack((test,pred_ts))        


print ("exporting files")
np.savetxt(train_file, train, delimiter=",", fmt='%.5f')
np.savetxt(test_file, test, delimiter=",", fmt='%.5f')        

# scipy.sparse.csr_matrix(df.values)
# You might need to take the transpose first, like df.values.T
# Out:
# exporting files

# %%
X.shape
# Out:
# (49352, 179)

# %%
print ("merging columns")   
        #stack xgboost predictions
X=np.column_stack((X,train_stacker))
        # stack id to test
X_test=np.column_stack((X_test,test_stacker))        
        
        # stack target to train
X=np.column_stack((y,X))
        # stack id to test
X_test=np.column_stack((ids,X_test))
        
        #export to txt files (, del.)

# %%
import numpy as np
import xgboost as xgb
from sklearn.cross_validation import KFold

__author__ = 'dpace'


class OOFCallback:
    def  __init__(self, oof_preds_dict, maximize=True):
        """
        :param dict oof_preds_dict: Should be an empty dict which can later be
            retrieved.
        :param bool maximize: If True, higher metric scores treated as better.
        """
        self.best_eval_metric = None
        self.oof_preds_dict = oof_preds_dict
        self.maximize=maximize

    def __call__(self, cbenv):
        current_val_score = cbenv.evaluation_result_list[1][1]
        if self.best_eval_metric is None:
            self.best_eval_metric = current_val_score
        if self.maximize:
            if current_val_score >= self.best_eval_metric:
                self.best_eval_metric = current_val_score
                self._compute_oof_preds(cbenv.cvfolds)
        elif current_val_score <= self.best_eval_metric:
                self.best_eval_metric = current_val_score
                self._compute_oof_preds(cbenv.cvfolds)

    def _compute_oof_preds(self, cvfolds):
        for i, fold in enumerate(cvfolds):
            self.oof_preds_dict[i] = fold.bst.predict(fold.dtest)

    

param = {}
param['objective'] = 'multi:softprob'
param['eta'] = .02
param['gamma'] = 0.0
param['max_depth'] = 6
param['silent'] = 1
param['num_class'] = 3
param['eval_metric'] = "mlogloss"
param['reg_alpha'] = 2
param['min_child_weight'] = 10
param['subsample'] = 0.75
param['colsample_bytree'] = 0.5
param['seed'] = 3
param['nthread'] = 4
param['n_jobs'] = -1
# num_rounds = 5000    
    # xgb params

    # Data structure in which to save out-of-folds preds
oof_preds_dict = {}

    # Running cv
cv_res = xgb.cv(params=param,
                dtrain=xgtrain,
                num_boost_round=5000,
                folds = 10,
                early_stopping_rounds=50,
                verbose_eval=100,
                callbacks=[OOFCallback(oof_preds_dict)])

print("\nOut-of-folds predictions at best iteration: \n\n", oof_preds_dict)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-102-1173df169c39> in <module>()
#      63                 early_stopping_rounds=50,
#      64                 verbose_eval=100,
# ---> 65                 callbacks=[OOFCallback(oof_preds_dict)])
#      66
#      67 print("\nOut-of-folds predictions at best iteration: \n\n", oof_preds_dict)
#
# /usr/lib/python2.7/site-packages/xgboost-0.6-py2.7.egg/xgboost/training.pyc in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks, shuffle)
#     405                            evaluation_result_list=None))
#     406         for fold in cvfolds:
# --> 407             fold.update(i, obj)
#     408         res = aggcv([f.eval(i, feval) for f in cvfolds])
#     409
#
# /usr/lib/python2.7/site-packages/xgboost-0.6-py2.7.egg/xgboost/training.pyc in update(self, iteration, fobj)
#     216     def update(self, iteration, fobj):
#     217         """"Update the boosters for one iteration"""
# --> 218         self.bst.update(self.dtrain, iteration, fobj)
#     219
#     220     def eval(self, iteration, feval):
#
# /usr/lib/python2.7/site-packages/xgboost-0.6-py2.7.egg/xgboost/core.pyc in update(self, dtrain, iteration, fobj)
#     817
#     818         if fobj is None:
# --> 819             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
#     820         else:
#     821             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
oof_preds_dict
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-99-abb05af3a422> in <module>()
# ----> 1 oof_preds_dict.shape
#
# AttributeError: 'dict' object has no attribute 'shape'

# %%
def append_meta_features():
# load StackNet input files
X = np.loadtxt("train_stacknet.csv", delimiter=",")`
X_test = np.loadtxt("test_stacknet.csv", delimiter=",")

# load results of one (or more) of your models - here also 
# out-of-fold predictions for the train set are needed
pred_test = np.loadtxt("meta_predictions/preds_test.txt")
pred_train = np.loadtxt("meta_predictions/preds_train.txt")

# combine them with the StackNet input
X_test = np.column_stack((X_test, pred_test))
X = np.column_stack((X, pred_train))

# save into new files to be fed into StackNet
np.savetxt("train_stacknet_with_meta.csv", X, delimiter=",", fmt='%.6f')
np.savetxt("test_stacknet_with_meta.csv", X_test, delimiter=",", fmt='%.6f')

# %%
#multiple xgboost models with different seeds

print("Start fitting...")

xgbclf=[]
rounds=10

for i in range(0,rounds):
    print("training %s"%(i))
    param['seed'] = randint(0,10000)
    num_rounds = 3700

    xgtrain = xgb.DMatrix(X_train, label=y_train)
    watchlist = [ (xgtrain,'train') ]
    plst= list(param.items())
    model = xgb.train(plst, xgtrain, num_rounds, watchlist)
    xgbclf.append(model)
    
print("Fitted")
# Out:
# Start fitting...
# training 0
# [0]	train-mlogloss:1.08598
# [1]	train-mlogloss:1.07326
# [2]	train-mlogloss:1.06097
# [3]	train-mlogloss:1.04901
# [4]	train-mlogloss:1.03742
# [5]	train-mlogloss:1.0263
# [6]	train-mlogloss:1.0155
# [7]	train-mlogloss:1.00489
# [8]	train-mlogloss:0.994561
# [9]	train-mlogloss:0.984789
# [10]	train-mlogloss:0.975207
# [11]	train-mlogloss:0.965806
# [12]	train-mlogloss:0.956604
# [13]	train-mlogloss:0.947781
# [14]	train-mlogloss:0.939169
# [15]	train-mlogloss:0.930738
# [16]	train-mlogloss:0.922704
# [17]	train-mlogloss:0.914803
# [18]	train-mlogloss:0.907279
# [19]	train-mlogloss:0.899824
# [20]	train-mlogloss:0.892694
# [21]	train-mlogloss:0.885631
# [22]	train-mlogloss:0.878687
# [23]	train-mlogloss:0.871953
# [24]	train-mlogloss:0.865478
# [25]	train-mlogloss:0.859057
# [26]	train-mlogloss:0.852902
# [27]	train-mlogloss:0.846865
# [28]	train-mlogloss:0.840968
# [29]	train-mlogloss:0.835328
# [30]	train-mlogloss:0.829831
# [31]	train-mlogloss:0.824402
# [32]	train-mlogloss:0.819231
# [33]	train-mlogloss:0.813976
# [34]	train-mlogloss:0.808864
# [35]	train-mlogloss:0.803859
# [36]	train-mlogloss:0.798988
# [37]	train-mlogloss:0.794285
# [38]	train-mlogloss:0.789848
# [39]	train-mlogloss:0.785365
# [40]	train-mlogloss:0.781021
# [41]	train-mlogloss:0.776761
# [42]	train-mlogloss:0.772684
# [43]	train-mlogloss:0.768533
# [44]	train-mlogloss:0.764573
# [45]	train-mlogloss:0.760738
# [46]	train-mlogloss:0.756919
# [47]	train-mlogloss:0.753171
# [48]	train-mlogloss:0.749473
# [49]	train-mlogloss:0.745904
# [50]	train-mlogloss:0.742412
# [51]	train-mlogloss:0.738995
# [52]	train-mlogloss:0.7358
# [53]	train-mlogloss:0.732509
# [54]	train-mlogloss:0.729289
# [55]	train-mlogloss:0.726222
# [56]	train-mlogloss:0.723317
# [57]	train-mlogloss:0.720366
# [58]	train-mlogloss:0.717484
# [59]	train-mlogloss:0.714644
# [60]	train-mlogloss:0.711922
# [61]	train-mlogloss:0.709193
# [62]	train-mlogloss:0.706523
# [63]	train-mlogloss:0.70402
# [64]	train-mlogloss:0.701481
# [65]	train-mlogloss:0.699003
# [66]	train-mlogloss:0.696668
# [67]	train-mlogloss:0.694275
# [68]	train-mlogloss:0.691925
# [69]	train-mlogloss:0.689668
# [70]	train-mlogloss:0.687419
# [71]	train-mlogloss:0.68523
# [72]	train-mlogloss:0.683074
# [73]	train-mlogloss:0.680972
# [74]	train-mlogloss:0.678939
# [75]	train-mlogloss:0.676888
# [76]	train-mlogloss:0.674914
# [77]	train-mlogloss:0.672934
# [78]	train-mlogloss:0.671035
# [79]	train-mlogloss:0.669215
# [80]	train-mlogloss:0.667352
# [81]	train-mlogloss:0.665628
# [82]	train-mlogloss:0.663894
# [83]	train-mlogloss:0.66216
# [84]	train-mlogloss:0.660478
# [85]	train-mlogloss:0.658831
# [86]	train-mlogloss:0.65718
# [87]	train-mlogloss:0.655558
# [88]	train-mlogloss:0.654054
# [89]	train-mlogloss:0.652556
# [90]	train-mlogloss:0.651029
# [91]	train-mlogloss:0.649516
# [92]	train-mlogloss:0.648089
# [93]	train-mlogloss:0.646702
# [94]	train-mlogloss:0.645322
# [95]	train-mlogloss:0.643968
# [96]	train-mlogloss:0.642632
# [97]	train-mlogloss:0.641283
# [98]	train-mlogloss:0.640007
# [99]	train-mlogloss:0.638747
# [100]	train-mlogloss:0.637522
# [101]	train-mlogloss:0.636302
# [102]	train-mlogloss:0.635083
# [103]	train-mlogloss:0.633857
# [104]	train-mlogloss:0.632677
# [105]	train-mlogloss:0.631529
# [106]	train-mlogloss:0.630455
# [107]	train-mlogloss:0.629332
# [108]	train-mlogloss:0.628272
# [109]	train-mlogloss:0.627189
# [110]	train-mlogloss:0.626156
# [111]	train-mlogloss:0.625156
# [112]	train-mlogloss:0.624152
# [113]	train-mlogloss:0.623163
# [114]	train-mlogloss:0.6222
# [115]	train-mlogloss:0.62122
# [116]	train-mlogloss:0.620289
# [117]	train-mlogloss:0.619345
# [118]	train-mlogloss:0.618443
# [119]	train-mlogloss:0.617566
# [120]	train-mlogloss:0.616692
# [121]	train-mlogloss:0.615832
# [122]	train-mlogloss:0.614963
# [123]	train-mlogloss:0.614153
# [124]	train-mlogloss:0.613346
# [125]	train-mlogloss:0.612501
# [126]	train-mlogloss:0.61171
# [127]	train-mlogloss:0.610901
# [128]	train-mlogloss:0.610099
# [129]	train-mlogloss:0.609341
# [130]	train-mlogloss:0.608579
# [131]	train-mlogloss:0.607785
# [132]	train-mlogloss:0.607024
# [133]	train-mlogloss:0.606315
# [134]	train-mlogloss:0.605616
# [135]	train-mlogloss:0.604908
# [136]	train-mlogloss:0.60424
# [137]	train-mlogloss:0.603547
# [138]	train-mlogloss:0.602897
# [139]	train-mlogloss:0.602244
# [140]	train-mlogloss:0.601566
# [141]	train-mlogloss:0.600907
# [142]	train-mlogloss:0.60028
# [143]	train-mlogloss:0.599678
# [144]	train-mlogloss:0.599051
# [145]	train-mlogloss:0.598482
# [146]	train-mlogloss:0.597891
# [147]	train-mlogloss:0.597301
# [148]	train-mlogloss:0.596711
# [149]	train-mlogloss:0.596135
# [150]	train-mlogloss:0.595566
# [151]	train-mlogloss:0.594986
# [152]	train-mlogloss:0.594427
# [153]	train-mlogloss:0.593903
# [154]	train-mlogloss:0.593323
# [155]	train-mlogloss:0.592818
# [156]	train-mlogloss:0.592305
# [157]	train-mlogloss:0.591796
# [158]	train-mlogloss:0.591314
# [159]	train-mlogloss:0.590815
# [160]	train-mlogloss:0.59035
# [161]	train-mlogloss:0.589876
# [162]	train-mlogloss:0.589386
# [163]	train-mlogloss:0.588878
# [164]	train-mlogloss:0.588397
# [165]	train-mlogloss:0.587931
# [166]	train-mlogloss:0.587484
# [167]	train-mlogloss:0.587031
# [168]	train-mlogloss:0.586574
# [169]	train-mlogloss:0.586093
# [170]	train-mlogloss:0.585622
# [171]	train-mlogloss:0.585204
# [172]	train-mlogloss:0.584761
# [173]	train-mlogloss:0.584343
# [174]	train-mlogloss:0.583903
# [175]	train-mlogloss:0.583464
# [176]	train-mlogloss:0.583076
# [177]	train-mlogloss:0.582704
# [178]	train-mlogloss:0.582297
# [179]	train-mlogloss:0.581893
# [180]	train-mlogloss:0.581509
# [181]	train-mlogloss:0.581122
# [182]	train-mlogloss:0.580749
# [183]	train-mlogloss:0.580364
# [184]	train-mlogloss:0.579983
# [185]	train-mlogloss:0.579645
# [186]	train-mlogloss:0.579288
# [187]	train-mlogloss:0.578936
# [188]	train-mlogloss:0.578586
# [189]	train-mlogloss:0.578239
# [190]	train-mlogloss:0.577874
# [191]	train-mlogloss:0.577492
# [192]	train-mlogloss:0.577117
# [193]	train-mlogloss:0.576788
# [194]	train-mlogloss:0.576442
# [195]	train-mlogloss:0.576061
# [196]	train-mlogloss:0.575732
# [197]	train-mlogloss:0.575352
# [198]	train-mlogloss:0.57503
# [199]	train-mlogloss:0.574667
# [200]	train-mlogloss:0.574351
# [201]	train-mlogloss:0.574017
# [202]	train-mlogloss:0.573725
# [203]	train-mlogloss:0.573399
# [204]	train-mlogloss:0.573061
# [205]	train-mlogloss:0.572747
# [206]	train-mlogloss:0.572453
# [207]	train-mlogloss:0.572149
# [208]	train-mlogloss:0.571837
# [209]	train-mlogloss:0.57153
# [210]	train-mlogloss:0.571216
# [211]	train-mlogloss:0.57087
# [212]	train-mlogloss:0.570587
# [213]	train-mlogloss:0.570279
# [214]	train-mlogloss:0.569991
# [215]	train-mlogloss:0.569667
# [216]	train-mlogloss:0.569357
# [217]	train-mlogloss:0.569097
# [218]	train-mlogloss:0.568804
# [219]	train-mlogloss:0.568543
# [220]	train-mlogloss:0.568276
# [221]	train-mlogloss:0.567983
# [222]	train-mlogloss:0.567701
# [223]	train-mlogloss:0.567441
# [224]	train-mlogloss:0.567159
# [225]	train-mlogloss:0.56691
# [226]	train-mlogloss:0.566627
# [227]	train-mlogloss:0.566361
# [228]	train-mlogloss:0.566112
# [229]	train-mlogloss:0.565864
# [230]	train-mlogloss:0.5656
# [231]	train-mlogloss:0.565334
# [232]	train-mlogloss:0.565092
# [233]	train-mlogloss:0.564849
# [234]	train-mlogloss:0.564559
# [235]	train-mlogloss:0.564298
# [236]	train-mlogloss:0.564039
# [237]	train-mlogloss:0.563788
# [238]	train-mlogloss:0.563544
# [239]	train-mlogloss:0.563296
# [240]	train-mlogloss:0.563058
# [241]	train-mlogloss:0.562841
# [242]	train-mlogloss:0.56262
# [243]	train-mlogloss:0.562362
# [244]	train-mlogloss:0.562138
# [245]	train-mlogloss:0.561895
# [246]	train-mlogloss:0.561641
# [247]	train-mlogloss:0.561384
# [248]	train-mlogloss:0.56114
# [249]	train-mlogloss:0.560905
# [250]	train-mlogloss:0.560684
# [251]	train-mlogloss:0.560451
# [252]	train-mlogloss:0.560231
# [253]	train-mlogloss:0.559971
# [254]	train-mlogloss:0.559754
# [255]	train-mlogloss:0.559511
# [256]	train-mlogloss:0.55929
# [257]	train-mlogloss:0.559089
# [258]	train-mlogloss:0.558886
# [259]	train-mlogloss:0.558638
# [260]	train-mlogloss:0.558405
# [261]	train-mlogloss:0.558199
# [262]	train-mlogloss:0.557996
# [263]	train-mlogloss:0.55778
# [264]	train-mlogloss:0.557561
# [265]	train-mlogloss:0.557361
# [266]	train-mlogloss:0.557139
# [267]	train-mlogloss:0.556931
# [268]	train-mlogloss:0.556716
# [269]	train-mlogloss:0.55649
# [270]	train-mlogloss:0.556276
# [271]	train-mlogloss:0.55607
# [272]	train-mlogloss:0.555893
# [273]	train-mlogloss:0.555696
# [274]	train-mlogloss:0.5555
# [275]	train-mlogloss:0.55527
# [276]	train-mlogloss:0.55508
# [277]	train-mlogloss:0.554881
# [278]	train-mlogloss:0.554676
# [279]	train-mlogloss:0.554488
# [280]	train-mlogloss:0.554302
# [281]	train-mlogloss:0.554118
# [282]	train-mlogloss:0.553925
# [283]	train-mlogloss:0.553743
# [284]	train-mlogloss:0.553506
# [285]	train-mlogloss:0.553322
# [286]	train-mlogloss:0.55316
# [287]	train-mlogloss:0.553003
# [288]	train-mlogloss:0.552836
# [289]	train-mlogloss:0.552635
# [290]	train-mlogloss:0.552439
# [291]	train-mlogloss:0.552241
# [292]	train-mlogloss:0.552072
# [293]	train-mlogloss:0.551866
# [294]	train-mlogloss:0.551685
# [295]	train-mlogloss:0.551521
# [296]	train-mlogloss:0.55133
# [297]	train-mlogloss:0.551116
# [298]	train-mlogloss:0.55094
# [299]	train-mlogloss:0.550784
# [300]	train-mlogloss:0.550564
# [301]	train-mlogloss:0.550401
# [302]	train-mlogloss:0.55022
# [303]	train-mlogloss:0.550057
# [304]	train-mlogloss:0.549875
# [305]	train-mlogloss:0.549689
# [306]	train-mlogloss:0.549505
# [307]	train-mlogloss:0.549337
# [308]	train-mlogloss:0.549178
# [309]	train-mlogloss:0.549033
# [310]	train-mlogloss:0.548867
# [311]	train-mlogloss:0.548717
# [312]	train-mlogloss:0.548559
# [313]	train-mlogloss:0.548398
# [314]	train-mlogloss:0.548243
# [315]	train-mlogloss:0.548108
# [316]	train-mlogloss:0.54795
# [317]	train-mlogloss:0.547815
# [318]	train-mlogloss:0.547667
# [319]	train-mlogloss:0.547504
# [320]	train-mlogloss:0.54736
# [321]	train-mlogloss:0.547189
# [322]	train-mlogloss:0.547021
# [323]	train-mlogloss:0.546877
# [324]	train-mlogloss:0.546723
# [325]	train-mlogloss:0.546569
# [326]	train-mlogloss:0.546414
# [327]	train-mlogloss:0.546264
# [328]	train-mlogloss:0.546104
# [329]	train-mlogloss:0.545943
# [330]	train-mlogloss:0.545758
# [331]	train-mlogloss:0.545615
# [332]	train-mlogloss:0.545444
# [333]	train-mlogloss:0.545291
# [334]	train-mlogloss:0.545151
# [335]	train-mlogloss:0.544998
# [336]	train-mlogloss:0.544869
# [337]	train-mlogloss:0.544685
# [338]	train-mlogloss:0.544538
# [339]	train-mlogloss:0.544376
# [340]	train-mlogloss:0.544241
# [341]	train-mlogloss:0.544103
# [342]	train-mlogloss:0.543938
# [343]	train-mlogloss:0.543794
# [344]	train-mlogloss:0.543675
# [345]	train-mlogloss:0.543498
# [346]	train-mlogloss:0.543371
# [347]	train-mlogloss:0.543227
# [348]	train-mlogloss:0.543096
# [349]	train-mlogloss:0.542962
# [350]	train-mlogloss:0.542835
# [351]	train-mlogloss:0.542702
# [352]	train-mlogloss:0.542553
# [353]	train-mlogloss:0.542422
# [354]	train-mlogloss:0.542282
# [355]	train-mlogloss:0.542155
# [356]	train-mlogloss:0.542031
# [357]	train-mlogloss:0.541899
# [358]	train-mlogloss:0.541752
# [359]	train-mlogloss:0.541599
# [360]	train-mlogloss:0.541474
# [361]	train-mlogloss:0.541331
# [362]	train-mlogloss:0.54121
# [363]	train-mlogloss:0.541077
# [364]	train-mlogloss:0.540897
# [365]	train-mlogloss:0.540746
# [366]	train-mlogloss:0.540575
# [367]	train-mlogloss:0.540471
# [368]	train-mlogloss:0.540331
# [369]	train-mlogloss:0.54023
# [370]	train-mlogloss:0.540119
# [371]	train-mlogloss:0.539944
# [372]	train-mlogloss:0.539823
# [373]	train-mlogloss:0.539691
# [374]	train-mlogloss:0.539566
# [375]	train-mlogloss:0.53947
# [376]	train-mlogloss:0.539332
# [377]	train-mlogloss:0.539184
# [378]	train-mlogloss:0.539047
# [379]	train-mlogloss:0.538925
# [380]	train-mlogloss:0.538781
# [381]	train-mlogloss:0.538659
# [382]	train-mlogloss:0.538554
# [383]	train-mlogloss:0.538433
# [384]	train-mlogloss:0.538316
# [385]	train-mlogloss:0.538146
# [386]	train-mlogloss:0.538024
# [387]	train-mlogloss:0.537922
# [388]	train-mlogloss:0.537768
# [389]	train-mlogloss:0.537636
# [390]	train-mlogloss:0.53749
# [391]	train-mlogloss:0.537379
# [392]	train-mlogloss:0.537248
# [393]	train-mlogloss:0.537116
# [394]	train-mlogloss:0.536996
# [395]	train-mlogloss:0.536893
# [396]	train-mlogloss:0.536728
# [397]	train-mlogloss:0.536601
# [398]	train-mlogloss:0.536473
# [399]	train-mlogloss:0.536366
# [400]	train-mlogloss:0.536224
# [401]	train-mlogloss:0.5361
# [402]	train-mlogloss:0.536013
# [403]	train-mlogloss:0.535862
# [404]	train-mlogloss:0.535762
# [405]	train-mlogloss:0.535645
# [406]	train-mlogloss:0.535538
# [407]	train-mlogloss:0.535439
# [408]	train-mlogloss:0.535312
# [409]	train-mlogloss:0.535206
# [410]	train-mlogloss:0.535098
# [411]	train-mlogloss:0.534954
# [412]	train-mlogloss:0.534833
# [413]	train-mlogloss:0.534716
# [414]	train-mlogloss:0.534623
# [415]	train-mlogloss:0.534508
# [416]	train-mlogloss:0.53438
# [417]	train-mlogloss:0.534239
# [418]	train-mlogloss:0.534126
# [419]	train-mlogloss:0.534029
# [420]	train-mlogloss:0.533924
# [421]	train-mlogloss:0.533795
# [422]	train-mlogloss:0.533687
# [423]	train-mlogloss:0.533538
# [424]	train-mlogloss:0.533421
# [425]	train-mlogloss:0.533259
# [426]	train-mlogloss:0.533126
# [427]	train-mlogloss:0.533035
# [428]	train-mlogloss:0.532917
# [429]	train-mlogloss:0.532795
# [430]	train-mlogloss:0.532689
# [431]	train-mlogloss:0.53259
# [432]	train-mlogloss:0.53246
# [433]	train-mlogloss:0.532352
# [434]	train-mlogloss:0.532261
# [435]	train-mlogloss:0.532167
# [436]	train-mlogloss:0.532062
# [437]	train-mlogloss:0.531963
# [438]	train-mlogloss:0.531835
# [439]	train-mlogloss:0.531744
# [440]	train-mlogloss:0.531595
# [441]	train-mlogloss:0.531472
# [442]	train-mlogloss:0.531369
# [443]	train-mlogloss:0.53128
# [444]	train-mlogloss:0.531171
# [445]	train-mlogloss:0.53104
# [446]	train-mlogloss:0.53094
# [447]	train-mlogloss:0.53084
# [448]	train-mlogloss:0.530758
# [449]	train-mlogloss:0.530642
# [450]	train-mlogloss:0.530564
# [451]	train-mlogloss:0.530467
# [452]	train-mlogloss:0.53033
# [453]	train-mlogloss:0.530218
# [454]	train-mlogloss:0.530115
# [455]	train-mlogloss:0.53001
# [456]	train-mlogloss:0.529899
# [457]	train-mlogloss:0.529802
# [458]	train-mlogloss:0.529698
# [459]	train-mlogloss:0.529592
# [460]	train-mlogloss:0.529451
# [461]	train-mlogloss:0.529344
# [462]	train-mlogloss:0.529247
# [463]	train-mlogloss:0.529131
# [464]	train-mlogloss:0.529033
# [465]	train-mlogloss:0.528963
# [466]	train-mlogloss:0.528864
# [467]	train-mlogloss:0.528769
# [468]	train-mlogloss:0.52867
# [469]	train-mlogloss:0.528579
# [470]	train-mlogloss:0.528484
# [471]	train-mlogloss:0.528392
# [472]	train-mlogloss:0.528289
# [473]	train-mlogloss:0.528209
# [474]	train-mlogloss:0.52809
# [475]	train-mlogloss:0.527968
# [476]	train-mlogloss:0.527862
# [477]	train-mlogloss:0.527784
# [478]	train-mlogloss:0.527664
# [479]	train-mlogloss:0.527568
# [480]	train-mlogloss:0.527466
# [481]	train-mlogloss:0.527354
# [482]	train-mlogloss:0.527266
# [483]	train-mlogloss:0.52718
# [484]	train-mlogloss:0.527084
# [485]	train-mlogloss:0.526972
# [486]	train-mlogloss:0.526845
# [487]	train-mlogloss:0.526705
# [488]	train-mlogloss:0.52657
# [489]	train-mlogloss:0.526468
# [490]	train-mlogloss:0.526365
# [491]	train-mlogloss:0.526251
# [492]	train-mlogloss:0.526159
# [493]	train-mlogloss:0.526082
# [494]	train-mlogloss:0.525969
# [495]	train-mlogloss:0.525838
# [496]	train-mlogloss:0.525744
# [497]	train-mlogloss:0.525653
# [498]	train-mlogloss:0.525528
# [499]	train-mlogloss:0.525432
# [500]	train-mlogloss:0.525351
# [501]	train-mlogloss:0.525244
# [502]	train-mlogloss:0.525148
# [503]	train-mlogloss:0.525059
# [504]	train-mlogloss:0.524959
# [505]	train-mlogloss:0.524868
# [506]	train-mlogloss:0.524777
# [507]	train-mlogloss:0.524662
# [508]	train-mlogloss:0.524566
# [509]	train-mlogloss:0.524475
# [510]	train-mlogloss:0.524388
# [511]	train-mlogloss:0.524291
# [512]	train-mlogloss:0.524214
# [513]	train-mlogloss:0.524111
# [514]	train-mlogloss:0.524028
# [515]	train-mlogloss:0.523943
# [516]	train-mlogloss:0.523871
# [517]	train-mlogloss:0.523774
# [518]	train-mlogloss:0.523676
# [519]	train-mlogloss:0.523571
# [520]	train-mlogloss:0.523486
# [521]	train-mlogloss:0.523374
# [522]	train-mlogloss:0.523301
# [523]	train-mlogloss:0.523216
# [524]	train-mlogloss:0.523116
# [525]	train-mlogloss:0.52302
# [526]	train-mlogloss:0.522931
# [527]	train-mlogloss:0.522855
# [528]	train-mlogloss:0.522756
# [529]	train-mlogloss:0.522659
# [530]	train-mlogloss:0.52258
# [531]	train-mlogloss:0.522458
# [532]	train-mlogloss:0.522384
# [533]	train-mlogloss:0.522281
# [534]	train-mlogloss:0.522219
# [535]	train-mlogloss:0.522111
# [536]	train-mlogloss:0.522037
# [537]	train-mlogloss:0.521966
# [538]	train-mlogloss:0.521885
# [539]	train-mlogloss:0.521791
# [540]	train-mlogloss:0.521702
# [541]	train-mlogloss:0.521612
# [542]	train-mlogloss:0.521506
# [543]	train-mlogloss:0.521427
# [544]	train-mlogloss:0.521342
# [545]	train-mlogloss:0.521272
# [546]	train-mlogloss:0.521171
# [547]	train-mlogloss:0.521064
# [548]	train-mlogloss:0.52097
# [549]	train-mlogloss:0.520889
# [550]	train-mlogloss:0.520801
# [551]	train-mlogloss:0.520727
# [552]	train-mlogloss:0.520638
# [553]	train-mlogloss:0.520549
# [554]	train-mlogloss:0.520451
# [555]	train-mlogloss:0.520363
# [556]	train-mlogloss:0.520276
# [557]	train-mlogloss:0.520176
# [558]	train-mlogloss:0.520105
# [559]	train-mlogloss:0.51999
# [560]	train-mlogloss:0.519888
# [561]	train-mlogloss:0.519798
# [562]	train-mlogloss:0.519699
# [563]	train-mlogloss:0.519626
# [564]	train-mlogloss:0.519536
# [565]	train-mlogloss:0.519443
# [566]	train-mlogloss:0.519362
# [567]	train-mlogloss:0.519291
# [568]	train-mlogloss:0.51921
# [569]	train-mlogloss:0.519131
# [570]	train-mlogloss:0.519035
# [571]	train-mlogloss:0.518955
# [572]	train-mlogloss:0.518874
# [573]	train-mlogloss:0.518768
# [574]	train-mlogloss:0.518679
# [575]	train-mlogloss:0.518589
# [576]	train-mlogloss:0.518518
# [577]	train-mlogloss:0.518447
# [578]	train-mlogloss:0.518372
# [579]	train-mlogloss:0.51831
# [580]	train-mlogloss:0.518239
# [581]	train-mlogloss:0.518181
# [582]	train-mlogloss:0.518074
# [583]	train-mlogloss:0.517977
# [584]	train-mlogloss:0.51787
# [585]	train-mlogloss:0.517784
# [586]	train-mlogloss:0.51772
# [587]	train-mlogloss:0.517648
# [588]	train-mlogloss:0.51754
# [589]	train-mlogloss:0.517451
# [590]	train-mlogloss:0.517367
# [591]	train-mlogloss:0.517286
# [592]	train-mlogloss:0.517193
# [593]	train-mlogloss:0.517098
# [594]	train-mlogloss:0.516991
# [595]	train-mlogloss:0.516917
# [596]	train-mlogloss:0.516832
# [597]	train-mlogloss:0.516754
# [598]	train-mlogloss:0.516668
# [599]	train-mlogloss:0.516584
# [600]	train-mlogloss:0.51651
# [601]	train-mlogloss:0.516436
# [602]	train-mlogloss:0.516341
# [603]	train-mlogloss:0.51625
# [604]	train-mlogloss:0.516181
# [605]	train-mlogloss:0.516088
# [606]	train-mlogloss:0.516
# [607]	train-mlogloss:0.515923
# [608]	train-mlogloss:0.515841
# [609]	train-mlogloss:0.51575
# [610]	train-mlogloss:0.515677
# [611]	train-mlogloss:0.515624
# [612]	train-mlogloss:0.51556
# [613]	train-mlogloss:0.515467
# [614]	train-mlogloss:0.515393
# [615]	train-mlogloss:0.515337
# [616]	train-mlogloss:0.515273
# [617]	train-mlogloss:0.515202
# [618]	train-mlogloss:0.515133
# [619]	train-mlogloss:0.515078
# [620]	train-mlogloss:0.515003
# [621]	train-mlogloss:0.514923
# [622]	train-mlogloss:0.514844
# [623]	train-mlogloss:0.514767
# [624]	train-mlogloss:0.514692
# [625]	train-mlogloss:0.514609
# [626]	train-mlogloss:0.514528
# [627]	train-mlogloss:0.514467
# [628]	train-mlogloss:0.514392
# [629]	train-mlogloss:0.514299
# [630]	train-mlogloss:0.5142
# [631]	train-mlogloss:0.514135
# [632]	train-mlogloss:0.514051
# [633]	train-mlogloss:0.513945
# [634]	train-mlogloss:0.513854
# [635]	train-mlogloss:0.513789
# [636]	train-mlogloss:0.513722
# [637]	train-mlogloss:0.513647
# [638]	train-mlogloss:0.513585
# [639]	train-mlogloss:0.513519
# [640]	train-mlogloss:0.513445
# [641]	train-mlogloss:0.513373
# [642]	train-mlogloss:0.513305
# [643]	train-mlogloss:0.513232
# [644]	train-mlogloss:0.513162
# [645]	train-mlogloss:0.51309
# [646]	train-mlogloss:0.513006
# [647]	train-mlogloss:0.512926
# [648]	train-mlogloss:0.51285
# [649]	train-mlogloss:0.512789
# [650]	train-mlogloss:0.512714
# [651]	train-mlogloss:0.51266
# [652]	train-mlogloss:0.512607
# [653]	train-mlogloss:0.512512
# [654]	train-mlogloss:0.512428
# [655]	train-mlogloss:0.512328
# [656]	train-mlogloss:0.512252
# [657]	train-mlogloss:0.512166
# [658]	train-mlogloss:0.512118
# [659]	train-mlogloss:0.512058
# [660]	train-mlogloss:0.511979
# [661]	train-mlogloss:0.511901
# [662]	train-mlogloss:0.511811
# [663]	train-mlogloss:0.511745
# [664]	train-mlogloss:0.511667
# [665]	train-mlogloss:0.511602
# [666]	train-mlogloss:0.511526
# [667]	train-mlogloss:0.511453
# [668]	train-mlogloss:0.51139
# [669]	train-mlogloss:0.511305
# [670]	train-mlogloss:0.511256
# [671]	train-mlogloss:0.511178
# [672]	train-mlogloss:0.511122
# [673]	train-mlogloss:0.511071
# [674]	train-mlogloss:0.511012
# [675]	train-mlogloss:0.510964
# [676]	train-mlogloss:0.510881
# [677]	train-mlogloss:0.510795
# [678]	train-mlogloss:0.510704
# [679]	train-mlogloss:0.51063
# [680]	train-mlogloss:0.510546
# [681]	train-mlogloss:0.510489
# [682]	train-mlogloss:0.510417
# [683]	train-mlogloss:0.510363
# [684]	train-mlogloss:0.510296
# [685]	train-mlogloss:0.5102
# [686]	train-mlogloss:0.510131
# [687]	train-mlogloss:0.510062
# [688]	train-mlogloss:0.509977
# [689]	train-mlogloss:0.509936
# [690]	train-mlogloss:0.509867
# [691]	train-mlogloss:0.509796
# [692]	train-mlogloss:0.509729
# [693]	train-mlogloss:0.509656
# [694]	train-mlogloss:0.509577
# [695]	train-mlogloss:0.509496
# [696]	train-mlogloss:0.50941
# [697]	train-mlogloss:0.50933
# [698]	train-mlogloss:0.50923
# [699]	train-mlogloss:0.509156
# [700]	train-mlogloss:0.509087
# [701]	train-mlogloss:0.509017
# [702]	train-mlogloss:0.508916
# [703]	train-mlogloss:0.508851
# [704]	train-mlogloss:0.50878
# [705]	train-mlogloss:0.508685
# [706]	train-mlogloss:0.508642
# [707]	train-mlogloss:0.508555
# [708]	train-mlogloss:0.50849
# [709]	train-mlogloss:0.508405
# [710]	train-mlogloss:0.508325
# [711]	train-mlogloss:0.508267
# [712]	train-mlogloss:0.50818
# [713]	train-mlogloss:0.508113
# [714]	train-mlogloss:0.508048
# [715]	train-mlogloss:0.507978
# [716]	train-mlogloss:0.507903
# [717]	train-mlogloss:0.507846
# [718]	train-mlogloss:0.507773
# [719]	train-mlogloss:0.5077
# [720]	train-mlogloss:0.507649
# [721]	train-mlogloss:0.507595
# [722]	train-mlogloss:0.507531
# [723]	train-mlogloss:0.507483
# [724]	train-mlogloss:0.50742
# [725]	train-mlogloss:0.507339
# [726]	train-mlogloss:0.507269
# [727]	train-mlogloss:0.507196
# [728]	train-mlogloss:0.507137
# [729]	train-mlogloss:0.507072
# [730]	train-mlogloss:0.506989
# [731]	train-mlogloss:0.506913
# [732]	train-mlogloss:0.506854
# [733]	train-mlogloss:0.506796
# [734]	train-mlogloss:0.506735
# [735]	train-mlogloss:0.506677
# [736]	train-mlogloss:0.506618
# [737]	train-mlogloss:0.506544
# [738]	train-mlogloss:0.506469
# [739]	train-mlogloss:0.506404
# [740]	train-mlogloss:0.506335
# [741]	train-mlogloss:0.506251
# [742]	train-mlogloss:0.506172
# [743]	train-mlogloss:0.50612
# [744]	train-mlogloss:0.506052
# [745]	train-mlogloss:0.505978
# [746]	train-mlogloss:0.505925
# [747]	train-mlogloss:0.505851
# [748]	train-mlogloss:0.505777
# [749]	train-mlogloss:0.505722
# [750]	train-mlogloss:0.50568
# [751]	train-mlogloss:0.505613
# [752]	train-mlogloss:0.505527
# [753]	train-mlogloss:0.505465
# [754]	train-mlogloss:0.505405
# [755]	train-mlogloss:0.505326
# [756]	train-mlogloss:0.50527
# [757]	train-mlogloss:0.505192
# [758]	train-mlogloss:0.505116
# [759]	train-mlogloss:0.505045
# [760]	train-mlogloss:0.504975
# [761]	train-mlogloss:0.504885
# [762]	train-mlogloss:0.504813
# [763]	train-mlogloss:0.504745
# [764]	train-mlogloss:0.504655
# [765]	train-mlogloss:0.504599
# [766]	train-mlogloss:0.504538
# [767]	train-mlogloss:0.504472
# [768]	train-mlogloss:0.504416
# [769]	train-mlogloss:0.50435
# [770]	train-mlogloss:0.504307
# [771]	train-mlogloss:0.504246
# [772]	train-mlogloss:0.504186
# [773]	train-mlogloss:0.504131
# [774]	train-mlogloss:0.504059
# [775]	train-mlogloss:0.503998
# [776]	train-mlogloss:0.503928
# [777]	train-mlogloss:0.503871
# [778]	train-mlogloss:0.503806
# [779]	train-mlogloss:0.503737
# [780]	train-mlogloss:0.503693
# [781]	train-mlogloss:0.50363
# [782]	train-mlogloss:0.503556
# [783]	train-mlogloss:0.503508
# [784]	train-mlogloss:0.503445
# [785]	train-mlogloss:0.503371
# [786]	train-mlogloss:0.503302
# [787]	train-mlogloss:0.503238
# [788]	train-mlogloss:0.50319
# [789]	train-mlogloss:0.503134
# [790]	train-mlogloss:0.503064
# [791]	train-mlogloss:0.503009
# [792]	train-mlogloss:0.502946
# [793]	train-mlogloss:0.502892
# [794]	train-mlogloss:0.50284
# [795]	train-mlogloss:0.502769
# [796]	train-mlogloss:0.502701
# [797]	train-mlogloss:0.502641
# [798]	train-mlogloss:0.502573
# [799]	train-mlogloss:0.502521
# [800]	train-mlogloss:0.502453
# [801]	train-mlogloss:0.502412
# [802]	train-mlogloss:0.502357
# [803]	train-mlogloss:0.502293
# [804]	train-mlogloss:0.502209
# [805]	train-mlogloss:0.502167
# [806]	train-mlogloss:0.50211
# [807]	train-mlogloss:0.502055
# [808]	train-mlogloss:0.501987
# [809]	train-mlogloss:0.501932
# [810]	train-mlogloss:0.501873
# [811]	train-mlogloss:0.501815
# [812]	train-mlogloss:0.501754
# [813]	train-mlogloss:0.501691
# [814]	train-mlogloss:0.50163
# [815]	train-mlogloss:0.501582
# [816]	train-mlogloss:0.501524
# [817]	train-mlogloss:0.501461
# [818]	train-mlogloss:0.501412
# [819]	train-mlogloss:0.501343
# [820]	train-mlogloss:0.501278
# [821]	train-mlogloss:0.501227
# [822]	train-mlogloss:0.501154
# [823]	train-mlogloss:0.501094
# [824]	train-mlogloss:0.501038
# [825]	train-mlogloss:0.500982
# [826]	train-mlogloss:0.500935
# [827]	train-mlogloss:0.500879
# [828]	train-mlogloss:0.500828
# [829]	train-mlogloss:0.500763
# [830]	train-mlogloss:0.500692
# [831]	train-mlogloss:0.50064
# [832]	train-mlogloss:0.500564
# [833]	train-mlogloss:0.500498
# [834]	train-mlogloss:0.500437
# [835]	train-mlogloss:0.500365
# [836]	train-mlogloss:0.500312
# [837]	train-mlogloss:0.500246
# [838]	train-mlogloss:0.500202
# [839]	train-mlogloss:0.500116
# [840]	train-mlogloss:0.500058
# [841]	train-mlogloss:0.499972
# [842]	train-mlogloss:0.499899
# [843]	train-mlogloss:0.499843
# [844]	train-mlogloss:0.499776
# [845]	train-mlogloss:0.499712
# [846]	train-mlogloss:0.499651
# [847]	train-mlogloss:0.499572
# [848]	train-mlogloss:0.499495
# [849]	train-mlogloss:0.499416
# [850]	train-mlogloss:0.499354
# [851]	train-mlogloss:0.499313
# [852]	train-mlogloss:0.499249
# [853]	train-mlogloss:0.499178
# [854]	train-mlogloss:0.499109
# [855]	train-mlogloss:0.499044
# [856]	train-mlogloss:0.498975
# [857]	train-mlogloss:0.49892
# [858]	train-mlogloss:0.49884
# [859]	train-mlogloss:0.498766
# [860]	train-mlogloss:0.498719
# [861]	train-mlogloss:0.498676
# [862]	train-mlogloss:0.498601
# [863]	train-mlogloss:0.498529
# [864]	train-mlogloss:0.49847
# [865]	train-mlogloss:0.49842
# [866]	train-mlogloss:0.498359
# [867]	train-mlogloss:0.498308
# [868]	train-mlogloss:0.498243
# [869]	train-mlogloss:0.49819
# [870]	train-mlogloss:0.498127
# [871]	train-mlogloss:0.498065
# [872]	train-mlogloss:0.49801
# [873]	train-mlogloss:0.497969
# [874]	train-mlogloss:0.497917
# [875]	train-mlogloss:0.497855
# [876]	train-mlogloss:0.497799
# [877]	train-mlogloss:0.497744
# [878]	train-mlogloss:0.497691
# [879]	train-mlogloss:0.497623
# [880]	train-mlogloss:0.497556
# [881]	train-mlogloss:0.497498
# [882]	train-mlogloss:0.497418
# [883]	train-mlogloss:0.497359
# [884]	train-mlogloss:0.497313
# [885]	train-mlogloss:0.49725
# [886]	train-mlogloss:0.497185
# [887]	train-mlogloss:0.497131
# [888]	train-mlogloss:0.497064
# [889]	train-mlogloss:0.497004
# [890]	train-mlogloss:0.496943
# [891]	train-mlogloss:0.496891
# [892]	train-mlogloss:0.496833
# [893]	train-mlogloss:0.496786
# [894]	train-mlogloss:0.496727
# [895]	train-mlogloss:0.496676
# [896]	train-mlogloss:0.496616
# [897]	train-mlogloss:0.496573
# [898]	train-mlogloss:0.496516
# [899]	train-mlogloss:0.496467
# [900]	train-mlogloss:0.496405
# [901]	train-mlogloss:0.496356
# [902]	train-mlogloss:0.496309
# [903]	train-mlogloss:0.496245
# [904]	train-mlogloss:0.496205
# [905]	train-mlogloss:0.496136
# [906]	train-mlogloss:0.496073
# [907]	train-mlogloss:0.496025
# [908]	train-mlogloss:0.495948
# [909]	train-mlogloss:0.495895
# [910]	train-mlogloss:0.495829
# [911]	train-mlogloss:0.495787
# [912]	train-mlogloss:0.49572
# [913]	train-mlogloss:0.495667
# [914]	train-mlogloss:0.495601
# [915]	train-mlogloss:0.495535
# [916]	train-mlogloss:0.495481
# [917]	train-mlogloss:0.495425
# [918]	train-mlogloss:0.495354
# [919]	train-mlogloss:0.495316
# [920]	train-mlogloss:0.495244
# [921]	train-mlogloss:0.49517
# [922]	train-mlogloss:0.495116
# [923]	train-mlogloss:0.495039
# [924]	train-mlogloss:0.494957
# [925]	train-mlogloss:0.494902
# [926]	train-mlogloss:0.494847
# [927]	train-mlogloss:0.49479
# [928]	train-mlogloss:0.494735
# [929]	train-mlogloss:0.494661
# [930]	train-mlogloss:0.494601
# [931]	train-mlogloss:0.49454
# [932]	train-mlogloss:0.494484
# [933]	train-mlogloss:0.494432
# [934]	train-mlogloss:0.494394
# [935]	train-mlogloss:0.49436
# [936]	train-mlogloss:0.494297
# [937]	train-mlogloss:0.494243
# [938]	train-mlogloss:0.494178
# [939]	train-mlogloss:0.49411
# [940]	train-mlogloss:0.494051
# [941]	train-mlogloss:0.494005
# [942]	train-mlogloss:0.493939
# [943]	train-mlogloss:0.493877
# [944]	train-mlogloss:0.493809
# [945]	train-mlogloss:0.493752
# [946]	train-mlogloss:0.493708
# [947]	train-mlogloss:0.493659
# [948]	train-mlogloss:0.493612
# [949]	train-mlogloss:0.493582
# [950]	train-mlogloss:0.493515
# [951]	train-mlogloss:0.493461
# [952]	train-mlogloss:0.49341
# [953]	train-mlogloss:0.493362
# [954]	train-mlogloss:0.493314
# [955]	train-mlogloss:0.493268
# [956]	train-mlogloss:0.49321
# [957]	train-mlogloss:0.493157
# [958]	train-mlogloss:0.493108
# [959]	train-mlogloss:0.49305
# [960]	train-mlogloss:0.493
# [961]	train-mlogloss:0.492959
# [962]	train-mlogloss:0.492901
# [963]	train-mlogloss:0.49284
# [964]	train-mlogloss:0.492776
# [965]	train-mlogloss:0.492721
# [966]	train-mlogloss:0.492668
# [967]	train-mlogloss:0.492616
# [968]	train-mlogloss:0.492559
# [969]	train-mlogloss:0.492519
# [970]	train-mlogloss:0.492454
# [971]	train-mlogloss:0.492382
# [972]	train-mlogloss:0.492328
# [973]	train-mlogloss:0.492274
# [974]	train-mlogloss:0.492229
# [975]	train-mlogloss:0.492154
# [976]	train-mlogloss:0.492109
# [977]	train-mlogloss:0.492064
# [978]	train-mlogloss:0.491989
# [979]	train-mlogloss:0.491936
# [980]	train-mlogloss:0.491884
# [981]	train-mlogloss:0.49182
# [982]	train-mlogloss:0.49175
# [983]	train-mlogloss:0.491688
# [984]	train-mlogloss:0.491626
# [985]	train-mlogloss:0.491587
# [986]	train-mlogloss:0.491521
# [987]	train-mlogloss:0.491495
# [988]	train-mlogloss:0.491415
# [989]	train-mlogloss:0.491365
# [990]	train-mlogloss:0.491306
# [991]	train-mlogloss:0.491258
# [992]	train-mlogloss:0.4912
# [993]	train-mlogloss:0.491146
# [994]	train-mlogloss:0.491106
# [995]	train-mlogloss:0.491052
# [996]	train-mlogloss:0.491015
# [997]	train-mlogloss:0.490966
# [998]	train-mlogloss:0.490918
# [999]	train-mlogloss:0.490875
# [1000]	train-mlogloss:0.49083
# [1001]	train-mlogloss:0.49075
# [1002]	train-mlogloss:0.4907
# [1003]	train-mlogloss:0.49064
# [1004]	train-mlogloss:0.490577
# [1005]	train-mlogloss:0.490532
# [1006]	train-mlogloss:0.490474
# [1007]	train-mlogloss:0.490406
# [1008]	train-mlogloss:0.490335
# [1009]	train-mlogloss:0.490278
# [1010]	train-mlogloss:0.490223
# [1011]	train-mlogloss:0.490171
# [1012]	train-mlogloss:0.490111
# [1013]	train-mlogloss:0.490063
# [1014]	train-mlogloss:0.490015
# [1015]	train-mlogloss:0.489956
# [1016]	train-mlogloss:0.48992
# [1017]	train-mlogloss:0.48986
# [1018]	train-mlogloss:0.489804
# [1019]	train-mlogloss:0.48976
# [1020]	train-mlogloss:0.48972
# [1021]	train-mlogloss:0.489665
# [1022]	train-mlogloss:0.489614
# [1023]	train-mlogloss:0.489567
# [1024]	train-mlogloss:0.489514
# [1025]	train-mlogloss:0.489464
# [1026]	train-mlogloss:0.48942
# [1027]	train-mlogloss:0.489369
# [1028]	train-mlogloss:0.489292
# [1029]	train-mlogloss:0.489245
# [1030]	train-mlogloss:0.489184
# [1031]	train-mlogloss:0.489137
# [1032]	train-mlogloss:0.489078
# [1033]	train-mlogloss:0.489031
# [1034]	train-mlogloss:0.488985
# [1035]	train-mlogloss:0.48894
# [1036]	train-mlogloss:0.488879
# [1037]	train-mlogloss:0.488828
# [1038]	train-mlogloss:0.48877
# [1039]	train-mlogloss:0.48872
# [1040]	train-mlogloss:0.488654
# [1041]	train-mlogloss:0.488611
# [1042]	train-mlogloss:0.488573
# [1043]	train-mlogloss:0.488515
# [1044]	train-mlogloss:0.488467
# [1045]	train-mlogloss:0.488416
# [1046]	train-mlogloss:0.488375
# [1047]	train-mlogloss:0.488332
# [1048]	train-mlogloss:0.488271
# [1049]	train-mlogloss:0.488225
# [1050]	train-mlogloss:0.488179
# [1051]	train-mlogloss:0.488127
# [1052]	train-mlogloss:0.488039
# [1053]	train-mlogloss:0.487996
# [1054]	train-mlogloss:0.487938
# [1055]	train-mlogloss:0.487892
# [1056]	train-mlogloss:0.487857
# [1057]	train-mlogloss:0.487804
# [1058]	train-mlogloss:0.487749
# [1059]	train-mlogloss:0.487703
# [1060]	train-mlogloss:0.487657
# [1061]	train-mlogloss:0.487608
# [1062]	train-mlogloss:0.48756
# [1063]	train-mlogloss:0.487507
# [1064]	train-mlogloss:0.487437
# [1065]	train-mlogloss:0.487373
# [1066]	train-mlogloss:0.487306
# [1067]	train-mlogloss:0.487254
# [1068]	train-mlogloss:0.487197
# [1069]	train-mlogloss:0.487141
# [1070]	train-mlogloss:0.487073
# [1071]	train-mlogloss:0.487016
# [1072]	train-mlogloss:0.486977
# [1073]	train-mlogloss:0.486914
# [1074]	train-mlogloss:0.486842
# [1075]	train-mlogloss:0.486775
# [1076]	train-mlogloss:0.486719
# [1077]	train-mlogloss:0.486671
# [1078]	train-mlogloss:0.486615
# [1079]	train-mlogloss:0.486565
# [1080]	train-mlogloss:0.48651
# [1081]	train-mlogloss:0.486463
# [1082]	train-mlogloss:0.48641
# [1083]	train-mlogloss:0.486357
# [1084]	train-mlogloss:0.486314
# [1085]	train-mlogloss:0.486266
# [1086]	train-mlogloss:0.486217
# [1087]	train-mlogloss:0.486149
# [1088]	train-mlogloss:0.486085
# [1089]	train-mlogloss:0.486036
# [1090]	train-mlogloss:0.485989
# [1091]	train-mlogloss:0.485941
# [1092]	train-mlogloss:0.485897
# [1093]	train-mlogloss:0.485856
# [1094]	train-mlogloss:0.485805
# [1095]	train-mlogloss:0.485759
# [1096]	train-mlogloss:0.485697
# [1097]	train-mlogloss:0.485644
# [1098]	train-mlogloss:0.485582
# [1099]	train-mlogloss:0.485512
# [1100]	train-mlogloss:0.485465
# [1101]	train-mlogloss:0.485433
# [1102]	train-mlogloss:0.485376
# [1103]	train-mlogloss:0.485336
# [1104]	train-mlogloss:0.485279
# [1105]	train-mlogloss:0.485225
# [1106]	train-mlogloss:0.485188
# [1107]	train-mlogloss:0.485143
# [1108]	train-mlogloss:0.485098
# [1109]	train-mlogloss:0.485042
# [1110]	train-mlogloss:0.484978
# [1111]	train-mlogloss:0.484932
# [1112]	train-mlogloss:0.48486
# [1113]	train-mlogloss:0.484802
# [1114]	train-mlogloss:0.484757
# [1115]	train-mlogloss:0.484691
# [1116]	train-mlogloss:0.48463
# [1117]	train-mlogloss:0.484579
# [1118]	train-mlogloss:0.484518
# [1119]	train-mlogloss:0.48446
# [1120]	train-mlogloss:0.484407
# [1121]	train-mlogloss:0.484356
# [1122]	train-mlogloss:0.48432
# [1123]	train-mlogloss:0.484277
# [1124]	train-mlogloss:0.484227
# [1125]	train-mlogloss:0.484181
# [1126]	train-mlogloss:0.484132
# [1127]	train-mlogloss:0.484075
# [1128]	train-mlogloss:0.484032
# [1129]	train-mlogloss:0.483972
# [1130]	train-mlogloss:0.48392
# [1131]	train-mlogloss:0.48389
# [1132]	train-mlogloss:0.483844
# [1133]	train-mlogloss:0.483802
# [1134]	train-mlogloss:0.483745
# [1135]	train-mlogloss:0.483673
# [1136]	train-mlogloss:0.483624
# [1137]	train-mlogloss:0.483576
# [1138]	train-mlogloss:0.483522
# [1139]	train-mlogloss:0.483458
# [1140]	train-mlogloss:0.483404
# [1141]	train-mlogloss:0.483349
# [1142]	train-mlogloss:0.483312
# [1143]	train-mlogloss:0.483265
# [1144]	train-mlogloss:0.483211
# [1145]	train-mlogloss:0.483163
# [1146]	train-mlogloss:0.483111
# [1147]	train-mlogloss:0.483064
# [1148]	train-mlogloss:0.483002
# [1149]	train-mlogloss:0.482956
# [1150]	train-mlogloss:0.48292
# [1151]	train-mlogloss:0.482874
# [1152]	train-mlogloss:0.482832
# [1153]	train-mlogloss:0.48278
# [1154]	train-mlogloss:0.482709
# [1155]	train-mlogloss:0.482647
# [1156]	train-mlogloss:0.482594
# [1157]	train-mlogloss:0.482544
# [1158]	train-mlogloss:0.482497
# [1159]	train-mlogloss:0.482446
# [1160]	train-mlogloss:0.482395
# [1161]	train-mlogloss:0.482354
# [1162]	train-mlogloss:0.482298
# [1163]	train-mlogloss:0.482239
# [1164]	train-mlogloss:0.482183
# [1165]	train-mlogloss:0.482126
# [1166]	train-mlogloss:0.482077
# [1167]	train-mlogloss:0.482026
# [1168]	train-mlogloss:0.481981
# [1169]	train-mlogloss:0.481916
# [1170]	train-mlogloss:0.481856
# [1171]	train-mlogloss:0.481812
# [1172]	train-mlogloss:0.481768
# [1173]	train-mlogloss:0.481714
# [1174]	train-mlogloss:0.481672
# [1175]	train-mlogloss:0.481611
# [1176]	train-mlogloss:0.481572
# [1177]	train-mlogloss:0.481528
# [1178]	train-mlogloss:0.481481
# [1179]	train-mlogloss:0.481425
# [1180]	train-mlogloss:0.481376
# [1181]	train-mlogloss:0.481315
# [1182]	train-mlogloss:0.48127
# [1183]	train-mlogloss:0.481206
# [1184]	train-mlogloss:0.481162
# [1185]	train-mlogloss:0.481134
# [1186]	train-mlogloss:0.481105
# [1187]	train-mlogloss:0.481055
# [1188]	train-mlogloss:0.481012
# [1189]	train-mlogloss:0.480959
# [1190]	train-mlogloss:0.480913
# [1191]	train-mlogloss:0.480855
# [1192]	train-mlogloss:0.480794
# [1193]	train-mlogloss:0.480743
# [1194]	train-mlogloss:0.480701
# [1195]	train-mlogloss:0.480651
# [1196]	train-mlogloss:0.480616
# [1197]	train-mlogloss:0.480565
# [1198]	train-mlogloss:0.480532
# [1199]	train-mlogloss:0.480478
# [1200]	train-mlogloss:0.480435
# [1201]	train-mlogloss:0.480396
# [1202]	train-mlogloss:0.480339
# [1203]	train-mlogloss:0.480281
# [1204]	train-mlogloss:0.480231
# [1205]	train-mlogloss:0.480192
# [1206]	train-mlogloss:0.48015
# [1207]	train-mlogloss:0.480106
# [1208]	train-mlogloss:0.480047
# [1209]	train-mlogloss:0.480004
# [1210]	train-mlogloss:0.479971
# [1211]	train-mlogloss:0.479913
# [1212]	train-mlogloss:0.479859
# [1213]	train-mlogloss:0.47982
# [1214]	train-mlogloss:0.479762
# [1215]	train-mlogloss:0.479715
# [1216]	train-mlogloss:0.479679
# [1217]	train-mlogloss:0.479643
# [1218]	train-mlogloss:0.479602
# [1219]	train-mlogloss:0.479553
# [1220]	train-mlogloss:0.479503
# [1221]	train-mlogloss:0.479456
# [1222]	train-mlogloss:0.479408
# [1223]	train-mlogloss:0.479367
# [1224]	train-mlogloss:0.479326
# [1225]	train-mlogloss:0.479278
# [1226]	train-mlogloss:0.479213
# [1227]	train-mlogloss:0.479178
# [1228]	train-mlogloss:0.479126
# [1229]	train-mlogloss:0.479086
# [1230]	train-mlogloss:0.479046
# [1231]	train-mlogloss:0.479003
# [1232]	train-mlogloss:0.478954
# [1233]	train-mlogloss:0.478921
# [1234]	train-mlogloss:0.478888
# [1235]	train-mlogloss:0.478846
# [1236]	train-mlogloss:0.478796
# [1237]	train-mlogloss:0.478735
# [1238]	train-mlogloss:0.478672
# [1239]	train-mlogloss:0.478628
# [1240]	train-mlogloss:0.478584
# [1241]	train-mlogloss:0.47853
# [1242]	train-mlogloss:0.478467
# [1243]	train-mlogloss:0.478412
# [1244]	train-mlogloss:0.478364
# [1245]	train-mlogloss:0.478316
# [1246]	train-mlogloss:0.478252
# [1247]	train-mlogloss:0.478213
# [1248]	train-mlogloss:0.478167
# [1249]	train-mlogloss:0.478106
# [1250]	train-mlogloss:0.478035
# [1251]	train-mlogloss:0.477988
# [1252]	train-mlogloss:0.477921
# [1253]	train-mlogloss:0.47787
# [1254]	train-mlogloss:0.477806
# [1255]	train-mlogloss:0.477773
# [1256]	train-mlogloss:0.477725
# [1257]	train-mlogloss:0.47768
# [1258]	train-mlogloss:0.47764
# [1259]	train-mlogloss:0.477588
# [1260]	train-mlogloss:0.477541
# [1261]	train-mlogloss:0.477494
# [1262]	train-mlogloss:0.47745
# [1263]	train-mlogloss:0.477408
# [1264]	train-mlogloss:0.477352
# [1265]	train-mlogloss:0.477309
# [1266]	train-mlogloss:0.477249
# [1267]	train-mlogloss:0.477212
# [1268]	train-mlogloss:0.477153
# [1269]	train-mlogloss:0.477101
# [1270]	train-mlogloss:0.477059
# [1271]	train-mlogloss:0.477023
# [1272]	train-mlogloss:0.476957
# [1273]	train-mlogloss:0.476921
# [1274]	train-mlogloss:0.476875
# [1275]	train-mlogloss:0.476826
# [1276]	train-mlogloss:0.47678
# [1277]	train-mlogloss:0.476733
# [1278]	train-mlogloss:0.476682
# [1279]	train-mlogloss:0.476637
# [1280]	train-mlogloss:0.476586
# [1281]	train-mlogloss:0.476539
# [1282]	train-mlogloss:0.476501
# [1283]	train-mlogloss:0.476448
# [1284]	train-mlogloss:0.476395
# [1285]	train-mlogloss:0.476357
# [1286]	train-mlogloss:0.476291
# [1287]	train-mlogloss:0.476239
# [1288]	train-mlogloss:0.476175
# [1289]	train-mlogloss:0.476125
# [1290]	train-mlogloss:0.476085
# [1291]	train-mlogloss:0.476037
# [1292]	train-mlogloss:0.475993
# [1293]	train-mlogloss:0.475941
# [1294]	train-mlogloss:0.475893
# [1295]	train-mlogloss:0.475837
# [1296]	train-mlogloss:0.475798
# [1297]	train-mlogloss:0.475736
# [1298]	train-mlogloss:0.475679
# [1299]	train-mlogloss:0.475632
# [1300]	train-mlogloss:0.475568
# [1301]	train-mlogloss:0.475519
# [1302]	train-mlogloss:0.475476
# [1303]	train-mlogloss:0.475424
# [1304]	train-mlogloss:0.475373
# [1305]	train-mlogloss:0.475314
# [1306]	train-mlogloss:0.475268
# [1307]	train-mlogloss:0.475222
# [1308]	train-mlogloss:0.475186
# [1309]	train-mlogloss:0.475151
# [1310]	train-mlogloss:0.475107
# [1311]	train-mlogloss:0.475052
# [1312]	train-mlogloss:0.474984
# [1313]	train-mlogloss:0.47494
# [1314]	train-mlogloss:0.474892
# [1315]	train-mlogloss:0.474843
# [1316]	train-mlogloss:0.474786
# [1317]	train-mlogloss:0.474723
# [1318]	train-mlogloss:0.474674
# [1319]	train-mlogloss:0.474614
# [1320]	train-mlogloss:0.474563
# [1321]	train-mlogloss:0.474523
# [1322]	train-mlogloss:0.474494
# [1323]	train-mlogloss:0.474442
# [1324]	train-mlogloss:0.474398
# [1325]	train-mlogloss:0.474359
# [1326]	train-mlogloss:0.474315
# [1327]	train-mlogloss:0.474272
# [1328]	train-mlogloss:0.47424
# [1329]	train-mlogloss:0.474193
# [1330]	train-mlogloss:0.474144
# [1331]	train-mlogloss:0.4741
# [1332]	train-mlogloss:0.474066
# [1333]	train-mlogloss:0.474031
# [1334]	train-mlogloss:0.473973
# [1335]	train-mlogloss:0.473944
# [1336]	train-mlogloss:0.473891
# [1337]	train-mlogloss:0.473864
# [1338]	train-mlogloss:0.473831
# [1339]	train-mlogloss:0.473786
# [1340]	train-mlogloss:0.473738
# [1341]	train-mlogloss:0.473689
# [1342]	train-mlogloss:0.473649
# [1343]	train-mlogloss:0.473595
# [1344]	train-mlogloss:0.473564
# [1345]	train-mlogloss:0.473514
# [1346]	train-mlogloss:0.473464
# [1347]	train-mlogloss:0.47342
# [1348]	train-mlogloss:0.473395
# [1349]	train-mlogloss:0.473348
# [1350]	train-mlogloss:0.473291
# [1351]	train-mlogloss:0.473243
# [1352]	train-mlogloss:0.473207
# [1353]	train-mlogloss:0.473156
# [1354]	train-mlogloss:0.473103
# [1355]	train-mlogloss:0.473063
# [1356]	train-mlogloss:0.473027
# [1357]	train-mlogloss:0.472991
# [1358]	train-mlogloss:0.47296
# [1359]	train-mlogloss:0.472916
# [1360]	train-mlogloss:0.472867
# [1361]	train-mlogloss:0.472822
# [1362]	train-mlogloss:0.47278
# [1363]	train-mlogloss:0.472736
# [1364]	train-mlogloss:0.472685
# [1365]	train-mlogloss:0.472632
# [1366]	train-mlogloss:0.47258
# [1367]	train-mlogloss:0.472526
# [1368]	train-mlogloss:0.472481
# [1369]	train-mlogloss:0.47243
# [1370]	train-mlogloss:0.472389
# [1371]	train-mlogloss:0.472331
# [1372]	train-mlogloss:0.472295
# [1373]	train-mlogloss:0.472243
# [1374]	train-mlogloss:0.472185
# [1375]	train-mlogloss:0.472142
# [1376]	train-mlogloss:0.472095
# [1377]	train-mlogloss:0.472046
# [1378]	train-mlogloss:0.471995
# [1379]	train-mlogloss:0.471951
# [1380]	train-mlogloss:0.471913
# [1381]	train-mlogloss:0.471866
# [1382]	train-mlogloss:0.471822
# [1383]	train-mlogloss:0.471776
# [1384]	train-mlogloss:0.471741
# [1385]	train-mlogloss:0.471696
# [1386]	train-mlogloss:0.471645
# [1387]	train-mlogloss:0.471602
# [1388]	train-mlogloss:0.471546
# [1389]	train-mlogloss:0.471497
# [1390]	train-mlogloss:0.471451
# [1391]	train-mlogloss:0.471406
# [1392]	train-mlogloss:0.471361
# [1393]	train-mlogloss:0.471318
# [1394]	train-mlogloss:0.471269
# [1395]	train-mlogloss:0.471227
# [1396]	train-mlogloss:0.471186
# [1397]	train-mlogloss:0.471146
# [1398]	train-mlogloss:0.471106
# [1399]	train-mlogloss:0.471056
# [1400]	train-mlogloss:0.47103
# [1401]	train-mlogloss:0.470974
# [1402]	train-mlogloss:0.470923
# [1403]	train-mlogloss:0.470884
# [1404]	train-mlogloss:0.470844
# [1405]	train-mlogloss:0.470807
# [1406]	train-mlogloss:0.470775
# [1407]	train-mlogloss:0.470726
# [1408]	train-mlogloss:0.470675
# [1409]	train-mlogloss:0.470613
# [1410]	train-mlogloss:0.470571
# [1411]	train-mlogloss:0.470515
# [1412]	train-mlogloss:0.47046
# [1413]	train-mlogloss:0.470401
# [1414]	train-mlogloss:0.470357
# [1415]	train-mlogloss:0.470311
# [1416]	train-mlogloss:0.470267
# [1417]	train-mlogloss:0.470208
# [1418]	train-mlogloss:0.470163
# [1419]	train-mlogloss:0.470127
# [1420]	train-mlogloss:0.47007
# [1421]	train-mlogloss:0.470038
# [1422]	train-mlogloss:0.469995
# [1423]	train-mlogloss:0.469957
# [1424]	train-mlogloss:0.469914
# [1425]	train-mlogloss:0.46988
# [1426]	train-mlogloss:0.469843
# [1427]	train-mlogloss:0.469797
# [1428]	train-mlogloss:0.469751
# [1429]	train-mlogloss:0.469705
# [1430]	train-mlogloss:0.469682
# [1431]	train-mlogloss:0.469632
# [1432]	train-mlogloss:0.469582
# [1433]	train-mlogloss:0.469553
# [1434]	train-mlogloss:0.469491
# [1435]	train-mlogloss:0.469441
# [1436]	train-mlogloss:0.469398
# [1437]	train-mlogloss:0.469371
# [1438]	train-mlogloss:0.469332
# [1439]	train-mlogloss:0.469295
# [1440]	train-mlogloss:0.469241
# [1441]	train-mlogloss:0.469201
# [1442]	train-mlogloss:0.469163
# [1443]	train-mlogloss:0.469129
# [1444]	train-mlogloss:0.469074
# [1445]	train-mlogloss:0.469029
# [1446]	train-mlogloss:0.468984
# [1447]	train-mlogloss:0.468949
# [1448]	train-mlogloss:0.468917
# [1449]	train-mlogloss:0.468859
# [1450]	train-mlogloss:0.468825
# [1451]	train-mlogloss:0.468785
# [1452]	train-mlogloss:0.46876
# [1453]	train-mlogloss:0.468723
# [1454]	train-mlogloss:0.468693
# [1455]	train-mlogloss:0.468652
# [1456]	train-mlogloss:0.468615
# [1457]	train-mlogloss:0.468563
# [1458]	train-mlogloss:0.468529
# [1459]	train-mlogloss:0.4685
# [1460]	train-mlogloss:0.468465
# [1461]	train-mlogloss:0.468407
# [1462]	train-mlogloss:0.468368
# [1463]	train-mlogloss:0.468316
# [1464]	train-mlogloss:0.468269
# [1465]	train-mlogloss:0.468225
# [1466]	train-mlogloss:0.468184
# [1467]	train-mlogloss:0.468145
# [1468]	train-mlogloss:0.468107
# [1469]	train-mlogloss:0.468068
# [1470]	train-mlogloss:0.468006
# [1471]	train-mlogloss:0.467959
# [1472]	train-mlogloss:0.467914
# [1473]	train-mlogloss:0.467862
# [1474]	train-mlogloss:0.46782
# [1475]	train-mlogloss:0.467774
# [1476]	train-mlogloss:0.467737
# [1477]	train-mlogloss:0.467697
# [1478]	train-mlogloss:0.467649
# [1479]	train-mlogloss:0.467605
# [1480]	train-mlogloss:0.467557
# [1481]	train-mlogloss:0.467515
# [1482]	train-mlogloss:0.467477
# [1483]	train-mlogloss:0.467437
# [1484]	train-mlogloss:0.467381
# [1485]	train-mlogloss:0.467332
# [1486]	train-mlogloss:0.467296
# [1487]	train-mlogloss:0.467248
# [1488]	train-mlogloss:0.467202
# [1489]	train-mlogloss:0.467159
# [1490]	train-mlogloss:0.467108
# [1491]	train-mlogloss:0.46708
# [1492]	train-mlogloss:0.467032
# [1493]	train-mlogloss:0.466993
# [1494]	train-mlogloss:0.466962
# [1495]	train-mlogloss:0.466909
# [1496]	train-mlogloss:0.466866
# [1497]	train-mlogloss:0.466816
# [1498]	train-mlogloss:0.466763
# [1499]	train-mlogloss:0.466718
# [1500]	train-mlogloss:0.466674
# [1501]	train-mlogloss:0.466626
# [1502]	train-mlogloss:0.466595
# [1503]	train-mlogloss:0.46656
# [1504]	train-mlogloss:0.466527
# [1505]	train-mlogloss:0.466483
# [1506]	train-mlogloss:0.466437
# [1507]	train-mlogloss:0.466381
# [1508]	train-mlogloss:0.46634
# [1509]	train-mlogloss:0.466305
# [1510]	train-mlogloss:0.466256
# [1511]	train-mlogloss:0.466217
# [1512]	train-mlogloss:0.466172
# [1513]	train-mlogloss:0.46615
# [1514]	train-mlogloss:0.466084
# [1515]	train-mlogloss:0.466043
# [1516]	train-mlogloss:0.465997
# [1517]	train-mlogloss:0.465962
# [1518]	train-mlogloss:0.465919
# [1519]	train-mlogloss:0.465855
# [1520]	train-mlogloss:0.465811
# [1521]	train-mlogloss:0.465774
# [1522]	train-mlogloss:0.465735
# [1523]	train-mlogloss:0.465687
# [1524]	train-mlogloss:0.465643
# [1525]	train-mlogloss:0.465596
# [1526]	train-mlogloss:0.465558
# [1527]	train-mlogloss:0.465516
# [1528]	train-mlogloss:0.46547
# [1529]	train-mlogloss:0.465419
# [1530]	train-mlogloss:0.465364
# [1531]	train-mlogloss:0.465321
# [1532]	train-mlogloss:0.465269
# [1533]	train-mlogloss:0.465233
# [1534]	train-mlogloss:0.465197
# [1535]	train-mlogloss:0.465153
# [1536]	train-mlogloss:0.46511
# [1537]	train-mlogloss:0.465068
# [1538]	train-mlogloss:0.465024
# [1539]	train-mlogloss:0.464969
# [1540]	train-mlogloss:0.464931
# [1541]	train-mlogloss:0.464898
# [1542]	train-mlogloss:0.464855
# [1543]	train-mlogloss:0.464818
# [1544]	train-mlogloss:0.464784
# [1545]	train-mlogloss:0.46474
# [1546]	train-mlogloss:0.464692
# [1547]	train-mlogloss:0.464658
# [1548]	train-mlogloss:0.464619
# [1549]	train-mlogloss:0.464578
# [1550]	train-mlogloss:0.464543
# [1551]	train-mlogloss:0.464505
# [1552]	train-mlogloss:0.464458
# [1553]	train-mlogloss:0.464421
# [1554]	train-mlogloss:0.464377
# [1555]	train-mlogloss:0.464343
# [1556]	train-mlogloss:0.464287
# [1557]	train-mlogloss:0.464244
# [1558]	train-mlogloss:0.464198
# [1559]	train-mlogloss:0.464146
# [1560]	train-mlogloss:0.4641
# [1561]	train-mlogloss:0.464052
# [1562]	train-mlogloss:0.464008
# [1563]	train-mlogloss:0.463952
# [1564]	train-mlogloss:0.463918
# [1565]	train-mlogloss:0.46388
# [1566]	train-mlogloss:0.46383
# [1567]	train-mlogloss:0.463774
# [1568]	train-mlogloss:0.463733
# [1569]	train-mlogloss:0.463694
# [1570]	train-mlogloss:0.463659
# [1571]	train-mlogloss:0.463618
# [1572]	train-mlogloss:0.463585
# [1573]	train-mlogloss:0.463568
# [1574]	train-mlogloss:0.463533
# [1575]	train-mlogloss:0.463487
# [1576]	train-mlogloss:0.463458
# [1577]	train-mlogloss:0.463408
# [1578]	train-mlogloss:0.463367
# [1579]	train-mlogloss:0.463331
# [1580]	train-mlogloss:0.463296
# [1581]	train-mlogloss:0.46325
# [1582]	train-mlogloss:0.463203
# [1583]	train-mlogloss:0.463159
# [1584]	train-mlogloss:0.463111
# [1585]	train-mlogloss:0.463073
# [1586]	train-mlogloss:0.463027
# [1587]	train-mlogloss:0.462967
# [1588]	train-mlogloss:0.462933
# ...
# [837]	train-mlogloss:0.499993
# [838]	train-mlogloss:0.499951
# [839]	train-mlogloss:0.499894
# [840]	train-mlogloss:0.49984
# [841]	train-mlogloss:0.499789
# [842]	train-mlogloss:0.499726
# [843]	train-mlogloss:0.499685
# [844]	train-mlogloss:0.499622
# [845]	train-mlogloss:0.499558
# [846]	train-mlogloss:0.499501
# [847]	train-mlogloss:0.49945
# [848]	train-mlogloss:0.499386
# [849]	train-mlogloss:0.499318
# [850]	train-mlogloss:0.499246
# [851]	train-mlogloss:0.499173
# [852]	train-mlogloss:0.499096
# [853]	train-mlogloss:0.499047
# [854]	train-mlogloss:0.498977
# [855]	train-mlogloss:0.498912
# [856]	train-mlogloss:0.498857
# [857]	train-mlogloss:0.498786
# [858]	train-mlogloss:0.498713
# [859]	train-mlogloss:0.498651
# [860]	train-mlogloss:0.498605
# [861]	train-mlogloss:0.498534
# [862]	train-mlogloss:0.498475
# [863]	train-mlogloss:0.498423
# [864]	train-mlogloss:0.498355
# [865]	train-mlogloss:0.498294
# [866]	train-mlogloss:0.498225
# [867]	train-mlogloss:0.498183
# [868]	train-mlogloss:0.498108
# [869]	train-mlogloss:0.498047
# [870]	train-mlogloss:0.497969
# [871]	train-mlogloss:0.497899
# [872]	train-mlogloss:0.497826
# [873]	train-mlogloss:0.497754
# [874]	train-mlogloss:0.497679
# [875]	train-mlogloss:0.497596
# [876]	train-mlogloss:0.497526
# [877]	train-mlogloss:0.497479
# [878]	train-mlogloss:0.497419
# [879]	train-mlogloss:0.497381
# [880]	train-mlogloss:0.497329
# [881]	train-mlogloss:0.497271
# [882]	train-mlogloss:0.497199
# [883]	train-mlogloss:0.497147
# [884]	train-mlogloss:0.497075
# [885]	train-mlogloss:0.49701
# [886]	train-mlogloss:0.496949
# [887]	train-mlogloss:0.496886
# [888]	train-mlogloss:0.496833
# [889]	train-mlogloss:0.496769
# [890]	train-mlogloss:0.496722
# [891]	train-mlogloss:0.496672
# [892]	train-mlogloss:0.496604
# [893]	train-mlogloss:0.496524
# [894]	train-mlogloss:0.496488
# [895]	train-mlogloss:0.496423
# [896]	train-mlogloss:0.496382
# [897]	train-mlogloss:0.496314
# [898]	train-mlogloss:0.496272
# [899]	train-mlogloss:0.496221
# [900]	train-mlogloss:0.496153
# [901]	train-mlogloss:0.496105
# [902]	train-mlogloss:0.496031
# [903]	train-mlogloss:0.495959
# [904]	train-mlogloss:0.495921
# [905]	train-mlogloss:0.495842
# [906]	train-mlogloss:0.495784
# [907]	train-mlogloss:0.495723
# [908]	train-mlogloss:0.495667
# [909]	train-mlogloss:0.495601
# [910]	train-mlogloss:0.495556
# [911]	train-mlogloss:0.495488
# [912]	train-mlogloss:0.495439
# [913]	train-mlogloss:0.495379
# [914]	train-mlogloss:0.495329
# [915]	train-mlogloss:0.495262
# [916]	train-mlogloss:0.495194
# [917]	train-mlogloss:0.495122
# [918]	train-mlogloss:0.495063
# [919]	train-mlogloss:0.495015
# [920]	train-mlogloss:0.494968
# [921]	train-mlogloss:0.494924
# [922]	train-mlogloss:0.494845
# [923]	train-mlogloss:0.494789
# [924]	train-mlogloss:0.494735
# [925]	train-mlogloss:0.494668
# [926]	train-mlogloss:0.494609
# [927]	train-mlogloss:0.494564
# [928]	train-mlogloss:0.494522
# [929]	train-mlogloss:0.494454
# [930]	train-mlogloss:0.4944
# [931]	train-mlogloss:0.494357
# [932]	train-mlogloss:0.494299
# [933]	train-mlogloss:0.494235
# [934]	train-mlogloss:0.494175
# [935]	train-mlogloss:0.494128
# [936]	train-mlogloss:0.494059
# [937]	train-mlogloss:0.494007
# [938]	train-mlogloss:0.493959
# [939]	train-mlogloss:0.493893
# [940]	train-mlogloss:0.493842
# [941]	train-mlogloss:0.493798
# [942]	train-mlogloss:0.493749
# [943]	train-mlogloss:0.493678
# [944]	train-mlogloss:0.493635
# [945]	train-mlogloss:0.49358
# [946]	train-mlogloss:0.49353
# [947]	train-mlogloss:0.493462
# [948]	train-mlogloss:0.493422
# [949]	train-mlogloss:0.493365
# [950]	train-mlogloss:0.493289
# [951]	train-mlogloss:0.493248
# [952]	train-mlogloss:0.493199
# [953]	train-mlogloss:0.493157
# [954]	train-mlogloss:0.493097
# [955]	train-mlogloss:0.493058
# [956]	train-mlogloss:0.493016
# [957]	train-mlogloss:0.492974
# [958]	train-mlogloss:0.492915
# [959]	train-mlogloss:0.492876
# [960]	train-mlogloss:0.492833
# [961]	train-mlogloss:0.492758
# [962]	train-mlogloss:0.49271
# [963]	train-mlogloss:0.492648
# [964]	train-mlogloss:0.492589
# [965]	train-mlogloss:0.492538
# [966]	train-mlogloss:0.492488
# [967]	train-mlogloss:0.49242
# [968]	train-mlogloss:0.492365
# [969]	train-mlogloss:0.492321
# [970]	train-mlogloss:0.492263
# [971]	train-mlogloss:0.492206
# [972]	train-mlogloss:0.492159
# [973]	train-mlogloss:0.492101
# [974]	train-mlogloss:0.49205
# [975]	train-mlogloss:0.491977
# [976]	train-mlogloss:0.491919
# [977]	train-mlogloss:0.491865
# [978]	train-mlogloss:0.491813
# [979]	train-mlogloss:0.491759
# [980]	train-mlogloss:0.491711
# [981]	train-mlogloss:0.491653
# [982]	train-mlogloss:0.4916
# [983]	train-mlogloss:0.491556
# [984]	train-mlogloss:0.49151
# [985]	train-mlogloss:0.491461
# [986]	train-mlogloss:0.49139
# [987]	train-mlogloss:0.491314
# [988]	train-mlogloss:0.491263
# [989]	train-mlogloss:0.491209
# [990]	train-mlogloss:0.491158
# [991]	train-mlogloss:0.491099
# [992]	train-mlogloss:0.491031
# [993]	train-mlogloss:0.490984
# [994]	train-mlogloss:0.490942
# [995]	train-mlogloss:0.490902
# [996]	train-mlogloss:0.490859
# [997]	train-mlogloss:0.490796
# [998]	train-mlogloss:0.490739
# [999]	train-mlogloss:0.490685
# [1000]	train-mlogloss:0.490633
# [1001]	train-mlogloss:0.49058
# [1002]	train-mlogloss:0.490533
# [1003]	train-mlogloss:0.490483
# [1004]	train-mlogloss:0.490437
# [1005]	train-mlogloss:0.490387
# [1006]	train-mlogloss:0.490327
# [1007]	train-mlogloss:0.490285
# [1008]	train-mlogloss:0.490224
# [1009]	train-mlogloss:0.490174
# [1010]	train-mlogloss:0.490136
# [1011]	train-mlogloss:0.490075
# [1012]	train-mlogloss:0.490022
# [1013]	train-mlogloss:0.489964
# [1014]	train-mlogloss:0.48992
# [1015]	train-mlogloss:0.489862
# [1016]	train-mlogloss:0.489815
# [1017]	train-mlogloss:0.489759
# [1018]	train-mlogloss:0.489718
# [1019]	train-mlogloss:0.48968
# [1020]	train-mlogloss:0.48963
# [1021]	train-mlogloss:0.489561
# [1022]	train-mlogloss:0.489492
# [1023]	train-mlogloss:0.489438
# [1024]	train-mlogloss:0.489388
# [1025]	train-mlogloss:0.489339
# [1026]	train-mlogloss:0.489261
# [1027]	train-mlogloss:0.489198
# [1028]	train-mlogloss:0.489157
# [1029]	train-mlogloss:0.489115
# [1030]	train-mlogloss:0.489052
# [1031]	train-mlogloss:0.488991
# [1032]	train-mlogloss:0.488936
# [1033]	train-mlogloss:0.488882
# [1034]	train-mlogloss:0.488823
# [1035]	train-mlogloss:0.48877
# [1036]	train-mlogloss:0.488711
# [1037]	train-mlogloss:0.488659
# [1038]	train-mlogloss:0.488618
# [1039]	train-mlogloss:0.488576
# [1040]	train-mlogloss:0.488539
# [1041]	train-mlogloss:0.488483
# [1042]	train-mlogloss:0.488436
# [1043]	train-mlogloss:0.488363
# [1044]	train-mlogloss:0.488311
# [1045]	train-mlogloss:0.488261
# [1046]	train-mlogloss:0.488219
# [1047]	train-mlogloss:0.488151
# [1048]	train-mlogloss:0.488096
# [1049]	train-mlogloss:0.488036
# [1050]	train-mlogloss:0.487992
# [1051]	train-mlogloss:0.487945
# [1052]	train-mlogloss:0.4879
# [1053]	train-mlogloss:0.487841
# [1054]	train-mlogloss:0.487787
# [1055]	train-mlogloss:0.487729
# [1056]	train-mlogloss:0.487677
# [1057]	train-mlogloss:0.48762
# [1058]	train-mlogloss:0.487567
# [1059]	train-mlogloss:0.487508
# [1060]	train-mlogloss:0.487454
# [1061]	train-mlogloss:0.487398
# [1062]	train-mlogloss:0.487344
# [1063]	train-mlogloss:0.48729
# [1064]	train-mlogloss:0.487242
# [1065]	train-mlogloss:0.487197
# [1066]	train-mlogloss:0.487137
# [1067]	train-mlogloss:0.487097
# [1068]	train-mlogloss:0.487056
# [1069]	train-mlogloss:0.486992
# [1070]	train-mlogloss:0.486933
# [1071]	train-mlogloss:0.486891
# [1072]	train-mlogloss:0.486836
# [1073]	train-mlogloss:0.48679
# [1074]	train-mlogloss:0.48673
# [1075]	train-mlogloss:0.48667
# [1076]	train-mlogloss:0.486615
# [1077]	train-mlogloss:0.486562
# [1078]	train-mlogloss:0.486518
# [1079]	train-mlogloss:0.486448
# [1080]	train-mlogloss:0.486389
# [1081]	train-mlogloss:0.486332
# [1082]	train-mlogloss:0.48628
# [1083]	train-mlogloss:0.486227
# [1084]	train-mlogloss:0.486167
# [1085]	train-mlogloss:0.486119
# [1086]	train-mlogloss:0.486065
# [1087]	train-mlogloss:0.486008
# [1088]	train-mlogloss:0.485955
# [1089]	train-mlogloss:0.485904
# [1090]	train-mlogloss:0.485861
# [1091]	train-mlogloss:0.485798
# [1092]	train-mlogloss:0.485758
# [1093]	train-mlogloss:0.485709
# [1094]	train-mlogloss:0.485656
# [1095]	train-mlogloss:0.485607
# [1096]	train-mlogloss:0.485563
# [1097]	train-mlogloss:0.485508
# [1098]	train-mlogloss:0.48544
# [1099]	train-mlogloss:0.485383
# [1100]	train-mlogloss:0.485327
# [1101]	train-mlogloss:0.485281
# [1102]	train-mlogloss:0.48523
# [1103]	train-mlogloss:0.485172
# [1104]	train-mlogloss:0.485116
# [1105]	train-mlogloss:0.485073
# [1106]	train-mlogloss:0.485024
# [1107]	train-mlogloss:0.484971
# [1108]	train-mlogloss:0.484909
# [1109]	train-mlogloss:0.484845
# [1110]	train-mlogloss:0.484796
# [1111]	train-mlogloss:0.484744
# [1112]	train-mlogloss:0.484698
# [1113]	train-mlogloss:0.484666
# [1114]	train-mlogloss:0.484614
# [1115]	train-mlogloss:0.484562
# [1116]	train-mlogloss:0.484506
# [1117]	train-mlogloss:0.484456
# [1118]	train-mlogloss:0.4844
# [1119]	train-mlogloss:0.484355
# [1120]	train-mlogloss:0.484309
# [1121]	train-mlogloss:0.484253
# [1122]	train-mlogloss:0.484224
# [1123]	train-mlogloss:0.484151
# [1124]	train-mlogloss:0.484093
# [1125]	train-mlogloss:0.484056
# [1126]	train-mlogloss:0.484007
# [1127]	train-mlogloss:0.483985
# [1128]	train-mlogloss:0.483924
# [1129]	train-mlogloss:0.483875
# [1130]	train-mlogloss:0.483836
# [1131]	train-mlogloss:0.483778
# [1132]	train-mlogloss:0.483716
# [1133]	train-mlogloss:0.483671
# [1134]	train-mlogloss:0.483627
# [1135]	train-mlogloss:0.483574
# [1136]	train-mlogloss:0.483537
# [1137]	train-mlogloss:0.483484
# [1138]	train-mlogloss:0.483427
# [1139]	train-mlogloss:0.483372
# [1140]	train-mlogloss:0.483325
# [1141]	train-mlogloss:0.483288
# [1142]	train-mlogloss:0.483223
# [1143]	train-mlogloss:0.483174
# [1144]	train-mlogloss:0.483122
# [1145]	train-mlogloss:0.483053
# [1146]	train-mlogloss:0.482991
# [1147]	train-mlogloss:0.48294
# [1148]	train-mlogloss:0.482915
# [1149]	train-mlogloss:0.48287
# [1150]	train-mlogloss:0.482814
# [1151]	train-mlogloss:0.482753
# [1152]	train-mlogloss:0.482714
# [1153]	train-mlogloss:0.482665
# [1154]	train-mlogloss:0.482607
# [1155]	train-mlogloss:0.482545
# [1156]	train-mlogloss:0.482492
# [1157]	train-mlogloss:0.482449
# [1158]	train-mlogloss:0.482401
# [1159]	train-mlogloss:0.482341
# [1160]	train-mlogloss:0.482297
# [1161]	train-mlogloss:0.48225
# [1162]	train-mlogloss:0.482194
# [1163]	train-mlogloss:0.482132
# [1164]	train-mlogloss:0.482069
# [1165]	train-mlogloss:0.482018
# [1166]	train-mlogloss:0.481976
# [1167]	train-mlogloss:0.481933
# [1168]	train-mlogloss:0.481865
# [1169]	train-mlogloss:0.481807
# [1170]	train-mlogloss:0.481755
# [1171]	train-mlogloss:0.481704
# [1172]	train-mlogloss:0.48167
# [1173]	train-mlogloss:0.48164
# [1174]	train-mlogloss:0.481593
# [1175]	train-mlogloss:0.481533
# [1176]	train-mlogloss:0.481473
# [1177]	train-mlogloss:0.481426
# [1178]	train-mlogloss:0.481368
# [1179]	train-mlogloss:0.481314
# [1180]	train-mlogloss:0.481245
# [1181]	train-mlogloss:0.481194
# [1182]	train-mlogloss:0.481141
# [1183]	train-mlogloss:0.481112
# [1184]	train-mlogloss:0.481067
# [1185]	train-mlogloss:0.481027
# [1186]	train-mlogloss:0.480982
# [1187]	train-mlogloss:0.480941
# [1188]	train-mlogloss:0.480891
# [1189]	train-mlogloss:0.480838
# [1190]	train-mlogloss:0.480792
# [1191]	train-mlogloss:0.480737
# [1192]	train-mlogloss:0.48069
# [1193]	train-mlogloss:0.480652
# [1194]	train-mlogloss:0.480599
# [1195]	train-mlogloss:0.48057
# [1196]	train-mlogloss:0.480519
# [1197]	train-mlogloss:0.480471
# [1198]	train-mlogloss:0.480413
# [1199]	train-mlogloss:0.480376
# [1200]	train-mlogloss:0.480343
# [1201]	train-mlogloss:0.480277
# [1202]	train-mlogloss:0.48024
# [1203]	train-mlogloss:0.480179
# [1204]	train-mlogloss:0.480121
# [1205]	train-mlogloss:0.480082
# [1206]	train-mlogloss:0.480034
# [1207]	train-mlogloss:0.479979
# [1208]	train-mlogloss:0.479933
# [1209]	train-mlogloss:0.479878
# [1210]	train-mlogloss:0.479842
# [1211]	train-mlogloss:0.479781
# [1212]	train-mlogloss:0.47974
# [1213]	train-mlogloss:0.479685
# [1214]	train-mlogloss:0.479629
# [1215]	train-mlogloss:0.479576
# [1216]	train-mlogloss:0.479549
# [1217]	train-mlogloss:0.479494
# [1218]	train-mlogloss:0.479439
# [1219]	train-mlogloss:0.479382
# [1220]	train-mlogloss:0.479328
# [1221]	train-mlogloss:0.479277
# [1222]	train-mlogloss:0.479221
# [1223]	train-mlogloss:0.479189
# [1224]	train-mlogloss:0.479136
# [1225]	train-mlogloss:0.479087
# [1226]	train-mlogloss:0.479043
# [1227]	train-mlogloss:0.479002
# [1228]	train-mlogloss:0.478961
# [1229]	train-mlogloss:0.478902
# [1230]	train-mlogloss:0.47886
# [1231]	train-mlogloss:0.478813
# [1232]	train-mlogloss:0.478753
# [1233]	train-mlogloss:0.478695
# [1234]	train-mlogloss:0.47865
# [1235]	train-mlogloss:0.478595
# [1236]	train-mlogloss:0.478535
# [1237]	train-mlogloss:0.478498
# [1238]	train-mlogloss:0.478445
# [1239]	train-mlogloss:0.47841
# [1240]	train-mlogloss:0.478369
# [1241]	train-mlogloss:0.478338
# [1242]	train-mlogloss:0.478306
# [1243]	train-mlogloss:0.478266
# [1244]	train-mlogloss:0.478218
# [1245]	train-mlogloss:0.478177
# [1246]	train-mlogloss:0.478123
# [1247]	train-mlogloss:0.478075
# [1248]	train-mlogloss:0.478025
# [1249]	train-mlogloss:0.477968
# [1250]	train-mlogloss:0.477925
# [1251]	train-mlogloss:0.477882
# [1252]	train-mlogloss:0.477836
# [1253]	train-mlogloss:0.477791
# [1254]	train-mlogloss:0.477737
# [1255]	train-mlogloss:0.477684
# [1256]	train-mlogloss:0.477653
# [1257]	train-mlogloss:0.477592
# [1258]	train-mlogloss:0.477551
# [1259]	train-mlogloss:0.477502
# [1260]	train-mlogloss:0.47746
# [1261]	train-mlogloss:0.477387
# [1262]	train-mlogloss:0.477324
# [1263]	train-mlogloss:0.477282
# [1264]	train-mlogloss:0.477215
# [1265]	train-mlogloss:0.477171
# [1266]	train-mlogloss:0.477112
# [1267]	train-mlogloss:0.477066
# [1268]	train-mlogloss:0.477014
# [1269]	train-mlogloss:0.476965
# [1270]	train-mlogloss:0.47691
# [1271]	train-mlogloss:0.476861
# [1272]	train-mlogloss:0.476798
# [1273]	train-mlogloss:0.476753
# [1274]	train-mlogloss:0.476689
# [1275]	train-mlogloss:0.476644
# [1276]	train-mlogloss:0.476599
# [1277]	train-mlogloss:0.476548
# [1278]	train-mlogloss:0.47651
# [1279]	train-mlogloss:0.47647
# [1280]	train-mlogloss:0.476435
# [1281]	train-mlogloss:0.476387
# [1282]	train-mlogloss:0.476326
# [1283]	train-mlogloss:0.476298
# [1284]	train-mlogloss:0.476241
# [1285]	train-mlogloss:0.476188
# [1286]	train-mlogloss:0.476114
# [1287]	train-mlogloss:0.476069
# [1288]	train-mlogloss:0.47603
# [1289]	train-mlogloss:0.475968
# [1290]	train-mlogloss:0.47593
# [1291]	train-mlogloss:0.475892
# [1292]	train-mlogloss:0.475855
# [1293]	train-mlogloss:0.475805
# [1294]	train-mlogloss:0.475764
# [1295]	train-mlogloss:0.475709
# [1296]	train-mlogloss:0.475669
# [1297]	train-mlogloss:0.47563
# [1298]	train-mlogloss:0.475588
# [1299]	train-mlogloss:0.475538
# [1300]	train-mlogloss:0.475496
# [1301]	train-mlogloss:0.475449
# [1302]	train-mlogloss:0.475415
# [1303]	train-mlogloss:0.475364
# [1304]	train-mlogloss:0.475332
# [1305]	train-mlogloss:0.475289
# [1306]	train-mlogloss:0.475247
# [1307]	train-mlogloss:0.475213
# [1308]	train-mlogloss:0.475153
# [1309]	train-mlogloss:0.475101
# [1310]	train-mlogloss:0.475072
# [1311]	train-mlogloss:0.475026
# [1312]	train-mlogloss:0.474989
# [1313]	train-mlogloss:0.474955
# [1314]	train-mlogloss:0.47492
# [1315]	train-mlogloss:0.474867
# [1316]	train-mlogloss:0.474821
# [1317]	train-mlogloss:0.474779
# [1318]	train-mlogloss:0.474726
# [1319]	train-mlogloss:0.474685
# [1320]	train-mlogloss:0.474634
# [1321]	train-mlogloss:0.474589
# [1322]	train-mlogloss:0.474538
# [1323]	train-mlogloss:0.474498
# [1324]	train-mlogloss:0.474435
# [1325]	train-mlogloss:0.474388
# [1326]	train-mlogloss:0.474346
# [1327]	train-mlogloss:0.474306
# [1328]	train-mlogloss:0.474249
# [1329]	train-mlogloss:0.474193
# [1330]	train-mlogloss:0.474165
# [1331]	train-mlogloss:0.474106
# [1332]	train-mlogloss:0.474069
# [1333]	train-mlogloss:0.474023
# [1334]	train-mlogloss:0.473974
# [1335]	train-mlogloss:0.473924
# [1336]	train-mlogloss:0.473878
# [1337]	train-mlogloss:0.473829
# [1338]	train-mlogloss:0.473789
# [1339]	train-mlogloss:0.473745
# [1340]	train-mlogloss:0.473689
# [1341]	train-mlogloss:0.473645
# [1342]	train-mlogloss:0.47361
# [1343]	train-mlogloss:0.473587
# [1344]	train-mlogloss:0.473552
# [1345]	train-mlogloss:0.473508
# [1346]	train-mlogloss:0.473476
# [1347]	train-mlogloss:0.473421
# [1348]	train-mlogloss:0.473368
# [1349]	train-mlogloss:0.473328
# [1350]	train-mlogloss:0.473285
# [1351]	train-mlogloss:0.473245
# [1352]	train-mlogloss:0.473203
# [1353]	train-mlogloss:0.473145
# [1354]	train-mlogloss:0.473077
# [1355]	train-mlogloss:0.473029
# [1356]	train-mlogloss:0.472988
# [1357]	train-mlogloss:0.472951
# [1358]	train-mlogloss:0.472908
# [1359]	train-mlogloss:0.472853

# %%
def prepare_submission():
    xgtest = xgb.DMatrix(X_test)
    for i in range(rounds):
        model=xgbclf[i]
        if i==0:
            preds = model.predict(xgtest)
        else:
            preds += model.predict(xgtest)
    preds /= rounds
    return preds

submit = prepare_submission()

# %%
submission = pd.DataFrame(submit, columns = ['high','medium','low']).set_index(test_df.index)
submission['listing_id'] = test_df.listing_id.values
submission.to_csv('rogue_one_10seed_submission.csv', index= False)
#0.5326 LB

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd
from collections import defaultdict
from scipy import sparse
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import xgboost as xgb
from sklearn.cross_validation import StratifiedKFold
from sklearn.metrics import log_loss
from scipy.sparse import csr_matrix
import sys
reload(sys)
sys.setdefaultencoding('utf8')

def main():
    

        #training and test files, created using SRK's python script
        train_file="train_stnet.csv"
        test_file="test_stnet.csv"
        
        ######### Load files ############

#         X,X_test,y,ids=load_data_sparse (data_path="input/")# you might need to change that to whatever folder the json files are in
#         ids= np.array([int(k)+68119576 for k in ids ]) # we add the id value we removed before for scaling reasons.
#         print(X.shape, X_test.shape) 
        
        #create to numpy arrays (dense format)        
        X    = np.array(X_train)
        X_ts = np.array(X_test)  
        
        print ("scalling") 
        #scale the data
        stda=StandardScaler()  
        X_test=stda.fit_transform (X_test)          
        X=stda.transform(X)

        
        CO=[0,14,21] # columns to create averages on
        
        #Create Arrays for meta
        train_stacker=[ [0.0 for s in range(3)]  for k in range (0,(X.shape[0])) ]
        test_stacker=[[0.0 for s in range(3)]   for k in range (0,(X_ts.shape[0]))]
        
        number_of_folds=5 # number of folds to use
        print("kfolder")
        #cerate 5 fold object
        mean_logloss = 0.0
        kfolder=StratifiedKFold(y_train, n_folds=number_of_folds,shuffle=True, random_state=15)   

        #xgboost_params
        param = {}
        param['objective'] = 'multi:softprob'
        param['eta'] = .02
        param['gamma'] = 0.0
        param['max_depth'] = 6
        param['silent'] = 1
        param['num_class'] = 3
        param['eval_metric'] = "mlogloss"
        param['reg_alpha'] = 2
        param['min_child_weight'] = 10
        param['subsample'] = 0.75
        param['colsample_bytree'] = 0.5
        param['seed'] = 3
        param['nthread'] = 4
        param['n_jobs'] = -1
# num_rounds = 5000 

        
        i=0 # iterator counter
        print ("starting cross validation with %d kfolds " % (number_of_folds))
        for train_index, test_index in kfolder:
                # creaning and validation sets
                X_train, X_cv = X[train_index], X[test_index]
                y_trn, y_cv = np.array(y_train)[train_index], np.array(y_train)[test_index]
                #create past averages for some fetaures
#                 W_train,W_cv=convert_to_avg(X_train,y_tr, X_cv, seed=1, cvals=5, roundings=2, columns=CO)
                W_train = X_train
                W_cv = X_cv 
                print (" train size: %d. test size: %d, cols: %d " % ((W_train.shape[0]) ,(W_cv.shape[0]) ,(W_train.shape[1]) ))
                #training
                X1=xgb.DMatrix(csr_matrix(W_train), label=np.array(y_tr),missing =-999.0)
                X1cv=xgb.DMatrix(csr_matrix(W_cv), missing =-999.0)
                bst = xgb.train(param.items(), X1, 1000) 
                #predictions
                predictions = bst.predict(X1cv)     
                preds=predictions.reshape( W_cv.shape[0], 3)

                #scalepreds(preds)     
                logs = log_loss(y_cv,preds)
                print "size train: %d size cv: %d loglikelihood (fold %d/%d): %f" % ((W_train.shape[0]), (W_cv.shape[0]), i + 1, number_of_folds, logs)
             
                mean_logloss += logs
                #save the results
                no=0
                for real_index in test_index:
                    for d in range (0,3):
                        train_stacker[real_index][d]=(preds[no][d])
                    no+=1
                i+=1
        mean_logloss/=number_of_folds
        print (" Average Lolikelihood: %f" % (mean_logloss) )
                
        #calculating averages for the train data
#         W,W_test=convert_to_avg(X,y, X_test, seed=1, cvals=5, roundings=2, columns=CO)
        W= X
        W_test= X_ts          
        #X_test=np.column_stack((X_test,woe_cv))      
        print (" making test predictions ")
        
        X1=xgb.DMatrix(csr_matrix(W), label=np.array(y_train) , missing =-999.0)
        X1cv=xgb.DMatrix(csr_matrix(W_test), missing =-999.0)
        bst = xgb.train(param.items(), X1, 1000) 
        predictions = bst.predict(X1cv)     
        preds=predictions.reshape( W_test.shape[0], 3)        
       
        for pr in range (0,len(preds)):  
                for d in range (0,3):            
                    test_stacker[pr][d]=(preds[pr][d]) 
        
        
        
        print ("merging columns")   
        #stack xgboost predictions
        X=np.column_stack((X,train_stacker))
        # stack id to test
        X_ts=np.column_stack((X_ts,test_stacker))        
        
#         # stack target to train
#         X=np.column_stack((y_train,X))
#         # stack id to test
#         X_test=np.column_stack((ids,X_test))
        
#         #export to txt files (, del.)
#         print ("exporting files")
#         np.savetxt(train_file, X, delimiter=",", fmt='%.5f')
#         np.savetxt(test_file, X_test, delimiter=",", fmt='%.5f')        

#         print("Write results...")
#         output_file = "submission_"+str( (mean_logloss ))+".csv"
#         print("Writing submission to %s" % output_file)
#         f = open(output_file, "w")   
#         f.write("listing_id,high,medium,low\n")# the header   
#         for g in range(0, len(test_stacker))  :
#           f.write("%s" % (ids[g]))
#           for prediction in test_stacker[g]:
#              f.write(",%f" % (prediction))    
#           f.write("\n")
#         f.close()
#         print("Done.")
                             
                  

       



if __name__=="__main__":
  main()
# Out:
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-100-5b47abe553ff> in <module>()
#     157
#     158 if __name__=="__main__":
# --> 159   main()
#
# <ipython-input-100-5b47abe553ff> in main()
#      27
#      28         #create to numpy arrays (dense format)
# ---> 29         X    = np.array(X_train)
#      30         X_ts = np.array(X_test)
#      31
#
# UnboundLocalError: local variable 'X_train' referenced before assignment

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# x_train = np.array(X_train)
# x_test = np.array(X_test)

X_train = X_train.replace([np.inf, -np.inf], np.nan)
X_train = X_train.fillna(0)

X_test = X_test.replace([np.inf, -np.inf], np.nan)
X_test = X_test.fillna(0)

x_train = scaler.fit_transform(X_train)
x_test = scaler.transform(X_test)

print x_train.shape
print x_test.shape
# Out:
# (49352, 175)
# (74659, 175)

# %%
from sklearn.manifold import TSNE,MDS

dim = TSNE(n_components= 10, perplexity=30.0, early_exaggeration=4.0, learning_rate=1000.0, n_iter=1000, 
                      n_iter_without_progress=30, min_grad_norm=1e-07, metric='euclidean', init='random', verbose=0, 
                      random_state=None, method='barnes_hut', angle=0.5)

# %%
# tr_tsne = dim.fit_transform(x_train)

test_tsne = dim.fit_transform(x_test)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-282-4ea1c9008245> in <module>()
#       1 # tr_tsne = dim.fit_transform(x_train)
#       2
# ----> 3 test_tsne = dim.fit_transform(x_test)
#
# /usr/lib64/python2.7/site-packages/sklearn/manifold/t_sne.pyc in fit_transform(self, X, y)
#     882             Embedding of the training data in low-dimensional space.
#     883         """
# --> 884         embedding = self._fit(X)
#     885         self.embedding_ = embedding
#     886         return self.embedding_
#
# /usr/lib64/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _fit(self, X, skip_num_points)
#     787                           X_embedded=X_embedded,
#     788                           neighbors=neighbors_nn,
# --> 789                           skip_num_points=skip_num_points)
#     790
#     791     def _tsne(self, P, degrees_of_freedom, n_samples, random_state,
#
# /usr/lib64/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _tsne(self, P, degrees_of_freedom, n_samples, random_state, X_embedded, neighbors, skip_num_points)
#     856         opt_args['n_iter'] = self.n_iter
#     857         opt_args['it'] = it + 1
# --> 858         params, error, it = _gradient_descent(obj_func, params, **opt_args)
#     859
#     860         if self.verbose:
#
# /usr/lib64/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _gradient_descent(objective, p0, it, n_iter, objective_error, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, min_error_diff, verbose, args, kwargs)
#     385
#     386     for i in range(it, n_iter):
# --> 387         new_error, grad = objective(p, *args, **kwargs)
#     388         grad_norm = linalg.norm(grad)
#     389
#
# /usr/lib64/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _kl_divergence_bh(params, P, neighbors, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose)
#     288     error = _barnes_hut_tsne.gradient(sP, X_embedded, neighbors,
#     289                                       grad, angle, n_components, verbose,
# --> 290                                       dof=degrees_of_freedom)
#     291     c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     292     grad = grad.ravel()
#
# KeyboardInterrupt:

# %%
mds = MDS(n_components=2, metric=True, n_init=4, max_iter=300, verbose=0, eps=0.001, n_jobs=1, random_state=None,
          dissimilarity='euclidean')
